# %% [markdown]
# <span style="font-size: 36px;">W4111_Fall_2024_003 - Introduction to Databases:<br> Homework 3 and 4 Setup<br>Game of Thrones Data Engineering</span>

# %% [markdown]
# # Overview

# %% [markdown]
# ## Application Scenario

# %% [markdown]
# There are many types of applications that use databases. Two of the most common types are:
# 1. __Interactive/Operational Applications__ allow end users to create, retrieve, update and delete information. Online banking, e-commerce, course registration, etc. are examples. The non-programming track students implement a simple, [full-stack](https://en.wikipedia.org/wiki/Solution_stack), interaction application.
# 2. __Data Insight/Decision Support Applications__ are primarily for analysts and business professionals. The application enable complex query and data navigation to provide information useful for managing and improving business processes, products, etc. Non-programming tracks students implement complex queries that provide datasets useful for visualization. Visualization is often the first step in a data insight project.

# %% [markdown]
# The following diagram depicts some major elements of the applications.
# - Both tracks implement a simple [data engineering](https://en.wikipedia.org/wiki/Data_engineering) project, specifically an [extract-transform-load](https://en.wikipedia.org/wiki/Extract,_transform,_load) application in a Jupyter notebook.
#   - The input datatsets are information from [IMDB](https://developer.imdb.com/non-commercial-datasets/) and information about [Game of Thrones](https://github.com/jeffreylancaster/game-of-thrones).
#   - The data engineer tasks process and load information into three databases:
#       - A local installation of MySQL
#       - A cloud document database on [MongoDB Atlas](https://www.mongodb.com/atlas)
#       - A graph database on [Neo4j Aura](https://neo4j.com/product/auradb/)
# - The non-programming track implements a very simply decision support/data insight application in a Jupyter notebook. The application queries the various databases to produce a "view" that can be used for visualization.
# - The programming track implements a web application that implements simple retrieve and data navigation.

# %% [markdown]
# | <img src="overall-system.jpg" width="800px;"> |
# | :---: |
# | __Overall Application Concept__ |

# %% [markdown]
# ## Data Engineering

# %% [markdown]
# The following diagram is an overview of data engineering concepts, and entity-relationship modeling in general.
#
# The data engineering tasks for the project are primarily _bottom-up data analysis and engineering._ There are two datasets that are the input to the data engineering:
# 1. IMDB data in comma separated value file.
# 2. Games-of-Thrones data in [JSON](https://en.wikipedia.org/wiki/JSON) files.
#
# To simplify the project, the definition of the problem defines the "to be" data model and explains how to map from the "as is" data to the "to be" data. The specification also problems examples to help students get started.

# %% [markdown]
# | <img src="./top_down_bottom_up.jpg" width="700px;"> |
# | :---: |
# | __Data Modeling__ |

# %% [markdown]
# | <img src="./data-janitor.jpg" width="700px;"> |
# | :---: |
# | __Data Engineering__ |

# %% [markdown]
# ## Data Insight Application

# %% [markdown]
# A separate document will explain the data analysis and insight tasks. The current project and purpose of this notebook is to ensure that students have a working environment.

# %% [markdown]
# ## Interactive Web Application

# %% [markdown]
# A separate document will explain the data analysis and insight tasks. The current project and purpose of this notebook is to ensure that students have a working environment.

# %% [markdown]
# ## This Notebook

# %% [markdown]
# This notebook simply enables students to get started with the environment, test their setup, etc.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# To complete this notebook, the students must have setup and configured a MongoDB Atlas and Neo4j Aura environment. The recorded recitation of 2024-NOV-17 explains how to do the setup.

# %% [markdown]
# # Initialization

# %% [markdown]
# ## General Python Packages

# %%
import copy

# %%
import json

# %%
import pandas

# %%
# You should have installed the packages for previous homework assignments
#
import pymysql
import sqlalchemy

# %%
# You may have to do %pip installs to use the packages below.
#
# %pip install "pymongo[srv]"
import pymongo

# %%
# You may have to do %pip installs to use the packages below.
#
# %pip install neo4j
import neo4j

# %%
import numpy

# %% [markdown]
# ## MySQL

# %% [markdown]
# ### ipython-sql

# %%
# You have installed and configured ipython-sql for previous assignments.
# https://pypi.org/project/ipython-sql/
#
# %load_ext sql

# %%
# Make sure that you set these values to the correct values for your installation and 
# configuration of MySQL
#
db_user = "root"
db_password = "dbuserdbuser"

# %%
# Create the URL for connecting to the database.
# Do not worry about the local_infile=1, I did that for wizard reasons that you should not have to use.
#
db_url = f"mysql+pymysql://{db_user}:{db_password}@localhost?local_infile=1"

# %%
# Initialize ipython-sql
#
# %sql $db_url

# %%
# Your answer will be different based on the databases that you have created on your local MySQL instance.
#
# %sql show databases
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 21 rows affected.
# [('classicmodels',),
#  ('columbia_model',),
#  ('course_management',),
#  ('course_student_coupons',),
#  ('courseworks_videos',),
#  ('db_book',),
#  ('F24_examples',),
#  ('f24_GoT',),
#  ('f24_imdb_clean',),
#  ('F24_IMDB_Raw',),
#  ('f24_imdb_raw_new',),
#  ('fitness',),
#  ('import_web_data',),
#  ('information_schema',),
#  ('lahmansbaseballdb',),
#  ('lor_data',),
#  ('mysql',),
#  ('p1_database',),
#  ('performance_schema',),
#  ('sys',),
#  ('testdb',)]

# %% [markdown]
# ### PyMySQL

# %%
default_mysql_conn = pymysql.connect(
    user=db_user,
    password=db_password,
    host="localhost",
    port=3306,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True
)

# %%
cur = default_mysql_conn.cursor()

result = cur.execute("show databases;");
result = cur.fetchall()
result_df = pandas.DataFrame(result)
result_df
# Out:
#                   Database
# 0            classicmodels
# 1           columbia_model
# 2        course_management
# 3   course_student_coupons
# 4       courseworks_videos
# 5                  db_book
# 6             F24_examples
# 7                  f24_GoT
# 8           f24_imdb_clean
# 9             F24_IMDB_Raw
# 10        f24_imdb_raw_new
# 11                 fitness
# 12         import_web_data
# 13      information_schema
# 14       lahmansbaseballdb
# 15                lor_data
# 16                   mysql
# 17             p1_database
# 18      performance_schema
# 19                     sys
# 20                  testdb

# %% [markdown]
# ### SQLAlchemy

# %%
from sqlalchemy import create_engine
default_engine = create_engine(db_url)

# %%
result_df = pandas.read_sql(
    "show databases", con=default_engine
)
result_df
# Out:
#                   Database
# 0            classicmodels
# 1           columbia_model
# 2        course_management
# 3   course_student_coupons
# 4       courseworks_videos
# 5                  db_book
# 6             F24_examples
# 7                  f24_GoT
# 8           f24_imdb_clean
# 9             F24_IMDB_Raw
# 10        f24_imdb_raw_new
# 11                 fitness
# 12         import_web_data
# 13      information_schema
# 14       lahmansbaseballdb
# 15                lor_data
# 16                   mysql
# 17             p1_database
# 18      performance_schema
# 19                     sys
# 20                  testdb

# %% [markdown]
# ## MongoDB Atlas

# %%
mongo_db_pw="b2i7hvgS0YCl5k3Z"
mongodb_user="dbuser"

# %%
# You have to set this information in MongoDB Atlas by creating a user and setting a password.
#
# Since I publish my notebook on GitHub, I keep the information in a separate file that I do not share.
#
# The import below will not work for you. You can directly enter your information.
import my_secrets

# %%
# mongodb_user = "dff9"
# mongo_db_pw = my_secrets.mongo_db_pw

# %%
# You can get the URL and info below from looking at the connect instructions for you MongoDB Atlas instance.
#
# mongo_db_url = f"mongodb+srv://{mongodb_user}:{mongo_db_pw}@cluster0.t8qdk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

mongo_db_url = f"mongodb+srv://{mongodb_user}:{mongo_db_pw}@w4111hw.q6fxp.mongodb.net/?retryWrites=true&w=majority&appName=W4111HW"

# %%
mongo_client = pymongo.MongoClient(mongo_db_url)

# %%
# Your list of databases will be different.
#
list(mongo_client.list_databases())
# Out:
# [{'name': 'sample_mflix', 'sizeOnDisk': 128262144, 'empty': False},
#  {'name': 'admin', 'sizeOnDisk': 393216, 'empty': False},
#  {'name': 'local', 'sizeOnDisk': 11278524416, 'empty': False}]

# %%
list(mongo_client.sample_mflix.list_collections())
# Out:
# [{'name': 'movies',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\x17\x0c\xbf\x85>\xa2E\xc1\x92\x96\xaf\xd6^\xf6Z\xb0', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'comments',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'5\xacl]\x15[@\n\xb6t?f\xc3f\xa4d', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'embedded_movies',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'S\xe2\xff\x9a\x8a6IQ\x8d2l\x1d\xf6\x95\xeb\xe3', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'theaters',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'Y\x15l\x14\x0e\xc9Eb\xa4>\xd4\xaax\xfa\x00\xd6', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'sessions',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\x95\x08\xe4\xea\x07.K9\xbb\x1a?\\\x02\xf7\x16l', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'users',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\xe3\xc3I\xca\x08\xacM\x8f\xb7~\x8cL\xb4\x1b`W', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}}]

# %% [markdown]
# ## Neo4j

# %%
# You need to have created a Neo4j Aura DB with a user ID and information.
# Please make sure you copied the information for connecting.
# You can download this information when you create your instance.
#
# Wait 60 seconds before connecting using these details, or login to https://console.neo4j.io to validate the Aura Instance is available
#
# You will have to modify the file you download to wrap the strings with "
#
NEO4J_URI="neo4j+s://a21b3c82.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="U9Sql3CKGFBMgUbxDRV6aRlFwx4keShh_np-YrOciDo"
AURA_INSTANCEID="a21b3c82"
AURA_INSTANCENAME="Instance01"

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
URI = NEO4J_URI
AUTH = (NEO4J_USERNAME, NEO4J_PASSWORD)

with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()

# %%
# The following code assumes that you followed the tutorial for the Movie Database and loaded the data.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    # driver.verify_connectivity()
    
    records, summary, keys = driver.execute_query(
        "MATCH (p:Person) RETURN p.name AS name, p.born as birth_year",
    )
    
    # Loop through results and do something with them
    # There is probably an easier way to do this.
    #
    person_records = []
    for person in records:
        new_p = dict(person)
        person_records.append(new_p)
    
    # Summary information
    print("The query `{query}` returned {records_count} records in {time} ms.".format(
        query=summary.query, records_count=len(records),
        time=summary.result_available_after,
    ))
# Out:
# The query `MATCH (p:Person) RETURN p.name AS name, p.born as birth_year` returned 133 records in 33 ms.

# %%
results_df = pandas.DataFrame(person_records)
results_df.head(10)
# Out:
#                  name  birth_year
# 0        Keanu Reeves      1964.0
# 1    Carrie-Anne Moss      1967.0
# 2  Laurence Fishburne      1961.0
# 3        Hugo Weaving      1960.0
# 4     Lilly Wachowski      1967.0
# 5      Lana Wachowski      1965.0
# 6         Joel Silver      1952.0
# 7         Emil Eifrem      1978.0
# 8     Charlize Theron      1975.0
# 9           Al Pacino      1940.0

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Atlas MongoDB

# %% [markdown]
# There is some helper python code in the relative directory ```process_got``` and in the ```utils``` directory.
#
#
# I make copies of some of the code for convenience so that you can run it in the notebook.

# %%
def load_json_file(file_path):

    with open(file_path, "r") as in_file:
        result = json.load(in_file)

    return result

# %%
# There is a bunch of GoT files in the relative data directory.
# %ls ../data/GoT
# Out:
# character_relationship_scenes.json  heatmap.json
# characters-gender-all.json          keyValues.json
# characters-gender.json              lands-of-ice-and-fire.json
# characters-groups.json              locations.json
# characters-include.json             opening-locations.json
# characters.json                     script-bag-of-words.json
# colors.json                         wordcount-gender.json
# costars.json                        wordcount-synonyms.json
# episodes.json                       wordcount.json

# %%
# This is a set of files to load and save to MongoDB Atlas.
#
# Set this to the location where you have the data files in your installation
#
data_path = "../data/GoT/"

def load_and_save_file(file_path,
                       mongodb_con, database_name,
                       collection_name, 
                       top_level_element=None, 
                       is_list=True,
                       drop_collection=True):

    j_data = load_json_file(file_path)

    if top_level_element:
        j_data = j_data[top_level_element]

    if not is_list:
        j_data = [j_data]

    if drop_collection:
        mongodb_con[database_name][collection_name].drop()

    mongodb_con[database_name][collection_name].insert_many(j_data)


def load_and_save_all_files(data_file_info, mongodb_con):

    for f in data_file_info:
        load_and_save_file(
            file_path=data_path + f['file_name'],
            mongodb_con=mongodb_con,
            database_name=f['database'],
            collection_name=f['collection'],
            top_level_element=f['top_level_element'],
            is_list=f["is_list"]
        )

# %%
# The files to load.
#
data_file_load_info = [
    {
        "file_name": "characters-groups.json",
        "top_level_element": "groups",
        "database": "f24_got",
        "collection": "characters_groups",
        "is_list": True
    },
    {
        "file_name": "characters.json",
        "top_level_element": "characters",
        "database": "f24_got",
        "collection": "characters",
        "is_list": True
    },
    {
        "file_name": "episodes.json",
        "top_level_element": "episodes",
        "database": "f24_got",
        "collection": "episodes",
        "is_list": True
    },
    {
        "file_name": "locations.json",
        "top_level_element": "regions",
        "database": "f24_got",
        "collection": "locations",
        "is_list": True
    }
]

# %%
load_and_save_all_files(data_file_load_info, mongo_client)

# %%
# Test if we loaded properly
# 
characters = mongo_client["f24_got"]["characters"].find(
    {},
    { 
        "_id": 0, 
        "characterName": 1,
        "actorName": 1,
        "actorLink": 1,
        "houseName": 1,
        "royal": 1,
        "kingsguard": 1,
        "nickname": 1
    }
)
characters_df = pandas.DataFrame(list(characters))

# %%
# Convert "Not a number" to None
#
characters_df = characters_df.replace({numpy.nan: None})

# %%
characters_df
# Out:
#            characterName         actorName         actorLink  houseName royal  \
# 0         Addam Marbrand         B.J. Hogg  /name/nm0389698/       None  None
# 1        Aegon Targaryen              None              None  Targaryen  True
# 2          Aeron Greyjoy     Michael Feast  /name/nm0269923/    Greyjoy  None
# 3     Aerys II Targaryen     David Rintoul  /name/nm0727778/  Targaryen  True
# 4                   Akho        Chuku Modu  /name/nm6729880/       None  None
# ..                   ...               ...               ...        ...   ...
# 384            Young Nan   Annette Tierney  /name/nm1519719/       None  None
# 385            Young Ned    Robert Aramayo  /name/nm7075019/      Stark  None
# 386      Young Ned Stark   Sebastian Croft  /name/nm7509185/      Stark  None
# 387  Young Rodrik Cassel    Fergus Leathem  /name/nm7509186/       None  None
# 388              Zanrush  Gerald Lepkowski  /name/nm0503319/       None  None
#
#          nickname kingsguard
# 0            None       None
# 1            None       None
# 2        Damphair       None
# 3    The Mad King       None
# 4            None       None
# ..            ...        ...
# 384          None       None
# 385          None       None
# 386          None       None
# 387          None       None
# 388          None       None
#
# [389 rows x 7 columns]

# %% [markdown]
# ## Neo4j Aura

# %%
characters_dict = characters_df.to_dict(orient="records")

# %%
characters_dict
# Out:
# [{'characterName': 'Addam Marbrand',
#   'actorName': 'B.J. Hogg',
#   'actorLink': '/name/nm0389698/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Aegon Targaryen',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Aeron Greyjoy',
#   'actorName': 'Michael Feast',
#   'actorLink': '/name/nm0269923/',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': 'Damphair',
#   'kingsguard': None},
#  {'characterName': 'Aerys II Targaryen',
#   'actorName': 'David Rintoul',
#   'actorLink': '/name/nm0727778/',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': 'The Mad King',
#   'kingsguard': None},
#  {'characterName': 'Akho',
#   'actorName': 'Chuku Modu',
#   'actorLink': '/name/nm6729880/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Alliser Thorne',
#   'actorName': 'Owen Teale',
#   'actorLink': '/name/nm0853583/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Alton Lannister',
#   'actorName': 'Karl Davies',
#   'actorLink': '/name/nm0203801/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Alys Karstark',
#   'actorName': 'Megan Parkinson',
#   'actorLink': '/name/nm8257864/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Amory Lorch',
#   'actorName': 'Fintan McKeown',
#   'actorLink': '/name/nm0571654/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Anguy',
#   'actorName': 'Philip McGinley',
#   'actorLink': '/name/nm1528121/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Archmaester Marwyn',
#   'actorName': 'Jim Broadbent',
#   'actorLink': '/name/nm0000980/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Areo Hotah',
#   'actorName': 'Deobia Oparei',
#   'actorLink': '/name/nm0649046/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Armeca',
#   'actorName': 'Sahara Knite',
#   'actorLink': '/name/nm1783582/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Arthur',
#   'actorName': 'Nathanael Saleh',
#   'actorLink': '/name/nm8127149/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Arthur Dayne',
#   'actorName': 'Luke Roberts',
#   'actorLink': '/name/nm1074361/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Arya Stark',
#   'actorName': 'Maisie Williams',
#   'actorLink': '/name/nm3586035/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Baby Sam',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Balon Greyjoy',
#   'actorName': 'Patrick Malahide',
#   'actorLink': '/name/nm0538869/',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Baratheon Guard',
#   'actorName': 'Phil Barnhill',
#   'actorLink': '/name/nm4207240/',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Barristan Selmy',
#   'actorName': 'Ian McElhinney',
#   'actorLink': '/name/nm0568400/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Benjen Stark',
#   'actorName': 'Joseph Mawle',
#   'actorLink': '/name/nm1152798/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Beric Dondarrion',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bianca',
#   'actorName': 'Eline Powell',
#   'actorLink': '/name/nm4730958/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Biter',
#   'actorName': 'Gerard Jordan',
#   'actorLink': '/name/nm0429956/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Black Lorren',
#   'actorName': 'Forbes KB',
#   'actorLink': '/name/nm1978998/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Black Walder Rivers',
#   'actorName': 'Tim Plester',
#   'actorLink': '/name/nm1043031/',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bobono',
#   'actorName': 'Leigh Gill',
#   'actorLink': '/name/nm5279916/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bowen Marsh',
#   'actorName': 'Michael Condron',
#   'actorLink': '/name/nm1638006/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brandon Stark',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bran Stark',
#   'actorName': 'Isaac Hempstead Wright',
#   'actorLink': '/name/nm3652842/',
#   'houseName': 'Stark',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brea',
#   'actorName': 'Gemita Samarra',
#   'actorLink': '/name/nm5106314/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brienne of Tarth',
#   'actorName': 'Gwendoline Christie',
#   'actorLink': '/name/nm3729225/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Bronn',
#   'actorName': 'Jerome Flynn',
#   'actorLink': '/name/nm0283492/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brother Ray',
#   'actorName': 'Ian McShane',
#   'actorLink': '/name/nm0574534/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brynden Tully',
#   'actorName': 'Clive Russell',
#   'actorLink': '/name/nm0751085/',
#   'houseName': 'Tully',
#   'royal': None,
#   'nickname': 'Blackfish',
#   'kingsguard': None},
#  {'characterName': 'Captain of the Archers',
#   'actorName': 'Michael Grennell',
#   'actorLink': '/name/nm1214477/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Catelyn Stark',
#   'actorName': 'Michelle Fairley',
#   'actorLink': '/name/nm0265610/',
#   'houseName': ['Stark', 'Tully'],
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Catspaw Assassin',
#   'actorName': 'Lalor Roddy',
#   'actorLink': '/name/nm0734498/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Cersei Lannister',
#   'actorName': 'Lena Headey',
#   'actorLink': '/name/nm0372176/',
#   'houseName': ['Lannister', 'Baratheon'],
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Child of the Forest',
#   'actorName': 'Alice Hewkin',
#   'actorLink': '/name/nm2456829/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Citadel Maester',
#   'actorName': 'Frank Hvam',
#   'actorLink': '/name/nm0404809/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Colen of Greenpools',
#   'actorName': 'Darren Killeen',
#   'actorLink': '/name/nm4007028/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Craster',
#   'actorName': 'Robert Pugh',
#   'actorLink': '/name/nm0700059/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Daario Naharis',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Daenerys Targaryen',
#   'actorName': 'Emilia Clarke',
#   'actorLink': '/name/nm3592338/',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dagmer Cleftjaw',
#   'actorName': 'Ralph Ineson',
#   'actorLink': '/name/nm0408591/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Daisy',
#   'actorName': 'Maisie Dee',
#   'actorLink': '/name/nm3996678/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Davos Seaworth',
#   'actorName': 'Liam Cunningham',
#   'actorLink': '/name/nm0192377/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dickon Tarly',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dongo the Giant',
#   'actorName': 'Ian Whyte',
#   'actorLink': '/name/nm1613839/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Donnel Waynwood',
#   'actorName': 'Alisdair Simpson',
#   'actorLink': '/name/nm1368037/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dontos Hollard',
#   'actorName': 'Tony Way',
#   'actorLink': '/name/nm0915453/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Doran Martell',
#   'actorName': 'Alexander Siddig',
#   'actorLink': '/name/nm0796502/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Doreah',
#   'actorName': 'Roxanne McKee',
#   'actorLink': '/name/nm1861467/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dothraki Bloodrider #1',
#   'actorName': 'Diogo Sales',
#   'actorLink': '/name/nm6088160/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dothraki Bloodrider #2',
#   'actorName': 'Junade Khan',
#   'actorLink': '/name/nm2999602/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Drennan',
#   'actorName': 'David Coakley',
#   'actorLink': '/name/nm2231505/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Drogon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Drowned Priest',
#   'actorName': 'Jonathan Ryan',
#   'actorLink': '/name/nm0752638/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Eddard Stark',
#   'actorName': 'Sean Bean',
#   'actorLink': '/name/nm0000293/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': 'Ned',
#   'kingsguard': None},
#  {'characterName': 'Eddison Tollett',
#   'actorName': 'Ben Crompton',
#   'actorLink': '/name/nm0174005/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Edmure Tully',
#   'actorName': 'Tobias Menzies',
#   'actorLink': '/name/nm0580014/',
#   'houseName': 'Tully',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ellaria Sand',
#   'actorName': 'Indira Varma',
#   'actorLink': '/name/nm0890055/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Elia Martell',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Martell',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Eon Hunter',
#   'actorName': 'Barrington Cullen',
#   'actorLink': '/name/nm4473207/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Euron Greyjoy',
#   'actorName': 'Pilou Asbæk',
#   'actorLink': '/name/nm1561982/',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Faceless Man',
#   'actorName': 'Cedric Henderson',
#   'actorLink': '/name/nm2406775/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Farlen',
#   'actorName': 'Peter Ballance',
#   'actorLink': '/name/nm0050520/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gared',
#   'actorName': 'Dermot Keaney',
#   'actorLink': '/name/nm0443825/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gatins',
#   'actorName': 'Ricky Champ',
#   'actorLink': '/name/nm2307468/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gendry',
#   'actorName': 'Joe Dempsie',
#   'actorLink': '/name/nm1478079/',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gerold Hightower',
#   'actorName': 'Eddie Eyre',
#   'actorLink': '/name/nm6793798/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ghost',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gilly',
#   'actorName': 'Hannah Murray',
#   'actorLink': '/name/nm2356940/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak',
#   'actorName': 'Alan Paris',
#   'actorLink': '/name/nm3354768/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak',
#   'actorName': 'Sam Callis',
#   'actorLink': '/name/nm0130538/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak #1',
#   'actorName': 'Nikovich Sammut',
#   'actorLink': '/name/nm2089809/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak #2',
#   'actorName': 'Seamus Kelly',
#   'actorLink': '/name/nm4440118/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grand Maester Pycelle',
#   'actorName': 'Julian Glover',
#   'actorLink': '/name/nm0002103/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #1',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #2',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #3',
#   'actorName': 'Peter Silverleaf',
#   'actorLink': '/name/nm0798872/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #4',
#   'actorName': 'Davor Jozinovic',
#   'actorLink': '/name/nm7318132/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #5',
#   'actorName': 'Ivan Peric',
#   'actorLink': '/name/nm3005802/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #6',
#   'actorName': 'Hadi Kermani',
#   'actorLink': '/name/nm7318134/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #7',
#   'actorName': 'Tonci Banov',
#   'actorLink': '/name/nm7318135/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Greatjon Umber',
#   'actorName': 'Clive Mantle',
#   'actorLink': '/name/nm0544139/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gregor Clegane',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': 'The Mountain',
#   'kingsguard': None},
#  {'characterName': 'Greizhen mo Ullhor',
#   'actorName': 'Cliff Barry',
#   'actorLink': '/name/nm0057965/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grenn',
#   'actorName': 'Mark Stanley',
#   'actorLink': '/name/nm4440305/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grey Wind',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grey Worm',
#   'actorName': 'Jacob Anderson',
#   'actorLink': '/name/nm2760664/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hallyne',
#   'actorName': 'Roy Dotrice',
#   'actorLink': '/name/nm0234541/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Handmaid',
#   'actorName': 'Sabrina Bartlett',
#   'actorLink': '/name/nm6301068/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Handmaid',
#   'actorName': 'Sara Dylan',
#   'actorLink': '/name/nm2407387/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Harald Karstark',
#   'actorName': 'Paul Rattray',
#   'actorLink': '/name/nm1051151/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Harry Strickland',
#   'actorName': 'Marc Rissmann',
#   'actorLink': '/name/nm4704928/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Priestess',
#   'actorName': 'Souad Faress',
#   'actorLink': '/name/nm0267256/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Septon',
#   'actorName': 'David Verrey',
#   'actorLink': '/name/nm0894857/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Septon',
#   'actorName': 'Paul Bentley',
#   'actorLink': '/name/nm0072855/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Sparrow',
#   'actorName': 'Jonathan Pryce',
#   'actorLink': '/name/nm0000596/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hizdahr zo Loraq',
#   'actorName': 'Joel Fry',
#   'actorLink': '/name/nm2181128/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hodor',
#   'actorName': 'Kristian Nairn',
#   'actorLink': '/name/nm3964231/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hoster Tully',
#   'actorName': 'Christopher Newman',
#   'actorLink': '/name/nm0628040/',
#   'houseName': 'Tully',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hot Pie',
#   'actorName': 'Ben Hawkey',
#   'actorLink': '/name/nm3444954/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Howland Reed',
#   'actorName': 'Leo Woodruff',
#   'actorLink': '/name/nm4547262/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hugh of the Vale',
#   'actorName': 'Jefferson Hall',
#   'actorLink': '/name/nm2131630/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Illyrio Mopatis',
#   'actorName': 'Roger Allam',
#   'actorLink': '/name/nm0019885/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ilyn Payne',
#   'actorName': 'Wilko Johnson',
#   'actorLink': '/name/nm3330122/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Irri',
#   'actorName': 'Amrita Acharia',
#   'actorLink': '/name/nm3822505/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Izembaro',
#   'actorName': 'Richard E. Grant',
#   'actorLink': '/name/nm0001290/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jacks',
#   'actorName': 'Paul Caddell',
#   'actorLink': '/name/nm4781280/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jafer Flowers',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jaime Lannister',
#   'actorName': 'Nikolaj Coster-Waldau',
#   'actorLink': '/name/nm0182666/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': 'The Kingslayer',
#   'kingsguard': True},
#  {'characterName': 'Janos Slynt',
#   'actorName': 'Dominic Carter',
#   'actorLink': '/name/nm0141582/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Jaqen H'ghar",
#   'actorName': 'Tom Wlaschiha',
#   'actorLink': '/name/nm0937239/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Jaqen's Disguise",
#   'actorName': "Patrick O'Kane",
#   'actorLink': '/name/nm0641433/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jaremy Rykker',
#   'actorName': "Jeffrey O'Brien",
#   'actorLink': '/name/nm4475335/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jeor Mormont',
#   'actorName': 'James Cosmo',
#   'actorLink': '/name/nm0181920/',
#   'houseName': 'Mormont',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jhiqui',
#   'actorName': 'Sarita Piotrowski',
#   'actorLink': '/name/nm4424689/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Joffrey Baratheon',
#   'actorName': 'Jack Gleeson',
#   'actorLink': '/name/nm0322416/',
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jojen Reed',
#   'actorName': 'Thomas Brodie-Sangster',
#   'actorLink': '/name/nm1032473/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jon Arryn',
#   'actorName': 'John Standing',
#   'actorLink': '/name/nm0822062/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jon Snow',
#   'actorName': 'Kit Harington',
#   'actorLink': '/name/nm3229685/',
#   'houseName': ['Stark', 'Targaryen'],
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jonos Bracken',
#   'actorName': "Gerry O'Brien",
#   'actorLink': '/name/nm0639569/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jorah Mormont',
#   'actorName': 'Iain Glen',
#   'actorLink': '/name/nm0322513/',
#   'houseName': 'Mormont',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jory Cassel',
#   'actorName': 'Jamie Sives',
#   'actorLink': '/name/nm0803397/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Joyeuse Erenford',
#   'actorName': 'Kelly Long',
#   'actorLink': '/name/nm4958677/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Karl Tanner',
#   'actorName': 'Burn Gorman',
#   'actorLink': '/name/nm1218607/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Karsi',
#   'actorName': 'Birgitte Hjort Sørensen',
#   'actorLink': '/name/nm2171898/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kayla',
#   'actorName': 'Pixie Le Knot',
#   'actorLink': '/name/nm4768858/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kegs',
#   'actorName': 'Tim Landers',
#   'actorLink': '/name/nm2461009/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kevan Lannister',
#   'actorName': 'Ian Gelder',
#   'actorLink': '/name/nm0312245/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Khal Drogo',
#   'actorName': 'Jason Momoa',
#   'actorLink': '/name/nm0597388/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Khal Moro',
#   'actorName': 'Joseph Naufahu',
#   'actorLink': '/name/nm0622533/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Khal Rhalko',
#   'actorName': 'Andrei Claude',
#   'actorLink': '/name/nm3040811/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Joffrey Baratheon Dwarf',
#   'actorName': 'Raymond Griffiths',
#   'actorLink': '/name/nm0341739/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Renly Baratheon Dwarf',
#   'actorName': 'Dean Whatton',
#   'actorLink': '/name/nm2482781/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Robb Stark Dwarf',
#   'actorName': 'George Appleby',
#   'actorLink': '/name/nm3338062/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Stannis Baratheon Dwarf',
#   'actorName': 'Maxwell Laird',
#   'actorLink': '/name/nm3453345/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "King's Landing Rioter #1",
#   'actorName': 'Reg Wayment',
#   'actorLink': '/name/nm1168404/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "King's Landing Rioter #2",
#   'actorName': 'Marko Juraga',
#   'actorLink': '/name/nm0432837/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "King's Landing Rioter #3",
#   'actorName': 'Rea Separovic',
#   'actorLink': '/name/nm5037688/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kinvara',
#   'actorName': 'Ania Bukstein',
#   'actorLink': '/name/nm0119804/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kitty Frey',
#   'actorName': 'Lucy Hayes',
#   'actorLink': '/name/nm8314450/',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Knight of House Frey',
#   'actorName': 'Patrick Ryan',
#   'actorLink': '/name/nm3122423/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Knight of House Lynderly',
#   'actorName': 'Paddy Rocks',
#   'actorLink': '/name/nm0734304/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kovarro',
#   'actorName': 'Steven Cole',
#   'actorLink': '/name/nm0170799/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kraznys mo Nakloz',
#   'actorName': 'Dan Hildebrand',
#   'actorLink': '/name/nm0383835/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kurleket',
#   'actorName': 'Kevin Keenan',
#   'actorLink': '/name/nm4450657/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lady',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lady Crane',
#   'actorName': 'Essie Davis',
#   'actorLink': '/name/nm0204583/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lancel Lannister',
#   'actorName': 'Eugene Simon',
#   'actorLink': '/name/nm1638294/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Captain',
#   'actorName': 'Aiden Condron',
#   'actorLink': '/name/nm0174449/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Captain',
#   'actorName': 'Richard Laing',
#   'actorLink': '/name/nm0481924/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Guardsman',
#   'actorName': 'Conor Delaney',
#   'actorLink': '/name/nm1406364/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Messenger',
#   'actorName': 'Simon Stewart',
#   'actorLink': '/name/nm4492930/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Scout',
#   'actorName': 'Chris Gallagher',
#   'actorLink': '/name/nm3292422/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lead Dornish Guard',
#   'actorName': 'Christian Vit',
#   'actorLink': '/name/nm5908524/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Leaf',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lem Lemoncloak',
#   'actorName': 'Jóhannes Haukur Jóhannesson',
#   'actorLink': '/name/nm1778512/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Leo Lefford',
#   'actorName': 'Vinnie McCabe',
#   'actorLink': '/name/nm0564516/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lhara',
#   'actorName': 'Sarine Sofair',
#   'actorLink': '/name/nm3330066/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird',
#   'actorName': 'Samuel Paul Small',
#   'actorLink': '/name/nm6537691/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird',
#   'actorName': 'Tristan Mercieca',
#   'actorLink': '/name/nm4475204/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #3',
#   'actorName': 'Michael Nevin',
#   'actorLink': '/name/nm8127150/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #4',
#   'actorName': 'Jesse Magee',
#   'actorLink': '/name/nm8127151/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #5',
#   'actorName': 'Iona Clarke',
#   'actorLink': '/name/nm8133415/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #6',
#   'actorName': 'Lucy Gallagher',
#   'actorLink': '/name/nm8127152/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #7',
#   'actorName': 'Fionn Kernan',
#   'actorLink': '/name/nm6462692/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Loboda',
#   'actorName': 'Zachary Baharov',
#   'actorLink': '/name/nm1707712/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Locke',
#   'actorName': 'Noah Taylor',
#   'actorLink': '/name/nm0852965/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lollys Stokeworth',
#   'actorName': 'Elizabeth Cadwallader',
#   'actorLink': '/name/nm5502252/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lommy Greenhands',
#   'actorName': 'Eros Vlahos',
#   'actorLink': '/name/nm2869309/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Loras Tyrell',
#   'actorName': 'Finn Jones',
#   'actorLink': '/name/nm3645691/',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lord Galbart Glover',
#   'actorName': 'Mark Coney',
#   'actorLink': '/name/nm5651524/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lord Portan',
#   'actorName': 'Gordon Fulton',
#   'actorLink': '/name/nm1101680/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lord Varys',
#   'actorName': 'Conleth Hill',
#   'actorLink': '/name/nm0384152/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lordsport Dockhand',
#   'actorName': "Jer O'Leary",
#   'actorLink': '/name/nm0641596/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lothar Frey',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Loyal Night's Watchman #1",
#   'actorName': 'Steve Cash',
#   'actorLink': '/name/nm3524836/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Loyal Night's Watchman #2",
#   'actorName': 'Robert Fawsitt',
#   'actorLink': '/name/nm6342915/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lyanna Mormont',
#   'actorName': 'Bella Ramsey',
#   'actorLink': '/name/nm8165602/',
#   'houseName': 'Mormont',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lyanna Stark',
#   'actorName': 'Aisling Franciosi',
#   'actorLink': '/name/nm4957233/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lysa Arryn',
#   'actorName': 'Kate Dickie',
#   'actorLink': '/name/nm0225483/',
#   'houseName': ['Arryn', 'Tully'],
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mace Tyrell',
#   'actorName': 'Roger Ashton-Griffiths',
#   'actorLink': '/name/nm0004355/',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Aemon',
#   'actorName': 'Peter Vaughan',
#   'actorLink': '/name/nm0891092/',
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Cressen',
#   'actorName': 'Oliver Ford Davies',
#   'actorLink': '/name/nm0203882/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Luwin',
#   'actorName': 'Donald Sumpter',
#   'actorLink': '/name/nm0838910/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Wolkan',
#   'actorName': 'Richard Rycroft',
#   'actorLink': '/name/nm1483416/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mag the Mighty',
#   'actorName': 'Neil Fingleton',
#   'actorLink': '/name/nm2807170/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maggy',
#   'actorName': 'Jodhi May',
#   'actorLink': '/name/nm0562003/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mago',
#   'actorName': 'Ivailo Dimitrov',
#   'actorLink': '/name/nm2162079/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Male Prostitute',
#   'actorName': 'Dennis Stokes',
#   'actorLink': '/name/nm4982614/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Malko',
#   'actorName': 'Adewale Akinnuoye-Agbaje',
#   'actorLink': '/name/nm0015382/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mance Rayder',
#   'actorName': 'Ciarán Hinds',
#   'actorLink': '/name/nm0001354/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mandon Moore',
#   'actorName': 'James Doran',
#   'actorLink': '/name/nm0243696/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Manservant',
#   'actorName': 'Conor Watters',
#   'actorLink': '/name/nm6442298/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Marei',
#   'actorName': 'Josephine Gillan',
#   'actorLink': '/name/nm4982706/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Margaery Tyrell',
#   'actorName': 'Natalie Dormer',
#   'actorLink': '/name/nm1754059/',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Margaery's Handmaiden",
#   'actorName': 'Aisling Jarrett-Gavin',
#   'actorLink': '/name/nm2983094/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Marillion',
#   'actorName': 'Emun Elliott',
#   'actorLink': '/name/nm2047170/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Martyn Lannister',
#   'actorName': 'Dean-Charles Chapman',
#   'actorLink': '/name/nm2835616/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Masha Heddle',
#   'actorName': 'Susie Kelly',
#   'actorLink': '/name/nm3126053/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Matthos Seaworth',
#   'actorName': 'Kerr Logan',
#   'actorLink': '/name/nm4523680/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Meera Reed',
#   'actorName': 'Ellie Kendrick',
#   'actorLink': '/name/nm1697771/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Meereen Slave Master',
#   'actorName': 'Laurence Doherty',
#   'actorLink': '/name/nm2911170/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Melessa Tarly',
#   'actorName': 'Samantha Spiro',
#   'actorLink': '/name/nm0819087/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Melisandre',
#   'actorName': 'Carice van Houten',
#   'actorLink': '/name/nm0396924/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Merchant Captain',
#   'actorName': 'Gary Pillai',
#   'actorLink': '/name/nm0997747/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mero',
#   'actorName': 'Mark Killeen',
#   'actorLink': '/name/nm2075330/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Meryn Trant',
#   'actorName': 'Ian Beattie',
#   'actorLink': '/name/nm0064155/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mhaegen',
#   'actorName': 'Antonia Christophers',
#   'actorLink': '/name/nm4460936/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mikken',
#   'actorName': 'Boyd Rankin',
#   'actorLink': '/name/nm4595425/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mirelle',
#   'actorName': 'Elisa Lasowski',
#   'actorLink': '/name/nm2489799/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mirri Maz Duur',
#   'actorName': 'Mia Soteriou',
#   'actorLink': '/name/nm0815420/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Missandei',
#   'actorName': 'Nathalie Emmanuel',
#   'actorLink': '/name/nm2812026/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mord',
#   'actorName': 'Ciaran Bermingham',
#   'actorLink': '/name/nm2197118/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mossador',
#   'actorName': 'Reece Noi',
#   'actorLink': '/name/nm0634139/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #1',
#   'actorName': 'Nanna Bryndís Hilmarsdóttir',
#   'actorLink': '/name/nm5652293/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #1',
#   'actorName': 'Jon Thor Birgisson',
#   'actorLink': '/name/nm1743706/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #2',
#   'actorName': 'Ragnar Þórhallsson',
#   'actorLink': '/name/nm5652121/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #2',
#   'actorName': 'Orri P. Dyrason',
#   'actorLink': '/name/nm1743714/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #3',
#   'actorName': 'Georg Holm',
#   'actorLink': '/name/nm1743730/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #3',
#   'actorName': 'Arnar Rosenkranz Hilmarsson',
#   'actorLink': '/name/nm8158202/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #4',
#   'actorName': 'Brynjar Leifsson',
#   'actorLink': '/name/nm8158203/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #5',
#   'actorName': 'Kristján Kristjánsson',
#   'actorLink': '/name/nm1944894/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mycah',
#   'actorName': 'Rhodri Hosking',
#   'actorLink': '/name/nm4430905/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Myranda',
#   'actorName': 'Charlotte Hope',
#   'actorLink': '/name/nm3745225/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Myrcella Baratheon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ned Umber',
#   'actorName': 'Harry Grasby',
#   'actorLink': '/name/nm9132255/',
#   'houseName': 'Umber',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Deserter",
#   'actorName': "Barry John O'Connor",
#   'actorLink': '/name/nm3226454/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Messenger",
#   'actorName': "Frank O'Sullivan",
#   'actorLink': '/name/nm0642751/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Officer",
#   'actorName': 'Dennis McKeever',
#   'actorLink': '/name/nm4475182/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Officer",
#   'actorName': 'Michael Stuart',
#   'actorLink': '/name/nm5792452/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman",
#   'actorName': 'Marcus Lamb',
#   'actorLink': '/name/nm2228622/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman",
#   'actorName': 'Michael Hooley',
#   'actorLink': '/name/nm6706699/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman",
#   'actorName': 'Patrick J Molloy',
#   'actorLink': '/name/nm3561455/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman #1",
#   'actorName': 'Michael Hayes',
#   'actorLink': '/name/nm0371160/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman #2",
#   'actorName': 'Ruairí Heading',
#   'actorLink': '/name/nm6316115/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman #2",
#   'actorName': 'Tony Flynn',
#   'actorLink': '/name/nm0283642/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Northman Rioter',
#   'actorName': 'Jed Murray',
#   'actorLink': '/name/nm5697839/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Nymeria',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Nymeria Sand',
#   'actorName': 'Jessica Henwick',
#   'actorLink': '/name/nm3725055/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Obara Sand',
#   'actorName': 'Keisha Castle-Hughes',
#   'actorLink': '/name/nm1095720/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Oberyn Martell',
#   'actorName': 'Pedro Pascal',
#   'actorLink': '/name/nm0050959/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Old Nan',
#   'actorName': 'Margaret John',
#   'actorLink': '/name/nm0424191/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Old Woman Prisoner',
#   'actorName': 'Gina Moxley',
#   'actorLink': '/name/nm0610312/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Olenna Tyrell',
#   'actorName': 'Diana Rigg',
#   'actorLink': '/name/nm0001671/',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Olly',
#   'actorName': "Brenock O'Connor",
#   'actorLink': '/name/nm5282143/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Olyvar',
#   'actorName': 'Will Tudor',
#   'actorLink': '/name/nm4831584/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Orell',
#   'actorName': 'Mackenzie Crook',
#   'actorLink': '/name/nm0188871/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ornela',
#   'actorName': 'Hannah John-Kamen',
#   'actorLink': '/name/nm4789912/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Osha',
#   'actorName': 'Natalia Tena',
#   'actorLink': '/name/nm1164730/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Othell Yarwyck',
#   'actorName': 'Brian Fortune',
#   'actorLink': '/name/nm1987270/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Othor',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Pentoshi Servant',
#   'actorName': 'Rania Zouari',
#   'actorLink': '/name/nm4422639/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Petyr Baelish',
#   'actorName': 'Aidan Gillen',
#   'actorLink': '/name/nm0318821/',
#   'houseName': None,
#   'royal': None,
#   'nickname': 'Littlefinger',
#   'kingsguard': None},
#  {'characterName': 'Podrick Payne',
#   'actorName': 'Daniel Portman',
#   'actorLink': '/name/nm4535552/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Polliver',
#   'actorName': 'Andy Kellegher',
#   'actorLink': '/name/nm3464945/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Prendahl na Ghezn',
#   'actorName': 'Ramon Tikaram',
#   'actorLink': '/name/nm0863130/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Pyat Pree',
#   'actorName': 'Ian Hanmore',
#   'actorLink': '/name/nm0360171/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
# ...
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Moelle',
#   'actorName': 'Maggie Hayes',
#   'actorLink': '/name/nm1378629/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Mordane',
#   'actorName': 'Susan Brown',
#   'actorLink': '/name/nm0114742/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Scolera',
#   'actorName': 'Mary Jordan',
#   'actorLink': '/name/nm1103771/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Unella',
#   'actorName': 'Hannah Waddingham',
#   'actorLink': '/name/nm1821446/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septon',
#   'actorName': 'Kenneth Hadley',
#   'actorLink': '/name/nm0352901/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septon',
#   'actorName': 'Terry Byrne',
#   'actorLink': '/name/nm0126298/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ser Endrew Tarth',
#   'actorName': 'Dez McMahon',
#   'actorLink': '/name/nm4757478/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shae',
#   'actorName': 'Sibel Kekilli',
#   'actorLink': '/name/nm1402546/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shagga',
#   'actorName': 'Mark Lewis Jones',
#   'actorLink': '/name/nm0428765/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shaggydog',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shireen Baratheon',
#   'actorName': 'Kerry Ingram',
#   'actorLink': '/name/nm5081192/',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Silk King',
#   'actorName': 'Slavko Juraga',
#   'actorLink': '/name/nm0432838/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Smalljon Umber',
#   'actorName': 'Dean S. Jagger',
#   'actorLink': '/name/nm2746504/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Spice King',
#   'actorName': 'Nicholas Blane',
#   'actorLink': '/name/nm0087432/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stannis Baratheon',
#   'actorName': 'Stephen Dillane',
#   'actorLink': '/name/nm0226820/',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Bannerman',
#   'actorName': 'Michael Stuart',
#   'actorLink': '/name/nm5792452/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'actorName': 'Faolan Morgan',
#   'actorLink': '/name/nm4335246/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'actorName': 'Rick Burn',
#   'actorLink': '/name/nm4492916/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'actorName': 'David Sheehan',
#   'actorLink': '/name/nm1423916/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'actorName': 'Paul Monahan',
#   'actorLink': '/name/nm5981376/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Steelshanks Walton',
#   'actorName': 'Jamie Michie',
#   'actorLink': '/name/nm1652341/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stevron Frey',
#   'actorName': 'Colin Carnegie',
#   'actorLink': '/name/nm1794801/',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stiv',
#   'actorName': 'Stephen Don',
#   'actorLink': '/name/nm1651043/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Styr',
#   'actorName': 'Yuri Kolokolnikov',
#   'actorLink': '/name/nm0464305/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Summer',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Syrio Forel',
#   'actorName': 'Miltos Yerolemou',
#   'actorLink': '/name/nm1115654/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Talisa Maegyr',
#   'actorName': 'Oona Chaplin',
#   'actorLink': '/name/nm2772105/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Talla Tarly',
#   'actorName': 'Rebecca Benson',
#   'actorLink': '/name/nm5039410/',
#   'houseName': 'Tarly',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ternesio Terys',
#   'actorName': 'Gary Oliver',
#   'actorLink': '/name/nm1146807/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Bear',
#   'actorName': 'Bart the Bear',
#   'actorLink': '/name/nm1212069/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Night King',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Tickler',
#   'actorName': 'Anthony Morris',
#   'actorLink': '/name/nm1677757/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Waif',
#   'actorName': 'Faye Marsay',
#   'actorLink': '/name/nm3849670/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Thenn Warg',
#   'actorName': 'Joseph Gatt',
#   'actorLink': '/name/nm1395532/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Theon Greyjoy',
#   'actorName': 'Alfie Allen',
#   'actorLink': '/name/nm0654295/',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Thin Man',
#   'actorName': 'Oengus MacNamara',
#   'actorLink': '/name/nm0534062/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Thoros of Myr',
#   'actorName': 'Paul Kaye',
#   'actorLink': '/name/nm0443373/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Three-Eyed Raven',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Timett',
#   'actorName': 'Tobias Winter',
#   'actorLink': '/name/nm4385245/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tobho Mott',
#   'actorName': 'Andrew Wilde',
#   'actorLink': '/name/nm0928408/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Todder',
#   'actorName': "Will O'Connell",
#   'actorLink': '/name/nm3727276/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tomard',
#   'actorName': 'Phil Dixon',
#   'actorLink': '/name/nm4475303/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tommen Baratheon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tormund Giantsbane',
#   'actorName': 'Kristofer Hivju',
#   'actorLink': '/name/nm1970465/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Trystane Martell',
#   'actorName': 'Toby Sebastian',
#   'actorLink': '/name/nm4514519/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tycho Nestoris',
#   'actorName': 'Mark Gatiss',
#   'actorLink': '/name/nm0309693/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tyene Sand',
#   'actorName': 'Rosabell Laurenti Sellers',
#   'actorLink': '/name/nm3065809/',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tyrion Lannister',
#   'actorName': 'Peter Dinklage',
#   'actorLink': '/name/nm0227759/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tywin Lannister',
#   'actorName': 'Charles Dance',
#   'actorLink': '/name/nm0001097/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Vala',
#   'actorName': 'Meena Rayann',
#   'actorLink': '/name/nm5159884/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Vardis Egen',
#   'actorName': 'Brendan McCormack',
#   'actorLink': '/name/nm1788152/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Varly',
#   'actorName': 'Graham Charles',
#   'actorLink': '/name/nm1378721/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Viserion',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Viserys Targaryen',
#   'actorName': 'Harry Lloyd',
#   'actorLink': '/name/nm0516003/',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Walda Bolton',
#   'actorName': 'Elizabeth Webster',
#   'actorLink': '/name/nm3531913/',
#   'houseName': ['Bolton', 'Frey'],
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Walder Frey',
#   'actorName': 'David Bradley',
#   'actorLink': '/name/nm0103195/',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wallen',
#   'actorName': "Barry O'Connor",
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Warlock',
#   'actorName': 'Lottie Steer',
#   'actorLink': '/name/nm5390029/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Waymar Royce',
#   'actorName': 'Rob Ostlere',
#   'actorLink': '/name/nm3209935/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wedding Band',
#   'actorName': 'Sigur Rós',
#   'actorLink': '/name/nm1460176/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker',
#   'actorName': 'Ian Whyte',
#   'actorLink': '/name/nm1613839/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker',
#   'actorName': 'Ross Mullan',
#   'actorLink': '/name/nm1368643/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker',
#   'actorName': 'Tim Loane',
#   'actorLink': '/name/nm0516385/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker #2',
#   'actorName': 'Spencer Wilding',
#   'actorLink': '/name/nm1872855/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wight Wildling Girl',
#   'actorName': 'Claire Wright',
#   'actorLink': '/name/nm4422708/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wildling Rioter',
#   'actorName': 'Michael Patrick',
#   'actorLink': '/name/nm8199963/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Will',
#   'actorName': 'Bronson Webb',
#   'actorLink': '/name/nm0916037/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Willem Lannister',
#   'actorName': 'Timothy Gibbons',
#   'actorLink': '/name/nm5624523/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Willis Wode',
#   'actorName': 'Ryan McKenna',
#   'actorLink': '/name/nm4416560/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wine Merchant',
#   'actorName': 'Simon Lowe',
#   'actorLink': '/name/nm0523047/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Winterfell Shepherd',
#   'actorName': 'Donagh Deeney',
#   'actorLink': '/name/nm0214343/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wun Wun',
#   'actorName': 'Ian Whyte',
#   'actorLink': '/name/nm1613839/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wyllis',
#   'actorName': 'Sam Coleman',
#   'actorLink': '/name/nm4744043/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Xaro Xhoan Daxos',
#   'actorName': 'Nonso Anozie',
#   'actorLink': '/name/nm1996829/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yara Greyjoy',
#   'actorName': 'Gemma Whelan',
#   'actorLink': '/name/nm2247629/',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yezzan zo Qaggaz',
#   'actorName': 'Enzo Cilenti',
#   'actorLink': '/name/nm0162281/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ygritte',
#   'actorName': 'Rose Leslie',
#   'actorLink': '/name/nm3310211/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yohn Royce',
#   'actorName': 'Rupert Vansittart',
#   'actorLink': '/name/nm0889338/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yoren',
#   'actorName': 'Francis Magee',
#   'actorLink': '/name/nm0535837/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Benjen Stark',
#   'actorName': 'Matteo Elezi',
#   'actorLink': '/name/nm5502295/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Cersei Lannister',
#   'actorName': 'Nell Williams',
#   'actorLink': '/name/nm5309709/',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Lyanna Stark',
#   'actorName': 'Cordelia Hill',
#   'actorLink': '/name/nm8108764/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Nan',
#   'actorName': 'Annette Tierney',
#   'actorLink': '/name/nm1519719/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Ned',
#   'actorName': 'Robert Aramayo',
#   'actorLink': '/name/nm7075019/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Ned Stark',
#   'actorName': 'Sebastian Croft',
#   'actorLink': '/name/nm7509185/',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Rodrik Cassel',
#   'actorName': 'Fergus Leathem',
#   'actorLink': '/name/nm7509186/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Zanrush',
#   'actorName': 'Gerald Lepkowski',
#   'actorLink': '/name/nm0503319/',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None}]

# %%
actors_to_insert = []
characters_to_insert = []
relationships_to_insert = []

# %%
for c in characters_dict:

    next_actor = {}
    next_actor_name = c.get("actorName", None)
    next_actor_imdb_id = c.get("actorLink", None)

    next_character = copy.copy(c)

    if next_actor_name:
        next_actor["name"] = next_actor_name
        del next_character["actorName"]

        if next_actor_imdb_id:
            del next_character["actorLink"]
            fields = next_actor_imdb_id.split("/")
            next_actor_imdb_id = fields[2]
            next_actor["imdb_id"] = next_actor_imdb_id

            next_relationship = {"character": next_character["characterName"],
                                  "actor_id": next_actor["imdb_id"]
                                 }
            relationships_to_insert.append(next_relationship)

            actors_to_insert.append(next_actor)

    characters_to_insert.append(next_character)

# %%
characters_to_insert
# Out:
# [{'characterName': 'Addam Marbrand',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Aegon Targaryen',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Aeron Greyjoy',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': 'Damphair',
#   'kingsguard': None},
#  {'characterName': 'Aerys II Targaryen',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': 'The Mad King',
#   'kingsguard': None},
#  {'characterName': 'Akho',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Alliser Thorne',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Alton Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Alys Karstark',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Amory Lorch',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Anguy',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Archmaester Marwyn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Areo Hotah',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Armeca',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Arthur',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Arthur Dayne',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Arya Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Baby Sam',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Balon Greyjoy',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Baratheon Guard',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Barristan Selmy',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Benjen Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Beric Dondarrion',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bianca',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Biter',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Black Lorren',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Black Walder Rivers',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bobono',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bowen Marsh',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brandon Stark',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Bran Stark',
#   'houseName': 'Stark',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brea',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brienne of Tarth',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Bronn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brother Ray',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Brynden Tully',
#   'houseName': 'Tully',
#   'royal': None,
#   'nickname': 'Blackfish',
#   'kingsguard': None},
#  {'characterName': 'Captain of the Archers',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Catelyn Stark',
#   'houseName': ['Stark', 'Tully'],
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Catspaw Assassin',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Cersei Lannister',
#   'houseName': ['Lannister', 'Baratheon'],
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Child of the Forest',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Citadel Maester',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Colen of Greenpools',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Craster',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Daario Naharis',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Daenerys Targaryen',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dagmer Cleftjaw',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Daisy',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Davos Seaworth',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dickon Tarly',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dongo the Giant',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Donnel Waynwood',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dontos Hollard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Doran Martell',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Doreah',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dothraki Bloodrider #1',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Dothraki Bloodrider #2',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Drennan',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Drogon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Drowned Priest',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Eddard Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': 'Ned',
#   'kingsguard': None},
#  {'characterName': 'Eddison Tollett',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Edmure Tully',
#   'houseName': 'Tully',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ellaria Sand',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Elia Martell',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Martell',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Eon Hunter',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Euron Greyjoy',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Faceless Man',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Farlen',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gared',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gatins',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gendry',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gerold Hightower',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ghost',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gilly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak #1',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Goldcloak #2',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grand Maester Pycelle',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #1',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #2',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #3',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #4',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #5',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #6',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Great Master #7',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Greatjon Umber',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Gregor Clegane',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': 'The Mountain',
#   'kingsguard': None},
#  {'characterName': 'Greizhen mo Ullhor',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grenn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grey Wind',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Grey Worm',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hallyne',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Handmaid',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Handmaid',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Harald Karstark',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Harry Strickland',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Priestess',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Septon',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Septon',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'High Sparrow',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hizdahr zo Loraq',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hodor',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hoster Tully',
#   'houseName': 'Tully',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hot Pie',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Howland Reed',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Hugh of the Vale',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Illyrio Mopatis',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ilyn Payne',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Irri',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Izembaro',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jacks',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jafer Flowers',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jaime Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': 'The Kingslayer',
#   'kingsguard': True},
#  {'characterName': 'Janos Slynt',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Jaqen H'ghar",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Jaqen's Disguise",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jaremy Rykker',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jeor Mormont',
#   'houseName': 'Mormont',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jhiqui',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Joffrey Baratheon',
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jojen Reed',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jon Arryn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jon Snow',
#   'houseName': ['Stark', 'Targaryen'],
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jonos Bracken',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jorah Mormont',
#   'houseName': 'Mormont',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Jory Cassel',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Joyeuse Erenford',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Karl Tanner',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Karsi',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kayla',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kegs',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kevan Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Khal Drogo',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Khal Moro',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Khal Rhalko',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Joffrey Baratheon Dwarf',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Renly Baratheon Dwarf',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Robb Stark Dwarf',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'King Stannis Baratheon Dwarf',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "King's Landing Rioter #1",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "King's Landing Rioter #2",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "King's Landing Rioter #3",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kinvara',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kitty Frey',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Knight of House Frey',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Knight of House Lynderly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kovarro',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kraznys mo Nakloz',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Kurleket',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lady',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lady Crane',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lancel Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Captain',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Captain',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Guardsman',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Messenger',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lannister Scout',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lead Dornish Guard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Leaf',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lem Lemoncloak',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Leo Lefford',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lhara',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #3',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #4',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #5',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #6',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Little Bird #7',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Loboda',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Locke',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lollys Stokeworth',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lommy Greenhands',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Loras Tyrell',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lord Galbart Glover',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lord Portan',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lord Varys',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lordsport Dockhand',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lothar Frey',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Loyal Night's Watchman #1",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Loyal Night's Watchman #2",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lyanna Mormont',
#   'houseName': 'Mormont',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lyanna Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Lysa Arryn',
#   'houseName': ['Arryn', 'Tully'],
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mace Tyrell',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Aemon',
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Cressen',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Luwin',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maester Wolkan',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mag the Mighty',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Maggy',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mago',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Male Prostitute',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Malko',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mance Rayder',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mandon Moore',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Manservant',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Marei',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Margaery Tyrell',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Margaery's Handmaiden",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Marillion',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Martyn Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Masha Heddle',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Matthos Seaworth',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Meera Reed',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Meereen Slave Master',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Melessa Tarly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Melisandre',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Merchant Captain',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mero',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Meryn Trant',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mhaegen',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mikken',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mirelle',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mirri Maz Duur',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Missandei',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mord',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mossador',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #1',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #1',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #2',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #2',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #3',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #3',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #4',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Musician #5',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Mycah',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Myranda',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Myrcella Baratheon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ned Umber',
#   'houseName': 'Umber',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Deserter",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Messenger",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Officer",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watch Officer",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman #1",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman #2",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': "Night's Watchman #2",
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Northman Rioter',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Nymeria',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Nymeria Sand',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Obara Sand',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Oberyn Martell',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Old Nan',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Old Woman Prisoner',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Olenna Tyrell',
#   'houseName': 'Tyrell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Olly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Olyvar',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Orell',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ornela',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Osha',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Othell Yarwyck',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Othor',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Pentoshi Servant',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Petyr Baelish',
#   'houseName': None,
#   'royal': None,
#   'nickname': 'Littlefinger',
#   'kingsguard': None},
#  {'characterName': 'Podrick Payne',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': True},
#  {'characterName': 'Polliver',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Prendahl na Ghezn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Pyat Pree',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Pypar',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Qhono',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Qhorin Halfhand',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Qotho',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Quaithe',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Qyburn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rakharo',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ramsay Snow',
#   'houseName': 'Bolton',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Randyll Tarly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rast',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rattleshirt',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': 'Lord of Bones',
#   'kingsguard': None},
#  {'characterName': 'Razdal mo Eraz',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Red Keep Stableboy',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Red Priestess',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Red Priestess',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Renly Baratheon',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rhaegal',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rhaegar Targaryen',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rhaego',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rhaella Targaryen',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rhaenys Targaryen',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rickard Karstark',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rickard Stark',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rickon Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Robb Stark',
#   'houseName': 'Stark',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Robert Baratheon',
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Robett Glover',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Robin Arryn',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rodrik Cassel',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Roose Bolton',
#   'houseName': 'Bolton',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Rorge',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ros',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Roslin Frey',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Royal Steward',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ryger Rivers',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Salladhor Saan',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Samwell Tarly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Sandor Clegane',
#   'houseName': None,
#   'royal': None,
#   'nickname': 'The Hound',
#   'kingsguard': None},
#  {'characterName': 'Sansa Stark',
#   'houseName': 'Stark',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Selyse Baratheon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Moelle',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Mordane',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Scolera',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septa Unella',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septon',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Septon',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ser Endrew Tarth',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shae',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shagga',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shaggydog',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Shireen Baratheon',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Silk King',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Smalljon Umber',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Spice King',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stannis Baratheon',
#   'houseName': 'Baratheon',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Bannerman',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stark Guard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Steelshanks Walton',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stevron Frey',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Stiv',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Styr',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Summer',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Syrio Forel',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Talisa Maegyr',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Talla Tarly',
#   'houseName': 'Tarly',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ternesio Terys',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Bear',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Night King',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Tickler',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'The Waif',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Thenn Warg',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Theon Greyjoy',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Thin Man',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Thoros of Myr',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Three-Eyed Raven',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Timett',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tobho Mott',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Todder',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tomard',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tommen Baratheon',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Baratheon',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tormund Giantsbane',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Trystane Martell',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tycho Nestoris',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tyene Sand',
#   'houseName': 'Martell',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tyrion Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Tywin Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Vala',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Vardis Egen',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Varly',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Viserion',
#   'actorName': None,
#   'actorLink': None,
#   'houseName': 'Targaryen',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Viserys Targaryen',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Walda Bolton',
#   'houseName': ['Bolton', 'Frey'],
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Walder Frey',
#   'houseName': 'Frey',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wallen',
#   'actorLink': None,
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Warlock',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Waymar Royce',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wedding Band',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'White Walker #2',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wight Wildling Girl',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wildling Rioter',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Will',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Willem Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Willis Wode',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wine Merchant',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Winterfell Shepherd',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wun Wun',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Wyllis',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Xaro Xhoan Daxos',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yara Greyjoy',
#   'houseName': 'Greyjoy',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yezzan zo Qaggaz',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Ygritte',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yohn Royce',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Yoren',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Benjen Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Cersei Lannister',
#   'houseName': 'Lannister',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Lyanna Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Nan',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Ned',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Ned Stark',
#   'houseName': 'Stark',
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Young Rodrik Cassel',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None},
#  {'characterName': 'Zanrush',
#   'houseName': None,
#   'royal': None,
#   'nickname': None,
#   'kingsguard': None}]

# %%
actors_to_insert
# Out:
# [{'name': 'B.J. Hogg', 'imdb_id': 'nm0389698'},
#  {'name': 'Michael Feast', 'imdb_id': 'nm0269923'},
#  {'name': 'David Rintoul', 'imdb_id': 'nm0727778'},
#  {'name': 'Chuku Modu', 'imdb_id': 'nm6729880'},
#  {'name': 'Owen Teale', 'imdb_id': 'nm0853583'},
#  {'name': 'Karl Davies', 'imdb_id': 'nm0203801'},
#  {'name': 'Megan Parkinson', 'imdb_id': 'nm8257864'},
#  {'name': 'Fintan McKeown', 'imdb_id': 'nm0571654'},
#  {'name': 'Philip McGinley', 'imdb_id': 'nm1528121'},
#  {'name': 'Jim Broadbent', 'imdb_id': 'nm0000980'},
#  {'name': 'Deobia Oparei', 'imdb_id': 'nm0649046'},
#  {'name': 'Sahara Knite', 'imdb_id': 'nm1783582'},
#  {'name': 'Nathanael Saleh', 'imdb_id': 'nm8127149'},
#  {'name': 'Luke Roberts', 'imdb_id': 'nm1074361'},
#  {'name': 'Maisie Williams', 'imdb_id': 'nm3586035'},
#  {'name': 'Patrick Malahide', 'imdb_id': 'nm0538869'},
#  {'name': 'Phil Barnhill', 'imdb_id': 'nm4207240'},
#  {'name': 'Ian McElhinney', 'imdb_id': 'nm0568400'},
#  {'name': 'Joseph Mawle', 'imdb_id': 'nm1152798'},
#  {'name': 'Eline Powell', 'imdb_id': 'nm4730958'},
#  {'name': 'Gerard Jordan', 'imdb_id': 'nm0429956'},
#  {'name': 'Forbes KB', 'imdb_id': 'nm1978998'},
#  {'name': 'Tim Plester', 'imdb_id': 'nm1043031'},
#  {'name': 'Leigh Gill', 'imdb_id': 'nm5279916'},
#  {'name': 'Michael Condron', 'imdb_id': 'nm1638006'},
#  {'name': 'Isaac Hempstead Wright', 'imdb_id': 'nm3652842'},
#  {'name': 'Gemita Samarra', 'imdb_id': 'nm5106314'},
#  {'name': 'Gwendoline Christie', 'imdb_id': 'nm3729225'},
#  {'name': 'Jerome Flynn', 'imdb_id': 'nm0283492'},
#  {'name': 'Ian McShane', 'imdb_id': 'nm0574534'},
#  {'name': 'Clive Russell', 'imdb_id': 'nm0751085'},
#  {'name': 'Michael Grennell', 'imdb_id': 'nm1214477'},
#  {'name': 'Michelle Fairley', 'imdb_id': 'nm0265610'},
#  {'name': 'Lalor Roddy', 'imdb_id': 'nm0734498'},
#  {'name': 'Lena Headey', 'imdb_id': 'nm0372176'},
#  {'name': 'Alice Hewkin', 'imdb_id': 'nm2456829'},
#  {'name': 'Frank Hvam', 'imdb_id': 'nm0404809'},
#  {'name': 'Darren Killeen', 'imdb_id': 'nm4007028'},
#  {'name': 'Robert Pugh', 'imdb_id': 'nm0700059'},
#  {'name': 'Emilia Clarke', 'imdb_id': 'nm3592338'},
#  {'name': 'Ralph Ineson', 'imdb_id': 'nm0408591'},
#  {'name': 'Maisie Dee', 'imdb_id': 'nm3996678'},
#  {'name': 'Liam Cunningham', 'imdb_id': 'nm0192377'},
#  {'name': 'Ian Whyte', 'imdb_id': 'nm1613839'},
#  {'name': 'Alisdair Simpson', 'imdb_id': 'nm1368037'},
#  {'name': 'Tony Way', 'imdb_id': 'nm0915453'},
#  {'name': 'Alexander Siddig', 'imdb_id': 'nm0796502'},
#  {'name': 'Roxanne McKee', 'imdb_id': 'nm1861467'},
#  {'name': 'Diogo Sales', 'imdb_id': 'nm6088160'},
#  {'name': 'Junade Khan', 'imdb_id': 'nm2999602'},
#  {'name': 'David Coakley', 'imdb_id': 'nm2231505'},
#  {'name': 'Jonathan Ryan', 'imdb_id': 'nm0752638'},
#  {'name': 'Sean Bean', 'imdb_id': 'nm0000293'},
#  {'name': 'Ben Crompton', 'imdb_id': 'nm0174005'},
#  {'name': 'Tobias Menzies', 'imdb_id': 'nm0580014'},
#  {'name': 'Indira Varma', 'imdb_id': 'nm0890055'},
#  {'name': 'Barrington Cullen', 'imdb_id': 'nm4473207'},
#  {'name': 'Pilou Asbæk', 'imdb_id': 'nm1561982'},
#  {'name': 'Cedric Henderson', 'imdb_id': 'nm2406775'},
#  {'name': 'Peter Ballance', 'imdb_id': 'nm0050520'},
#  {'name': 'Dermot Keaney', 'imdb_id': 'nm0443825'},
#  {'name': 'Ricky Champ', 'imdb_id': 'nm2307468'},
#  {'name': 'Joe Dempsie', 'imdb_id': 'nm1478079'},
#  {'name': 'Eddie Eyre', 'imdb_id': 'nm6793798'},
#  {'name': 'Hannah Murray', 'imdb_id': 'nm2356940'},
#  {'name': 'Alan Paris', 'imdb_id': 'nm3354768'},
#  {'name': 'Sam Callis', 'imdb_id': 'nm0130538'},
#  {'name': 'Nikovich Sammut', 'imdb_id': 'nm2089809'},
#  {'name': 'Seamus Kelly', 'imdb_id': 'nm4440118'},
#  {'name': 'Julian Glover', 'imdb_id': 'nm0002103'},
#  {'name': 'Peter Silverleaf', 'imdb_id': 'nm0798872'},
#  {'name': 'Davor Jozinovic', 'imdb_id': 'nm7318132'},
#  {'name': 'Ivan Peric', 'imdb_id': 'nm3005802'},
#  {'name': 'Hadi Kermani', 'imdb_id': 'nm7318134'},
#  {'name': 'Tonci Banov', 'imdb_id': 'nm7318135'},
#  {'name': 'Clive Mantle', 'imdb_id': 'nm0544139'},
#  {'name': 'Cliff Barry', 'imdb_id': 'nm0057965'},
#  {'name': 'Mark Stanley', 'imdb_id': 'nm4440305'},
#  {'name': 'Jacob Anderson', 'imdb_id': 'nm2760664'},
#  {'name': 'Roy Dotrice', 'imdb_id': 'nm0234541'},
#  {'name': 'Sabrina Bartlett', 'imdb_id': 'nm6301068'},
#  {'name': 'Sara Dylan', 'imdb_id': 'nm2407387'},
#  {'name': 'Paul Rattray', 'imdb_id': 'nm1051151'},
#  {'name': 'Marc Rissmann', 'imdb_id': 'nm4704928'},
#  {'name': 'Souad Faress', 'imdb_id': 'nm0267256'},
#  {'name': 'David Verrey', 'imdb_id': 'nm0894857'},
#  {'name': 'Paul Bentley', 'imdb_id': 'nm0072855'},
#  {'name': 'Jonathan Pryce', 'imdb_id': 'nm0000596'},
#  {'name': 'Joel Fry', 'imdb_id': 'nm2181128'},
#  {'name': 'Kristian Nairn', 'imdb_id': 'nm3964231'},
#  {'name': 'Christopher Newman', 'imdb_id': 'nm0628040'},
#  {'name': 'Ben Hawkey', 'imdb_id': 'nm3444954'},
#  {'name': 'Leo Woodruff', 'imdb_id': 'nm4547262'},
#  {'name': 'Jefferson Hall', 'imdb_id': 'nm2131630'},
#  {'name': 'Roger Allam', 'imdb_id': 'nm0019885'},
#  {'name': 'Wilko Johnson', 'imdb_id': 'nm3330122'},
#  {'name': 'Amrita Acharia', 'imdb_id': 'nm3822505'},
#  {'name': 'Richard E. Grant', 'imdb_id': 'nm0001290'},
#  {'name': 'Paul Caddell', 'imdb_id': 'nm4781280'},
#  {'name': 'Nikolaj Coster-Waldau', 'imdb_id': 'nm0182666'},
#  {'name': 'Dominic Carter', 'imdb_id': 'nm0141582'},
#  {'name': 'Tom Wlaschiha', 'imdb_id': 'nm0937239'},
#  {'name': "Patrick O'Kane", 'imdb_id': 'nm0641433'},
#  {'name': "Jeffrey O'Brien", 'imdb_id': 'nm4475335'},
#  {'name': 'James Cosmo', 'imdb_id': 'nm0181920'},
#  {'name': 'Sarita Piotrowski', 'imdb_id': 'nm4424689'},
#  {'name': 'Jack Gleeson', 'imdb_id': 'nm0322416'},
#  {'name': 'Thomas Brodie-Sangster', 'imdb_id': 'nm1032473'},
#  {'name': 'John Standing', 'imdb_id': 'nm0822062'},
#  {'name': 'Kit Harington', 'imdb_id': 'nm3229685'},
#  {'name': "Gerry O'Brien", 'imdb_id': 'nm0639569'},
#  {'name': 'Iain Glen', 'imdb_id': 'nm0322513'},
#  {'name': 'Jamie Sives', 'imdb_id': 'nm0803397'},
#  {'name': 'Kelly Long', 'imdb_id': 'nm4958677'},
#  {'name': 'Burn Gorman', 'imdb_id': 'nm1218607'},
#  {'name': 'Birgitte Hjort Sørensen', 'imdb_id': 'nm2171898'},
#  {'name': 'Pixie Le Knot', 'imdb_id': 'nm4768858'},
#  {'name': 'Tim Landers', 'imdb_id': 'nm2461009'},
#  {'name': 'Ian Gelder', 'imdb_id': 'nm0312245'},
#  {'name': 'Jason Momoa', 'imdb_id': 'nm0597388'},
#  {'name': 'Joseph Naufahu', 'imdb_id': 'nm0622533'},
#  {'name': 'Andrei Claude', 'imdb_id': 'nm3040811'},
#  {'name': 'Raymond Griffiths', 'imdb_id': 'nm0341739'},
#  {'name': 'Dean Whatton', 'imdb_id': 'nm2482781'},
#  {'name': 'George Appleby', 'imdb_id': 'nm3338062'},
#  {'name': 'Maxwell Laird', 'imdb_id': 'nm3453345'},
#  {'name': 'Reg Wayment', 'imdb_id': 'nm1168404'},
#  {'name': 'Marko Juraga', 'imdb_id': 'nm0432837'},
#  {'name': 'Rea Separovic', 'imdb_id': 'nm5037688'},
#  {'name': 'Ania Bukstein', 'imdb_id': 'nm0119804'},
#  {'name': 'Lucy Hayes', 'imdb_id': 'nm8314450'},
#  {'name': 'Patrick Ryan', 'imdb_id': 'nm3122423'},
#  {'name': 'Paddy Rocks', 'imdb_id': 'nm0734304'},
#  {'name': 'Steven Cole', 'imdb_id': 'nm0170799'},
#  {'name': 'Dan Hildebrand', 'imdb_id': 'nm0383835'},
#  {'name': 'Kevin Keenan', 'imdb_id': 'nm4450657'},
#  {'name': 'Essie Davis', 'imdb_id': 'nm0204583'},
#  {'name': 'Eugene Simon', 'imdb_id': 'nm1638294'},
#  {'name': 'Aiden Condron', 'imdb_id': 'nm0174449'},
#  {'name': 'Richard Laing', 'imdb_id': 'nm0481924'},
#  {'name': 'Conor Delaney', 'imdb_id': 'nm1406364'},
#  {'name': 'Simon Stewart', 'imdb_id': 'nm4492930'},
#  {'name': 'Chris Gallagher', 'imdb_id': 'nm3292422'},
#  {'name': 'Christian Vit', 'imdb_id': 'nm5908524'},
#  {'name': 'Jóhannes Haukur Jóhannesson', 'imdb_id': 'nm1778512'},
#  {'name': 'Vinnie McCabe', 'imdb_id': 'nm0564516'},
#  {'name': 'Sarine Sofair', 'imdb_id': 'nm3330066'},
#  {'name': 'Samuel Paul Small', 'imdb_id': 'nm6537691'},
#  {'name': 'Tristan Mercieca', 'imdb_id': 'nm4475204'},
#  {'name': 'Michael Nevin', 'imdb_id': 'nm8127150'},
#  {'name': 'Jesse Magee', 'imdb_id': 'nm8127151'},
#  {'name': 'Iona Clarke', 'imdb_id': 'nm8133415'},
#  {'name': 'Lucy Gallagher', 'imdb_id': 'nm8127152'},
#  {'name': 'Fionn Kernan', 'imdb_id': 'nm6462692'},
#  {'name': 'Zachary Baharov', 'imdb_id': 'nm1707712'},
#  {'name': 'Noah Taylor', 'imdb_id': 'nm0852965'},
#  {'name': 'Elizabeth Cadwallader', 'imdb_id': 'nm5502252'},
#  {'name': 'Eros Vlahos', 'imdb_id': 'nm2869309'},
#  {'name': 'Finn Jones', 'imdb_id': 'nm3645691'},
#  {'name': 'Mark Coney', 'imdb_id': 'nm5651524'},
#  {'name': 'Gordon Fulton', 'imdb_id': 'nm1101680'},
#  {'name': 'Conleth Hill', 'imdb_id': 'nm0384152'},
#  {'name': "Jer O'Leary", 'imdb_id': 'nm0641596'},
#  {'name': 'Steve Cash', 'imdb_id': 'nm3524836'},
#  {'name': 'Robert Fawsitt', 'imdb_id': 'nm6342915'},
#  {'name': 'Bella Ramsey', 'imdb_id': 'nm8165602'},
#  {'name': 'Aisling Franciosi', 'imdb_id': 'nm4957233'},
#  {'name': 'Kate Dickie', 'imdb_id': 'nm0225483'},
#  {'name': 'Roger Ashton-Griffiths', 'imdb_id': 'nm0004355'},
#  {'name': 'Peter Vaughan', 'imdb_id': 'nm0891092'},
#  {'name': 'Oliver Ford Davies', 'imdb_id': 'nm0203882'},
#  {'name': 'Donald Sumpter', 'imdb_id': 'nm0838910'},
#  {'name': 'Richard Rycroft', 'imdb_id': 'nm1483416'},
#  {'name': 'Neil Fingleton', 'imdb_id': 'nm2807170'},
#  {'name': 'Jodhi May', 'imdb_id': 'nm0562003'},
#  {'name': 'Ivailo Dimitrov', 'imdb_id': 'nm2162079'},
#  {'name': 'Dennis Stokes', 'imdb_id': 'nm4982614'},
#  {'name': 'Adewale Akinnuoye-Agbaje', 'imdb_id': 'nm0015382'},
#  {'name': 'Ciarán Hinds', 'imdb_id': 'nm0001354'},
#  {'name': 'James Doran', 'imdb_id': 'nm0243696'},
#  {'name': 'Conor Watters', 'imdb_id': 'nm6442298'},
#  {'name': 'Josephine Gillan', 'imdb_id': 'nm4982706'},
#  {'name': 'Natalie Dormer', 'imdb_id': 'nm1754059'},
#  {'name': 'Aisling Jarrett-Gavin', 'imdb_id': 'nm2983094'},
#  {'name': 'Emun Elliott', 'imdb_id': 'nm2047170'},
#  {'name': 'Dean-Charles Chapman', 'imdb_id': 'nm2835616'},
#  {'name': 'Susie Kelly', 'imdb_id': 'nm3126053'},
#  {'name': 'Kerr Logan', 'imdb_id': 'nm4523680'},
#  {'name': 'Ellie Kendrick', 'imdb_id': 'nm1697771'},
#  {'name': 'Laurence Doherty', 'imdb_id': 'nm2911170'},
#  {'name': 'Samantha Spiro', 'imdb_id': 'nm0819087'},
#  {'name': 'Carice van Houten', 'imdb_id': 'nm0396924'},
#  {'name': 'Gary Pillai', 'imdb_id': 'nm0997747'},
#  {'name': 'Mark Killeen', 'imdb_id': 'nm2075330'},
#  {'name': 'Ian Beattie', 'imdb_id': 'nm0064155'},
#  {'name': 'Antonia Christophers', 'imdb_id': 'nm4460936'},
#  {'name': 'Boyd Rankin', 'imdb_id': 'nm4595425'},
#  {'name': 'Elisa Lasowski', 'imdb_id': 'nm2489799'},
#  {'name': 'Mia Soteriou', 'imdb_id': 'nm0815420'},
#  {'name': 'Nathalie Emmanuel', 'imdb_id': 'nm2812026'},
#  {'name': 'Ciaran Bermingham', 'imdb_id': 'nm2197118'},
#  {'name': 'Reece Noi', 'imdb_id': 'nm0634139'},
#  {'name': 'Nanna Bryndís Hilmarsdóttir', 'imdb_id': 'nm5652293'},
#  {'name': 'Jon Thor Birgisson', 'imdb_id': 'nm1743706'},
#  {'name': 'Ragnar Þórhallsson', 'imdb_id': 'nm5652121'},
#  {'name': 'Orri P. Dyrason', 'imdb_id': 'nm1743714'},
#  {'name': 'Georg Holm', 'imdb_id': 'nm1743730'},
#  {'name': 'Arnar Rosenkranz Hilmarsson', 'imdb_id': 'nm8158202'},
#  {'name': 'Brynjar Leifsson', 'imdb_id': 'nm8158203'},
#  {'name': 'Kristján Kristjánsson', 'imdb_id': 'nm1944894'},
#  {'name': 'Rhodri Hosking', 'imdb_id': 'nm4430905'},
#  {'name': 'Charlotte Hope', 'imdb_id': 'nm3745225'},
#  {'name': 'Harry Grasby', 'imdb_id': 'nm9132255'},
#  {'name': "Barry John O'Connor", 'imdb_id': 'nm3226454'},
#  {'name': "Frank O'Sullivan", 'imdb_id': 'nm0642751'},
#  {'name': 'Dennis McKeever', 'imdb_id': 'nm4475182'},
#  {'name': 'Michael Stuart', 'imdb_id': 'nm5792452'},
#  {'name': 'Marcus Lamb', 'imdb_id': 'nm2228622'},
#  {'name': 'Michael Hooley', 'imdb_id': 'nm6706699'},
#  {'name': 'Patrick J Molloy', 'imdb_id': 'nm3561455'},
#  {'name': 'Michael Hayes', 'imdb_id': 'nm0371160'},
#  {'name': 'Ruairí Heading', 'imdb_id': 'nm6316115'},
#  {'name': 'Tony Flynn', 'imdb_id': 'nm0283642'},
#  {'name': 'Jed Murray', 'imdb_id': 'nm5697839'},
#  {'name': 'Jessica Henwick', 'imdb_id': 'nm3725055'},
#  {'name': 'Keisha Castle-Hughes', 'imdb_id': 'nm1095720'},
#  {'name': 'Pedro Pascal', 'imdb_id': 'nm0050959'},
#  {'name': 'Margaret John', 'imdb_id': 'nm0424191'},
#  {'name': 'Gina Moxley', 'imdb_id': 'nm0610312'},
#  {'name': 'Diana Rigg', 'imdb_id': 'nm0001671'},
#  {'name': "Brenock O'Connor", 'imdb_id': 'nm5282143'},
#  {'name': 'Will Tudor', 'imdb_id': 'nm4831584'},
#  {'name': 'Mackenzie Crook', 'imdb_id': 'nm0188871'},
#  {'name': 'Hannah John-Kamen', 'imdb_id': 'nm4789912'},
#  {'name': 'Natalia Tena', 'imdb_id': 'nm1164730'},
#  {'name': 'Brian Fortune', 'imdb_id': 'nm1987270'},
#  {'name': 'Rania Zouari', 'imdb_id': 'nm4422639'},
#  {'name': 'Aidan Gillen', 'imdb_id': 'nm0318821'},
#  {'name': 'Daniel Portman', 'imdb_id': 'nm4535552'},
#  {'name': 'Andy Kellegher', 'imdb_id': 'nm3464945'},
#  {'name': 'Ramon Tikaram', 'imdb_id': 'nm0863130'},
#  {'name': 'Ian Hanmore', 'imdb_id': 'nm0360171'},
#  {'name': 'Josef Altin', 'imdb_id': 'nm1086981'},
#  {'name': 'Staz Nair', 'imdb_id': 'nm7047874'},
#  {'name': 'Simon Armstrong', 'imdb_id': 'nm1409802'},
#  {'name': 'Dar Salim', 'imdb_id': 'nm1502469'},
#  {'name': 'Laura Pradelska', 'imdb_id': 'nm3671418'},
#  {'name': 'Anton Lesser', 'imdb_id': 'nm0504320'},
#  {'name': 'Elyes Gabel', 'imdb_id': 'nm1175468'},
#  {'name': 'Iwan Rheon', 'imdb_id': 'nm3701064'},
#  {'name': 'James Faulkner', 'imdb_id': 'nm0269077'},
#  {'name': 'Luke Barnes', 'imdb_id': 'nm4430828'},
#  {'name': 'George Georgiou', 'imdb_id': 'nm1745190'},
#  {'name': 'Hugo Culverhouse', 'imdb_id': 'nm4164318'},
#  {'name': 'Melanie Liburd', 'imdb_id': 'nm4927489'},
#  {'name': 'Rila Fukushima', 'imdb_id': 'nm3822462'},
#  {'name': 'Gethin Anthony', 'imdb_id': 'nm2167445'},
#  {'name': 'Art Parkinson', 'imdb_id': 'nm3280686'},
#  {'name': 'Richard Madden', 'imdb_id': 'nm0534635'},
#  {'name': 'Mark Addy', 'imdb_id': 'nm0004692'},
#  {'name': 'Tim McInnerny', 'imdb_id': 'nm0570570'},
#  {'name': 'Lino Facioli', 'imdb_id': 'nm2996220'},
#  {'name': 'Ron Donachie', 'imdb_id': 'nm0231871'},
#  {'name': 'Michael McElhatton', 'imdb_id': 'nm0568385'},
#  {'name': 'Andy Beckwith', 'imdb_id': 'nm0065874'},
#  {'name': 'Esmé Bianco', 'imdb_id': 'nm2657974'},
#  {'name': 'Alexandra Dowling', 'imdb_id': 'nm5093301'},
#  {'name': 'Robert Sterne', 'imdb_id': 'nm1414435'},
#  {'name': 'Bryan McCaugherty', 'imdb_id': 'nm0565472'},
#  {'name': 'Lucian Msamati', 'imdb_id': 'nm1748634'},
#  {'name': 'John Bradley', 'imdb_id': 'nm4263213'},
#  {'name': 'Rory McCann', 'imdb_id': 'nm0564920'},
#  {'name': 'Sophie Turner', 'imdb_id': 'nm3849842'},
#  {'name': 'Maggie Hayes', 'imdb_id': 'nm1378629'},
#  {'name': 'Susan Brown', 'imdb_id': 'nm0114742'},
#  {'name': 'Mary Jordan', 'imdb_id': 'nm1103771'},
#  {'name': 'Hannah Waddingham', 'imdb_id': 'nm1821446'},
#  {'name': 'Kenneth Hadley', 'imdb_id': 'nm0352901'},
#  {'name': 'Terry Byrne', 'imdb_id': 'nm0126298'},
#  {'name': 'Dez McMahon', 'imdb_id': 'nm4757478'},
#  {'name': 'Sibel Kekilli', 'imdb_id': 'nm1402546'},
#  {'name': 'Mark Lewis Jones', 'imdb_id': 'nm0428765'},
#  {'name': 'Kerry Ingram', 'imdb_id': 'nm5081192'},
#  {'name': 'Slavko Juraga', 'imdb_id': 'nm0432838'},
#  {'name': 'Dean S. Jagger', 'imdb_id': 'nm2746504'},
#  {'name': 'Nicholas Blane', 'imdb_id': 'nm0087432'},
#  {'name': 'Stephen Dillane', 'imdb_id': 'nm0226820'},
#  {'name': 'Michael Stuart', 'imdb_id': 'nm5792452'},
#  {'name': 'Faolan Morgan', 'imdb_id': 'nm4335246'},
#  {'name': 'Rick Burn', 'imdb_id': 'nm4492916'},
#  {'name': 'David Sheehan', 'imdb_id': 'nm1423916'},
#  {'name': 'Paul Monahan', 'imdb_id': 'nm5981376'},
#  {'name': 'Jamie Michie', 'imdb_id': 'nm1652341'},
#  {'name': 'Colin Carnegie', 'imdb_id': 'nm1794801'},
#  {'name': 'Stephen Don', 'imdb_id': 'nm1651043'},
#  {'name': 'Yuri Kolokolnikov', 'imdb_id': 'nm0464305'},
#  {'name': 'Miltos Yerolemou', 'imdb_id': 'nm1115654'},
#  {'name': 'Oona Chaplin', 'imdb_id': 'nm2772105'},
#  {'name': 'Rebecca Benson', 'imdb_id': 'nm5039410'},
#  {'name': 'Gary Oliver', 'imdb_id': 'nm1146807'},
#  {'name': 'Bart the Bear', 'imdb_id': 'nm1212069'},
#  {'name': 'Anthony Morris', 'imdb_id': 'nm1677757'},
#  {'name': 'Faye Marsay', 'imdb_id': 'nm3849670'},
#  {'name': 'Joseph Gatt', 'imdb_id': 'nm1395532'},
#  {'name': 'Alfie Allen', 'imdb_id': 'nm0654295'},
#  {'name': 'Oengus MacNamara', 'imdb_id': 'nm0534062'},
#  {'name': 'Paul Kaye', 'imdb_id': 'nm0443373'},
#  {'name': 'Tobias Winter', 'imdb_id': 'nm4385245'},
#  {'name': 'Andrew Wilde', 'imdb_id': 'nm0928408'},
#  {'name': "Will O'Connell", 'imdb_id': 'nm3727276'},
#  {'name': 'Phil Dixon', 'imdb_id': 'nm4475303'},
#  {'name': 'Kristofer Hivju', 'imdb_id': 'nm1970465'},
#  {'name': 'Toby Sebastian', 'imdb_id': 'nm4514519'},
#  {'name': 'Mark Gatiss', 'imdb_id': 'nm0309693'},
#  {'name': 'Rosabell Laurenti Sellers', 'imdb_id': 'nm3065809'},
#  {'name': 'Peter Dinklage', 'imdb_id': 'nm0227759'},
#  {'name': 'Charles Dance', 'imdb_id': 'nm0001097'},
#  {'name': 'Meena Rayann', 'imdb_id': 'nm5159884'},
#  {'name': 'Brendan McCormack', 'imdb_id': 'nm1788152'},
#  {'name': 'Graham Charles', 'imdb_id': 'nm1378721'},
#  {'name': 'Harry Lloyd', 'imdb_id': 'nm0516003'},
#  {'name': 'Elizabeth Webster', 'imdb_id': 'nm3531913'},
#  {'name': 'David Bradley', 'imdb_id': 'nm0103195'},
#  {'name': 'Lottie Steer', 'imdb_id': 'nm5390029'},
#  {'name': 'Rob Ostlere', 'imdb_id': 'nm3209935'},
#  {'name': 'Sigur Rós', 'imdb_id': 'nm1460176'},
#  {'name': 'Ian Whyte', 'imdb_id': 'nm1613839'},
#  {'name': 'Ross Mullan', 'imdb_id': 'nm1368643'},
#  {'name': 'Tim Loane', 'imdb_id': 'nm0516385'},
#  {'name': 'Spencer Wilding', 'imdb_id': 'nm1872855'},
#  {'name': 'Claire Wright', 'imdb_id': 'nm4422708'},
#  {'name': 'Michael Patrick', 'imdb_id': 'nm8199963'},
#  {'name': 'Bronson Webb', 'imdb_id': 'nm0916037'},
#  {'name': 'Timothy Gibbons', 'imdb_id': 'nm5624523'},
#  {'name': 'Ryan McKenna', 'imdb_id': 'nm4416560'},
#  {'name': 'Simon Lowe', 'imdb_id': 'nm0523047'},
#  {'name': 'Donagh Deeney', 'imdb_id': 'nm0214343'},
#  {'name': 'Ian Whyte', 'imdb_id': 'nm1613839'},
#  {'name': 'Sam Coleman', 'imdb_id': 'nm4744043'},
#  {'name': 'Nonso Anozie', 'imdb_id': 'nm1996829'},
#  {'name': 'Gemma Whelan', 'imdb_id': 'nm2247629'},
#  {'name': 'Enzo Cilenti', 'imdb_id': 'nm0162281'},
#  {'name': 'Rose Leslie', 'imdb_id': 'nm3310211'},
#  {'name': 'Rupert Vansittart', 'imdb_id': 'nm0889338'},
#  {'name': 'Francis Magee', 'imdb_id': 'nm0535837'},
#  {'name': 'Matteo Elezi', 'imdb_id': 'nm5502295'},
#  {'name': 'Nell Williams', 'imdb_id': 'nm5309709'},
#  {'name': 'Cordelia Hill', 'imdb_id': 'nm8108764'},
#  {'name': 'Annette Tierney', 'imdb_id': 'nm1519719'},
#  {'name': 'Robert Aramayo', 'imdb_id': 'nm7075019'},
#  {'name': 'Sebastian Croft', 'imdb_id': 'nm7509185'},
#  {'name': 'Fergus Leathem', 'imdb_id': 'nm7509186'},
#  {'name': 'Gerald Lepkowski', 'imdb_id': 'nm0503319'}]

# %%
for a in actors_to_insert:
    if a["name"] == "Jim Broadbent":
        print("Found")
# Out:
# Found

# %%
relationships_to_insert
# Out:
# [{'character': 'Addam Marbrand', 'actor_id': 'nm0389698'},
#  {'character': 'Aeron Greyjoy', 'actor_id': 'nm0269923'},
#  {'character': 'Aerys II Targaryen', 'actor_id': 'nm0727778'},
#  {'character': 'Akho', 'actor_id': 'nm6729880'},
#  {'character': 'Alliser Thorne', 'actor_id': 'nm0853583'},
#  {'character': 'Alton Lannister', 'actor_id': 'nm0203801'},
#  {'character': 'Alys Karstark', 'actor_id': 'nm8257864'},
#  {'character': 'Amory Lorch', 'actor_id': 'nm0571654'},
#  {'character': 'Anguy', 'actor_id': 'nm1528121'},
#  {'character': 'Archmaester Marwyn', 'actor_id': 'nm0000980'},
#  {'character': 'Areo Hotah', 'actor_id': 'nm0649046'},
#  {'character': 'Armeca', 'actor_id': 'nm1783582'},
#  {'character': 'Arthur', 'actor_id': 'nm8127149'},
#  {'character': 'Arthur Dayne', 'actor_id': 'nm1074361'},
#  {'character': 'Arya Stark', 'actor_id': 'nm3586035'},
#  {'character': 'Balon Greyjoy', 'actor_id': 'nm0538869'},
#  {'character': 'Baratheon Guard', 'actor_id': 'nm4207240'},
#  {'character': 'Barristan Selmy', 'actor_id': 'nm0568400'},
#  {'character': 'Benjen Stark', 'actor_id': 'nm1152798'},
#  {'character': 'Bianca', 'actor_id': 'nm4730958'},
#  {'character': 'Biter', 'actor_id': 'nm0429956'},
#  {'character': 'Black Lorren', 'actor_id': 'nm1978998'},
#  {'character': 'Black Walder Rivers', 'actor_id': 'nm1043031'},
#  {'character': 'Bobono', 'actor_id': 'nm5279916'},
#  {'character': 'Bowen Marsh', 'actor_id': 'nm1638006'},
#  {'character': 'Bran Stark', 'actor_id': 'nm3652842'},
#  {'character': 'Brea', 'actor_id': 'nm5106314'},
#  {'character': 'Brienne of Tarth', 'actor_id': 'nm3729225'},
#  {'character': 'Bronn', 'actor_id': 'nm0283492'},
#  {'character': 'Brother Ray', 'actor_id': 'nm0574534'},
#  {'character': 'Brynden Tully', 'actor_id': 'nm0751085'},
#  {'character': 'Captain of the Archers', 'actor_id': 'nm1214477'},
#  {'character': 'Catelyn Stark', 'actor_id': 'nm0265610'},
#  {'character': 'Catspaw Assassin', 'actor_id': 'nm0734498'},
#  {'character': 'Cersei Lannister', 'actor_id': 'nm0372176'},
#  {'character': 'Child of the Forest', 'actor_id': 'nm2456829'},
#  {'character': 'Citadel Maester', 'actor_id': 'nm0404809'},
#  {'character': 'Colen of Greenpools', 'actor_id': 'nm4007028'},
#  {'character': 'Craster', 'actor_id': 'nm0700059'},
#  {'character': 'Daenerys Targaryen', 'actor_id': 'nm3592338'},
#  {'character': 'Dagmer Cleftjaw', 'actor_id': 'nm0408591'},
#  {'character': 'Daisy', 'actor_id': 'nm3996678'},
#  {'character': 'Davos Seaworth', 'actor_id': 'nm0192377'},
#  {'character': 'Dongo the Giant', 'actor_id': 'nm1613839'},
#  {'character': 'Donnel Waynwood', 'actor_id': 'nm1368037'},
#  {'character': 'Dontos Hollard', 'actor_id': 'nm0915453'},
#  {'character': 'Doran Martell', 'actor_id': 'nm0796502'},
#  {'character': 'Doreah', 'actor_id': 'nm1861467'},
#  {'character': 'Dothraki Bloodrider #1', 'actor_id': 'nm6088160'},
#  {'character': 'Dothraki Bloodrider #2', 'actor_id': 'nm2999602'},
#  {'character': 'Drennan', 'actor_id': 'nm2231505'},
#  {'character': 'Drowned Priest', 'actor_id': 'nm0752638'},
#  {'character': 'Eddard Stark', 'actor_id': 'nm0000293'},
#  {'character': 'Eddison Tollett', 'actor_id': 'nm0174005'},
#  {'character': 'Edmure Tully', 'actor_id': 'nm0580014'},
#  {'character': 'Ellaria Sand', 'actor_id': 'nm0890055'},
#  {'character': 'Eon Hunter', 'actor_id': 'nm4473207'},
#  {'character': 'Euron Greyjoy', 'actor_id': 'nm1561982'},
#  {'character': 'Faceless Man', 'actor_id': 'nm2406775'},
#  {'character': 'Farlen', 'actor_id': 'nm0050520'},
#  {'character': 'Gared', 'actor_id': 'nm0443825'},
#  {'character': 'Gatins', 'actor_id': 'nm2307468'},
#  {'character': 'Gendry', 'actor_id': 'nm1478079'},
#  {'character': 'Gerold Hightower', 'actor_id': 'nm6793798'},
#  {'character': 'Gilly', 'actor_id': 'nm2356940'},
#  {'character': 'Goldcloak', 'actor_id': 'nm3354768'},
#  {'character': 'Goldcloak', 'actor_id': 'nm0130538'},
#  {'character': 'Goldcloak #1', 'actor_id': 'nm2089809'},
#  {'character': 'Goldcloak #2', 'actor_id': 'nm4440118'},
#  {'character': 'Grand Maester Pycelle', 'actor_id': 'nm0002103'},
#  {'character': 'Great Master #3', 'actor_id': 'nm0798872'},
#  {'character': 'Great Master #4', 'actor_id': 'nm7318132'},
#  {'character': 'Great Master #5', 'actor_id': 'nm3005802'},
#  {'character': 'Great Master #6', 'actor_id': 'nm7318134'},
#  {'character': 'Great Master #7', 'actor_id': 'nm7318135'},
#  {'character': 'Greatjon Umber', 'actor_id': 'nm0544139'},
#  {'character': 'Greizhen mo Ullhor', 'actor_id': 'nm0057965'},
#  {'character': 'Grenn', 'actor_id': 'nm4440305'},
#  {'character': 'Grey Worm', 'actor_id': 'nm2760664'},
#  {'character': 'Hallyne', 'actor_id': 'nm0234541'},
#  {'character': 'Handmaid', 'actor_id': 'nm6301068'},
#  {'character': 'Handmaid', 'actor_id': 'nm2407387'},
#  {'character': 'Harald Karstark', 'actor_id': 'nm1051151'},
#  {'character': 'Harry Strickland', 'actor_id': 'nm4704928'},
#  {'character': 'High Priestess', 'actor_id': 'nm0267256'},
#  {'character': 'High Septon', 'actor_id': 'nm0894857'},
#  {'character': 'High Septon', 'actor_id': 'nm0072855'},
#  {'character': 'High Sparrow', 'actor_id': 'nm0000596'},
#  {'character': 'Hizdahr zo Loraq', 'actor_id': 'nm2181128'},
#  {'character': 'Hodor', 'actor_id': 'nm3964231'},
#  {'character': 'Hoster Tully', 'actor_id': 'nm0628040'},
#  {'character': 'Hot Pie', 'actor_id': 'nm3444954'},
#  {'character': 'Howland Reed', 'actor_id': 'nm4547262'},
#  {'character': 'Hugh of the Vale', 'actor_id': 'nm2131630'},
#  {'character': 'Illyrio Mopatis', 'actor_id': 'nm0019885'},
#  {'character': 'Ilyn Payne', 'actor_id': 'nm3330122'},
#  {'character': 'Irri', 'actor_id': 'nm3822505'},
#  {'character': 'Izembaro', 'actor_id': 'nm0001290'},
#  {'character': 'Jacks', 'actor_id': 'nm4781280'},
#  {'character': 'Jaime Lannister', 'actor_id': 'nm0182666'},
#  {'character': 'Janos Slynt', 'actor_id': 'nm0141582'},
#  {'character': "Jaqen H'ghar", 'actor_id': 'nm0937239'},
#  {'character': "Jaqen's Disguise", 'actor_id': 'nm0641433'},
#  {'character': 'Jaremy Rykker', 'actor_id': 'nm4475335'},
#  {'character': 'Jeor Mormont', 'actor_id': 'nm0181920'},
#  {'character': 'Jhiqui', 'actor_id': 'nm4424689'},
#  {'character': 'Joffrey Baratheon', 'actor_id': 'nm0322416'},
#  {'character': 'Jojen Reed', 'actor_id': 'nm1032473'},
#  {'character': 'Jon Arryn', 'actor_id': 'nm0822062'},
#  {'character': 'Jon Snow', 'actor_id': 'nm3229685'},
#  {'character': 'Jonos Bracken', 'actor_id': 'nm0639569'},
#  {'character': 'Jorah Mormont', 'actor_id': 'nm0322513'},
#  {'character': 'Jory Cassel', 'actor_id': 'nm0803397'},
#  {'character': 'Joyeuse Erenford', 'actor_id': 'nm4958677'},
#  {'character': 'Karl Tanner', 'actor_id': 'nm1218607'},
#  {'character': 'Karsi', 'actor_id': 'nm2171898'},
#  {'character': 'Kayla', 'actor_id': 'nm4768858'},
#  {'character': 'Kegs', 'actor_id': 'nm2461009'},
#  {'character': 'Kevan Lannister', 'actor_id': 'nm0312245'},
#  {'character': 'Khal Drogo', 'actor_id': 'nm0597388'},
#  {'character': 'Khal Moro', 'actor_id': 'nm0622533'},
#  {'character': 'Khal Rhalko', 'actor_id': 'nm3040811'},
#  {'character': 'King Joffrey Baratheon Dwarf', 'actor_id': 'nm0341739'},
#  {'character': 'King Renly Baratheon Dwarf', 'actor_id': 'nm2482781'},
#  {'character': 'King Robb Stark Dwarf', 'actor_id': 'nm3338062'},
#  {'character': 'King Stannis Baratheon Dwarf', 'actor_id': 'nm3453345'},
#  {'character': "King's Landing Rioter #1", 'actor_id': 'nm1168404'},
#  {'character': "King's Landing Rioter #2", 'actor_id': 'nm0432837'},
#  {'character': "King's Landing Rioter #3", 'actor_id': 'nm5037688'},
#  {'character': 'Kinvara', 'actor_id': 'nm0119804'},
#  {'character': 'Kitty Frey', 'actor_id': 'nm8314450'},
#  {'character': 'Knight of House Frey', 'actor_id': 'nm3122423'},
#  {'character': 'Knight of House Lynderly', 'actor_id': 'nm0734304'},
#  {'character': 'Kovarro', 'actor_id': 'nm0170799'},
#  {'character': 'Kraznys mo Nakloz', 'actor_id': 'nm0383835'},
#  {'character': 'Kurleket', 'actor_id': 'nm4450657'},
#  {'character': 'Lady Crane', 'actor_id': 'nm0204583'},
#  {'character': 'Lancel Lannister', 'actor_id': 'nm1638294'},
#  {'character': 'Lannister Captain', 'actor_id': 'nm0174449'},
#  {'character': 'Lannister Captain', 'actor_id': 'nm0481924'},
#  {'character': 'Lannister Guardsman', 'actor_id': 'nm1406364'},
#  {'character': 'Lannister Messenger', 'actor_id': 'nm4492930'},
#  {'character': 'Lannister Scout', 'actor_id': 'nm3292422'},
#  {'character': 'Lead Dornish Guard', 'actor_id': 'nm5908524'},
#  {'character': 'Lem Lemoncloak', 'actor_id': 'nm1778512'},
#  {'character': 'Leo Lefford', 'actor_id': 'nm0564516'},
#  {'character': 'Lhara', 'actor_id': 'nm3330066'},
#  {'character': 'Little Bird', 'actor_id': 'nm6537691'},
#  {'character': 'Little Bird', 'actor_id': 'nm4475204'},
#  {'character': 'Little Bird #3', 'actor_id': 'nm8127150'},
#  {'character': 'Little Bird #4', 'actor_id': 'nm8127151'},
#  {'character': 'Little Bird #5', 'actor_id': 'nm8133415'},
#  {'character': 'Little Bird #6', 'actor_id': 'nm8127152'},
#  {'character': 'Little Bird #7', 'actor_id': 'nm6462692'},
#  {'character': 'Loboda', 'actor_id': 'nm1707712'},
#  {'character': 'Locke', 'actor_id': 'nm0852965'},
#  {'character': 'Lollys Stokeworth', 'actor_id': 'nm5502252'},
#  {'character': 'Lommy Greenhands', 'actor_id': 'nm2869309'},
#  {'character': 'Loras Tyrell', 'actor_id': 'nm3645691'},
#  {'character': 'Lord Galbart Glover', 'actor_id': 'nm5651524'},
#  {'character': 'Lord Portan', 'actor_id': 'nm1101680'},
#  {'character': 'Lord Varys', 'actor_id': 'nm0384152'},
#  {'character': 'Lordsport Dockhand', 'actor_id': 'nm0641596'},
#  {'character': "Loyal Night's Watchman #1", 'actor_id': 'nm3524836'},
#  {'character': "Loyal Night's Watchman #2", 'actor_id': 'nm6342915'},
#  {'character': 'Lyanna Mormont', 'actor_id': 'nm8165602'},
#  {'character': 'Lyanna Stark', 'actor_id': 'nm4957233'},
#  {'character': 'Lysa Arryn', 'actor_id': 'nm0225483'},
#  {'character': 'Mace Tyrell', 'actor_id': 'nm0004355'},
#  {'character': 'Maester Aemon', 'actor_id': 'nm0891092'},
#  {'character': 'Maester Cressen', 'actor_id': 'nm0203882'},
#  {'character': 'Maester Luwin', 'actor_id': 'nm0838910'},
#  {'character': 'Maester Wolkan', 'actor_id': 'nm1483416'},
#  {'character': 'Mag the Mighty', 'actor_id': 'nm2807170'},
#  {'character': 'Maggy', 'actor_id': 'nm0562003'},
#  {'character': 'Mago', 'actor_id': 'nm2162079'},
#  {'character': 'Male Prostitute', 'actor_id': 'nm4982614'},
#  {'character': 'Malko', 'actor_id': 'nm0015382'},
#  {'character': 'Mance Rayder', 'actor_id': 'nm0001354'},
#  {'character': 'Mandon Moore', 'actor_id': 'nm0243696'},
#  {'character': 'Manservant', 'actor_id': 'nm6442298'},
#  {'character': 'Marei', 'actor_id': 'nm4982706'},
#  {'character': 'Margaery Tyrell', 'actor_id': 'nm1754059'},
#  {'character': "Margaery's Handmaiden", 'actor_id': 'nm2983094'},
#  {'character': 'Marillion', 'actor_id': 'nm2047170'},
#  {'character': 'Martyn Lannister', 'actor_id': 'nm2835616'},
#  {'character': 'Masha Heddle', 'actor_id': 'nm3126053'},
#  {'character': 'Matthos Seaworth', 'actor_id': 'nm4523680'},
#  {'character': 'Meera Reed', 'actor_id': 'nm1697771'},
#  {'character': 'Meereen Slave Master', 'actor_id': 'nm2911170'},
#  {'character': 'Melessa Tarly', 'actor_id': 'nm0819087'},
#  {'character': 'Melisandre', 'actor_id': 'nm0396924'},
#  {'character': 'Merchant Captain', 'actor_id': 'nm0997747'},
#  {'character': 'Mero', 'actor_id': 'nm2075330'},
#  {'character': 'Meryn Trant', 'actor_id': 'nm0064155'},
#  {'character': 'Mhaegen', 'actor_id': 'nm4460936'},
#  {'character': 'Mikken', 'actor_id': 'nm4595425'},
#  {'character': 'Mirelle', 'actor_id': 'nm2489799'},
#  {'character': 'Mirri Maz Duur', 'actor_id': 'nm0815420'},
#  {'character': 'Missandei', 'actor_id': 'nm2812026'},
#  {'character': 'Mord', 'actor_id': 'nm2197118'},
#  {'character': 'Mossador', 'actor_id': 'nm0634139'},
#  {'character': 'Musician #1', 'actor_id': 'nm5652293'},
#  {'character': 'Musician #1', 'actor_id': 'nm1743706'},
#  {'character': 'Musician #2', 'actor_id': 'nm5652121'},
#  {'character': 'Musician #2', 'actor_id': 'nm1743714'},
#  {'character': 'Musician #3', 'actor_id': 'nm1743730'},
#  {'character': 'Musician #3', 'actor_id': 'nm8158202'},
#  {'character': 'Musician #4', 'actor_id': 'nm8158203'},
#  {'character': 'Musician #5', 'actor_id': 'nm1944894'},
#  {'character': 'Mycah', 'actor_id': 'nm4430905'},
#  {'character': 'Myranda', 'actor_id': 'nm3745225'},
#  {'character': 'Ned Umber', 'actor_id': 'nm9132255'},
#  {'character': "Night's Watch Deserter", 'actor_id': 'nm3226454'},
#  {'character': "Night's Watch Messenger", 'actor_id': 'nm0642751'},
#  {'character': "Night's Watch Officer", 'actor_id': 'nm4475182'},
#  {'character': "Night's Watch Officer", 'actor_id': 'nm5792452'},
#  {'character': "Night's Watchman", 'actor_id': 'nm2228622'},
#  {'character': "Night's Watchman", 'actor_id': 'nm6706699'},
#  {'character': "Night's Watchman", 'actor_id': 'nm3561455'},
#  {'character': "Night's Watchman #1", 'actor_id': 'nm0371160'},
#  {'character': "Night's Watchman #2", 'actor_id': 'nm6316115'},
#  {'character': "Night's Watchman #2", 'actor_id': 'nm0283642'},
#  {'character': 'Northman Rioter', 'actor_id': 'nm5697839'},
#  {'character': 'Nymeria Sand', 'actor_id': 'nm3725055'},
#  {'character': 'Obara Sand', 'actor_id': 'nm1095720'},
#  {'character': 'Oberyn Martell', 'actor_id': 'nm0050959'},
#  {'character': 'Old Nan', 'actor_id': 'nm0424191'},
#  {'character': 'Old Woman Prisoner', 'actor_id': 'nm0610312'},
#  {'character': 'Olenna Tyrell', 'actor_id': 'nm0001671'},
#  {'character': 'Olly', 'actor_id': 'nm5282143'},
#  {'character': 'Olyvar', 'actor_id': 'nm4831584'},
#  {'character': 'Orell', 'actor_id': 'nm0188871'},
#  {'character': 'Ornela', 'actor_id': 'nm4789912'},
#  {'character': 'Osha', 'actor_id': 'nm1164730'},
#  {'character': 'Othell Yarwyck', 'actor_id': 'nm1987270'},
#  {'character': 'Pentoshi Servant', 'actor_id': 'nm4422639'},
#  {'character': 'Petyr Baelish', 'actor_id': 'nm0318821'},
#  {'character': 'Podrick Payne', 'actor_id': 'nm4535552'},
#  {'character': 'Polliver', 'actor_id': 'nm3464945'},
#  {'character': 'Prendahl na Ghezn', 'actor_id': 'nm0863130'},
#  {'character': 'Pyat Pree', 'actor_id': 'nm0360171'},
#  {'character': 'Pypar', 'actor_id': 'nm1086981'},
#  {'character': 'Qhono', 'actor_id': 'nm7047874'},
#  {'character': 'Qhorin Halfhand', 'actor_id': 'nm1409802'},
#  {'character': 'Qotho', 'actor_id': 'nm1502469'},
#  {'character': 'Quaithe', 'actor_id': 'nm3671418'},
#  {'character': 'Qyburn', 'actor_id': 'nm0504320'},
#  {'character': 'Rakharo', 'actor_id': 'nm1175468'},
#  {'character': 'Ramsay Snow', 'actor_id': 'nm3701064'},
#  {'character': 'Randyll Tarly', 'actor_id': 'nm0269077'},
#  {'character': 'Rast', 'actor_id': 'nm4430828'},
#  {'character': 'Razdal mo Eraz', 'actor_id': 'nm1745190'},
#  {'character': 'Red Keep Stableboy', 'actor_id': 'nm4164318'},
#  {'character': 'Red Priestess', 'actor_id': 'nm4927489'},
#  {'character': 'Red Priestess', 'actor_id': 'nm3822462'},
#  {'character': 'Renly Baratheon', 'actor_id': 'nm2167445'},
#  {'character': 'Rickon Stark', 'actor_id': 'nm3280686'},
#  {'character': 'Robb Stark', 'actor_id': 'nm0534635'},
#  {'character': 'Robert Baratheon', 'actor_id': 'nm0004692'},
#  {'character': 'Robett Glover', 'actor_id': 'nm0570570'},
#  {'character': 'Robin Arryn', 'actor_id': 'nm2996220'},
#  {'character': 'Rodrik Cassel', 'actor_id': 'nm0231871'},
#  {'character': 'Roose Bolton', 'actor_id': 'nm0568385'},
#  {'character': 'Rorge', 'actor_id': 'nm0065874'},
#  {'character': 'Ros', 'actor_id': 'nm2657974'},
#  {'character': 'Roslin Frey', 'actor_id': 'nm5093301'},
#  {'character': 'Royal Steward', 'actor_id': 'nm1414435'},
#  {'character': 'Ryger Rivers', 'actor_id': 'nm0565472'},
#  {'character': 'Salladhor Saan', 'actor_id': 'nm1748634'},
#  {'character': 'Samwell Tarly', 'actor_id': 'nm4263213'},
#  {'character': 'Sandor Clegane', 'actor_id': 'nm0564920'},
#  {'character': 'Sansa Stark', 'actor_id': 'nm3849842'},
#  {'character': 'Septa Moelle', 'actor_id': 'nm1378629'},
#  {'character': 'Septa Mordane', 'actor_id': 'nm0114742'},
#  {'character': 'Septa Scolera', 'actor_id': 'nm1103771'},
#  {'character': 'Septa Unella', 'actor_id': 'nm1821446'},
#  {'character': 'Septon', 'actor_id': 'nm0352901'},
#  {'character': 'Septon', 'actor_id': 'nm0126298'},
#  {'character': 'Ser Endrew Tarth', 'actor_id': 'nm4757478'},
#  {'character': 'Shae', 'actor_id': 'nm1402546'},
#  {'character': 'Shagga', 'actor_id': 'nm0428765'},
#  {'character': 'Shireen Baratheon', 'actor_id': 'nm5081192'},
#  {'character': 'Silk King', 'actor_id': 'nm0432838'},
#  {'character': 'Smalljon Umber', 'actor_id': 'nm2746504'},
#  {'character': 'Spice King', 'actor_id': 'nm0087432'},
#  {'character': 'Stannis Baratheon', 'actor_id': 'nm0226820'},
#  {'character': 'Stark Bannerman', 'actor_id': 'nm5792452'},
#  {'character': 'Stark Guard', 'actor_id': 'nm4335246'},
#  {'character': 'Stark Guard', 'actor_id': 'nm4492916'},
#  {'character': 'Stark Guard', 'actor_id': 'nm1423916'},
#  {'character': 'Stark Guard', 'actor_id': 'nm5981376'},
#  {'character': 'Steelshanks Walton', 'actor_id': 'nm1652341'},
#  {'character': 'Stevron Frey', 'actor_id': 'nm1794801'},
#  {'character': 'Stiv', 'actor_id': 'nm1651043'},
#  {'character': 'Styr', 'actor_id': 'nm0464305'},
#  {'character': 'Syrio Forel', 'actor_id': 'nm1115654'},
#  {'character': 'Talisa Maegyr', 'actor_id': 'nm2772105'},
#  {'character': 'Talla Tarly', 'actor_id': 'nm5039410'},
#  {'character': 'Ternesio Terys', 'actor_id': 'nm1146807'},
#  {'character': 'The Bear', 'actor_id': 'nm1212069'},
#  {'character': 'The Tickler', 'actor_id': 'nm1677757'},
#  {'character': 'The Waif', 'actor_id': 'nm3849670'},
#  {'character': 'Thenn Warg', 'actor_id': 'nm1395532'},
#  {'character': 'Theon Greyjoy', 'actor_id': 'nm0654295'},
#  {'character': 'Thin Man', 'actor_id': 'nm0534062'},
#  {'character': 'Thoros of Myr', 'actor_id': 'nm0443373'},
#  {'character': 'Timett', 'actor_id': 'nm4385245'},
#  {'character': 'Tobho Mott', 'actor_id': 'nm0928408'},
#  {'character': 'Todder', 'actor_id': 'nm3727276'},
#  {'character': 'Tomard', 'actor_id': 'nm4475303'},
#  {'character': 'Tormund Giantsbane', 'actor_id': 'nm1970465'},
#  {'character': 'Trystane Martell', 'actor_id': 'nm4514519'},
#  {'character': 'Tycho Nestoris', 'actor_id': 'nm0309693'},
#  {'character': 'Tyene Sand', 'actor_id': 'nm3065809'},
#  {'character': 'Tyrion Lannister', 'actor_id': 'nm0227759'},
#  {'character': 'Tywin Lannister', 'actor_id': 'nm0001097'},
#  {'character': 'Vala', 'actor_id': 'nm5159884'},
#  {'character': 'Vardis Egen', 'actor_id': 'nm1788152'},
#  {'character': 'Varly', 'actor_id': 'nm1378721'},
#  {'character': 'Viserys Targaryen', 'actor_id': 'nm0516003'},
#  {'character': 'Walda Bolton', 'actor_id': 'nm3531913'},
#  {'character': 'Walder Frey', 'actor_id': 'nm0103195'},
#  {'character': 'Warlock', 'actor_id': 'nm5390029'},
#  {'character': 'Waymar Royce', 'actor_id': 'nm3209935'},
#  {'character': 'Wedding Band', 'actor_id': 'nm1460176'},
#  {'character': 'White Walker', 'actor_id': 'nm1613839'},
#  {'character': 'White Walker', 'actor_id': 'nm1368643'},
#  {'character': 'White Walker', 'actor_id': 'nm0516385'},
#  {'character': 'White Walker #2', 'actor_id': 'nm1872855'},
#  {'character': 'Wight Wildling Girl', 'actor_id': 'nm4422708'},
#  {'character': 'Wildling Rioter', 'actor_id': 'nm8199963'},
#  {'character': 'Will', 'actor_id': 'nm0916037'},
#  {'character': 'Willem Lannister', 'actor_id': 'nm5624523'},
#  {'character': 'Willis Wode', 'actor_id': 'nm4416560'},
#  {'character': 'Wine Merchant', 'actor_id': 'nm0523047'},
#  {'character': 'Winterfell Shepherd', 'actor_id': 'nm0214343'},
#  {'character': 'Wun Wun', 'actor_id': 'nm1613839'},
#  {'character': 'Wyllis', 'actor_id': 'nm4744043'},
#  {'character': 'Xaro Xhoan Daxos', 'actor_id': 'nm1996829'},
#  {'character': 'Yara Greyjoy', 'actor_id': 'nm2247629'},
#  {'character': 'Yezzan zo Qaggaz', 'actor_id': 'nm0162281'},
#  {'character': 'Ygritte', 'actor_id': 'nm3310211'},
#  {'character': 'Yohn Royce', 'actor_id': 'nm0889338'},
#  {'character': 'Yoren', 'actor_id': 'nm0535837'},
#  {'character': 'Young Benjen Stark', 'actor_id': 'nm5502295'},
#  {'character': 'Young Cersei Lannister', 'actor_id': 'nm5309709'},
#  {'character': 'Young Lyanna Stark', 'actor_id': 'nm8108764'},
#  {'character': 'Young Nan', 'actor_id': 'nm1519719'},
#  {'character': 'Young Ned', 'actor_id': 'nm7075019'},
#  {'character': 'Young Ned Stark', 'actor_id': 'nm7509185'},
#  {'character': 'Young Rodrik Cassel', 'actor_id': 'nm7509186'},
#  {'character': 'Zanrush', 'actor_id': 'nm0503319'}]

# %%
# The following code tests loading a single actor after deleting all of the IMDB people.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    # driver.verify_connectivity()
    
    records, summary, keys = driver.execute_query(
        "MATCH (p:Person:IMDB) delete p",
    )

    summary = driver.execute_query(
        "CREATE (:Person:IMDB {name: $name, imdb_id: $imdb_id})",
        name="Alice",
        imdb_id="nm00000"
    ).summary

# %%
print(summary.counters)
# Out:
# {'_contains_updates': True, 'labels_added': 2, 'nodes_created': 1, 'properties_set': 2}

# %% [markdown]
# OK. Now let's load all of the characters.

# %%
# The following code loads all of the IMDB characters after deleting any already in the database.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    # driver.verify_connectivity()
    
    records, summary, keys = driver.execute_query(
        "MATCH (p:Character:IMDB) delete p",
    )

    query = "CREATE (:Character:IMDB {name: $name})"

    for c in characters_to_insert:
        summary = driver.execute_query(
            query,
            name=c["characterName"]
        ).summary
        print("Insert ", c)
# Out:
# Insert  {'characterName': 'Addam Marbrand', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Aegon Targaryen', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Aeron Greyjoy', 'houseName': 'Greyjoy', 'royal': None, 'nickname': 'Damphair', 'kingsguard': None}
# Insert  {'characterName': 'Aerys II Targaryen', 'houseName': 'Targaryen', 'royal': True, 'nickname': 'The Mad King', 'kingsguard': None}
# Insert  {'characterName': 'Akho', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Alliser Thorne', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Alton Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Alys Karstark', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Amory Lorch', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Anguy', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Archmaester Marwyn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Areo Hotah', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Armeca', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Arthur', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Arthur Dayne', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': True}
# Insert  {'characterName': 'Arya Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Baby Sam', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Balon Greyjoy', 'houseName': 'Greyjoy', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Baratheon Guard', 'houseName': 'Baratheon', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Barristan Selmy', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Benjen Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Beric Dondarrion', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Bianca', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Biter', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Black Lorren', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Black Walder Rivers', 'houseName': 'Frey', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Bobono', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Bowen Marsh', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Brandon Stark', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Bran Stark', 'houseName': 'Stark', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Brea', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Brienne of Tarth', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': True}
# Insert  {'characterName': 'Bronn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Brother Ray', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Brynden Tully', 'houseName': 'Tully', 'royal': None, 'nickname': 'Blackfish', 'kingsguard': None}
# Insert  {'characterName': 'Captain of the Archers', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Catelyn Stark', 'houseName': ['Stark', 'Tully'], 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Catspaw Assassin', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Cersei Lannister', 'houseName': ['Lannister', 'Baratheon'], 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Child of the Forest', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Citadel Maester', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Colen of Greenpools', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Craster', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Daario Naharis', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Daenerys Targaryen', 'houseName': 'Targaryen', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Dagmer Cleftjaw', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Daisy', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Davos Seaworth', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Dickon Tarly', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Dongo the Giant', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Donnel Waynwood', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Dontos Hollard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Doran Martell', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Doreah', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Dothraki Bloodrider #1', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Dothraki Bloodrider #2', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Drennan', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Drogon', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Drowned Priest', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Eddard Stark', 'houseName': 'Stark', 'royal': None, 'nickname': 'Ned', 'kingsguard': None}
# Insert  {'characterName': 'Eddison Tollett', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Edmure Tully', 'houseName': 'Tully', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ellaria Sand', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Elia Martell', 'actorName': None, 'actorLink': None, 'houseName': 'Martell', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Eon Hunter', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Euron Greyjoy', 'houseName': 'Greyjoy', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Faceless Man', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Farlen', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Gared', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Gatins', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Gendry', 'houseName': 'Baratheon', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Gerold Hightower', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ghost', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Gilly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Goldcloak', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Goldcloak', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Goldcloak #1', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Goldcloak #2', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Grand Maester Pycelle', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #1', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #2', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #3', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #4', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #5', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #6', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Great Master #7', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Greatjon Umber', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Gregor Clegane', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': 'The Mountain', 'kingsguard': None}
# Insert  {'characterName': 'Greizhen mo Ullhor', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Grenn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Grey Wind', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Grey Worm', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Hallyne', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Handmaid', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Handmaid', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Harald Karstark', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Harry Strickland', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'High Priestess', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'High Septon', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'High Septon', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'High Sparrow', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Hizdahr zo Loraq', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Hodor', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Hoster Tully', 'houseName': 'Tully', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Hot Pie', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Howland Reed', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Hugh of the Vale', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Illyrio Mopatis', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ilyn Payne', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Irri', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Izembaro', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jacks', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jafer Flowers', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jaime Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': 'The Kingslayer', 'kingsguard': True}
# Insert  {'characterName': 'Janos Slynt', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Jaqen H'ghar", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Jaqen's Disguise", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jaremy Rykker', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jeor Mormont', 'houseName': 'Mormont', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jhiqui', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Joffrey Baratheon', 'houseName': 'Baratheon', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jojen Reed', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jon Arryn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jon Snow', 'houseName': ['Stark', 'Targaryen'], 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jonos Bracken', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jorah Mormont', 'houseName': 'Mormont', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Jory Cassel', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Joyeuse Erenford', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Karl Tanner', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Karsi', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kayla', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kegs', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kevan Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Khal Drogo', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Khal Moro', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Khal Rhalko', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'King Joffrey Baratheon Dwarf', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'King Renly Baratheon Dwarf', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'King Robb Stark Dwarf', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'King Stannis Baratheon Dwarf', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "King's Landing Rioter #1", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "King's Landing Rioter #2", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "King's Landing Rioter #3", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kinvara', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kitty Frey', 'houseName': 'Frey', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Knight of House Frey', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Knight of House Lynderly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kovarro', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kraznys mo Nakloz', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Kurleket', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lady', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lady Crane', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lancel Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lannister Captain', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lannister Captain', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lannister Guardsman', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lannister Messenger', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lannister Scout', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lead Dornish Guard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Leaf', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lem Lemoncloak', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Leo Lefford', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lhara', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird #3', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird #4', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird #5', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird #6', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Little Bird #7', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Loboda', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Locke', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lollys Stokeworth', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lommy Greenhands', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Loras Tyrell', 'houseName': 'Tyrell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lord Galbart Glover', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lord Portan', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lord Varys', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lordsport Dockhand', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lothar Frey', 'actorName': None, 'actorLink': None, 'houseName': 'Frey', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Loyal Night's Watchman #1", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Loyal Night's Watchman #2", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lyanna Mormont', 'houseName': 'Mormont', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lyanna Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Lysa Arryn', 'houseName': ['Arryn', 'Tully'], 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mace Tyrell', 'houseName': 'Tyrell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Maester Aemon', 'houseName': 'Targaryen', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Maester Cressen', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Maester Luwin', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Maester Wolkan', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mag the Mighty', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Maggy', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mago', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Male Prostitute', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Malko', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mance Rayder', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mandon Moore', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': True}
# Insert  {'characterName': 'Manservant', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Marei', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Margaery Tyrell', 'houseName': 'Tyrell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Margaery's Handmaiden", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Marillion', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Martyn Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Masha Heddle', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Matthos Seaworth', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Meera Reed', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Meereen Slave Master', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Melessa Tarly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Melisandre', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Merchant Captain', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mero', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Meryn Trant', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mhaegen', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mikken', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mirelle', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mirri Maz Duur', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Missandei', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mord', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mossador', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #1', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #1', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #2', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #2', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #3', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #3', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #4', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Musician #5', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Mycah', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Myranda', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Myrcella Baratheon', 'actorName': None, 'actorLink': None, 'houseName': 'Baratheon', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ned Umber', 'houseName': 'Umber', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watch Deserter", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watch Messenger", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watch Officer", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watch Officer", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watchman", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watchman", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watchman", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watchman #1", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watchman #2", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': "Night's Watchman #2", 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Northman Rioter', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Nymeria', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Nymeria Sand', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Obara Sand', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Oberyn Martell', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Old Nan', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Old Woman Prisoner', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Olenna Tyrell', 'houseName': 'Tyrell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Olly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Olyvar', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Orell', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ornela', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Osha', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Othell Yarwyck', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Othor', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Pentoshi Servant', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Petyr Baelish', 'houseName': None, 'royal': None, 'nickname': 'Littlefinger', 'kingsguard': None}
# Insert  {'characterName': 'Podrick Payne', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': True}
# Insert  {'characterName': 'Polliver', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Prendahl na Ghezn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Pyat Pree', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Pypar', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Qhono', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Qhorin Halfhand', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Qotho', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Quaithe', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Qyburn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rakharo', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ramsay Snow', 'houseName': 'Bolton', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Randyll Tarly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rast', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rattleshirt', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': 'Lord of Bones', 'kingsguard': None}
# Insert  {'characterName': 'Razdal mo Eraz', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Red Keep Stableboy', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Red Priestess', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Red Priestess', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Renly Baratheon', 'houseName': 'Baratheon', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rhaegal', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rhaegar Targaryen', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rhaego', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rhaella Targaryen', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rhaenys Targaryen', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rickard Karstark', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rickard Stark', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rickon Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Robb Stark', 'houseName': 'Stark', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Robert Baratheon', 'houseName': 'Baratheon', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Robett Glover', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Robin Arryn', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rodrik Cassel', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Roose Bolton', 'houseName': 'Bolton', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Rorge', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ros', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Roslin Frey', 'houseName': 'Frey', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Royal Steward', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ryger Rivers', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Salladhor Saan', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Samwell Tarly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Sandor Clegane', 'houseName': None, 'royal': None, 'nickname': 'The Hound', 'kingsguard': None}
# Insert  {'characterName': 'Sansa Stark', 'houseName': 'Stark', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Selyse Baratheon', 'actorName': None, 'actorLink': None, 'houseName': 'Baratheon', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Septa Moelle', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Septa Mordane', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Septa Scolera', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Septa Unella', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Septon', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Septon', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ser Endrew Tarth', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Shae', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Shagga', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Shaggydog', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Shireen Baratheon', 'houseName': 'Baratheon', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Silk King', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Smalljon Umber', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Spice King', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stannis Baratheon', 'houseName': 'Baratheon', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stark Bannerman', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stark Guard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stark Guard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stark Guard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stark Guard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Steelshanks Walton', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stevron Frey', 'houseName': 'Frey', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Stiv', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Styr', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Summer', 'actorName': None, 'actorLink': None, 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Syrio Forel', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Talisa Maegyr', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Talla Tarly', 'houseName': 'Tarly', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ternesio Terys', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'The Bear', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'The Night King', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'The Tickler', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'The Waif', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Thenn Warg', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Theon Greyjoy', 'houseName': 'Greyjoy', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Thin Man', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Thoros of Myr', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Three-Eyed Raven', 'actorName': None, 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Timett', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tobho Mott', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Todder', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tomard', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tommen Baratheon', 'actorName': None, 'actorLink': None, 'houseName': 'Baratheon', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tormund Giantsbane', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Trystane Martell', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tycho Nestoris', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tyene Sand', 'houseName': 'Martell', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tyrion Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Tywin Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Vala', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Vardis Egen', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Varly', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Viserion', 'actorName': None, 'actorLink': None, 'houseName': 'Targaryen', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Viserys Targaryen', 'houseName': 'Targaryen', 'royal': True, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Walda Bolton', 'houseName': ['Bolton', 'Frey'], 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Walder Frey', 'houseName': 'Frey', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wallen', 'actorLink': None, 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Warlock', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Waymar Royce', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wedding Band', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'White Walker', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'White Walker', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'White Walker', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'White Walker #2', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wight Wildling Girl', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wildling Rioter', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Will', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Willem Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Willis Wode', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wine Merchant', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Winterfell Shepherd', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wun Wun', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Wyllis', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Xaro Xhoan Daxos', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Yara Greyjoy', 'houseName': 'Greyjoy', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Yezzan zo Qaggaz', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Ygritte', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Yohn Royce', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Yoren', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Benjen Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Cersei Lannister', 'houseName': 'Lannister', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Lyanna Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Nan', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Ned', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Ned Stark', 'houseName': 'Stark', 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Young Rodrik Cassel', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}
# Insert  {'characterName': 'Zanrush', 'houseName': None, 'royal': None, 'nickname': None, 'kingsguard': None}

# %%
# The following code loads all of the IMDB actors after deleting any already in the database.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    # driver.verify_connectivity()
    
    records, summary, keys = driver.execute_query(
        "MATCH (p:Person:IMDB) delete p",
    )

    query = "CREATE (:Person:IMDB {name: $name, imdb_id: $imdb_id})"

    for a in actors_to_insert:
        try:
            summary = driver.execute_query(
                query,
                name=a["name"],
                imdb_id=a.get("imdb_id", None)
            ).summary
        except Exception as e:
            print("That stinks.")
# Out:
# That stinks.
# That stinks.
# That stinks.
# That stinks.

# %%
# The following code loads all of the IMDB actors and character relationships after deleting any already in the database.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    # driver.verify_connectivity()
    
    
    query = """
        MATCH (p:Person:IMDB {imdb_id: $imdb_id}), (c:Character:IMDB {name: $character_name})
        CREATE (c)-[:PLAYED_BY]->(p)
    """

    for r in relationships_to_insert:
        try:
            summary = driver.execute_query(
                query,
                character_name=r["character"],
                imdb_id=r["actor_id"]
            ).summary
        except Exception as e:
            print("Cloud not link", r)
