# %% [markdown]
# <span style="font-size: 36px;">W4111_Fall_2024_003 - Introduction to Databases:<br>Homework 3B<br>Game of Thrones Data and IMDB</span>

# %% [markdown]
# Nathan Gong

# %% [markdown]
# # Overview

# %% [markdown]
# The non-programming track builds data insight/support notebook for HW4b and the programming track builds a simple full stak web application. Provide the data model the applications need requires more processing after the initial load. HW3b is common to both tracks and provides the data for the final practical HW. The final data model/database has information in three separate databases:
# 1. MySQL
# 2. Neo4j
# 3. MongoDB
#
# The conceptual data model is:
#
# | <img src="conceptual_data_model.jpg" > |
# | :---: |
# | __Conceptual Data Model__ |
#
# In the data load setup notebook, we "loaded data." In this notebook, we process, cleanup and link the data. This is necessary for the data insight and operational applications. __Note: I provide the DDL or definition for the "to be" tables, etc.__
#
# | <img src="data-janitor.jpg" > |
# | :---: |
# | __The Janitor__ |
#
# The sections and subsections below will:
# 1. Explain the entities and relationships.
# 2. Explain the data engineering tasks.
# 3. Provide a lot of helper code and provide some tests you can run while doing the work.
#
#
# __Code cells that students must complete contain a comment of the form "#TODO Student."__

# %% [markdown]
# # Initialize Environment

# %% [markdown]
# __Execute the cells in this section. The cells are the same as from the data loading notebook I prepared for you.__

# %% [markdown]
# ## General Python Packages

# %%
import copy

# %%
import json

# %%
import pandas

# %%
# You should have installed the packages for previous homework assignments
#
import pymysql
import sqlalchemy

# %%
# You may have to do %pip installs to use the packages below.
#
# %pip install "pymongo[srv]"
#
import pymongo

# %%
# You may have to do %pip installs to use the packages below.
#
# %pip install neo4j
#
import neo4j

# %%
import numpy

# %% [markdown]
# ## MySQL

# %% [markdown]
# ### ipython-sql

# %%
# You have installed and configured ipython-sql for previous assignments.
# https://pypi.org/project/ipython-sql/
#
# %load_ext sql

# %%
# Make sure that you set these values to the correct values for your installation and 
# configuration of MySQL
#
db_user = "root"
db_password = "dbuserdbuser"

# %%
# Create the URL for connecting to the database.
# Do not worry about the local_infile=1, I did that for wizard reasons that you should not have to use.
#
db_url = f"mysql+pymysql://{db_user}:{db_password}@localhost?local_infile=1"

# %%
# Initialize ipython-sql
#
# %sql $db_url

# %%
# Your answer will be different based on the databases that you have created on your local MySQL instance.
#
# %sql show databases
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 9 rows affected.
# [('classicmodels',),
#  ('db_book',),
#  ('f24_project',),
#  ('hw1b_ng2695',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('w4111_hw2_ng2695',)]

# %% [markdown]
# ### PyMySQL

# %%
default_mysql_conn = pymysql.connect(
    user=db_user,
    password=db_password,
    host="localhost",
    port=3306,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True
)

# %%
def get_mysql_con(
    user=db_user,
    password=db_password,
    host="localhost",
    port=3306,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True):

    result = pymysql.connect(
        user=db_user,
        password=db_password,
        host="localhost",
        port=3306,
        cursorclass=pymysql.cursors.DictCursor,
        autocommit=True
    )

    return result

# %%
cur = default_mysql_conn.cursor()

result = cur.execute("show databases;");
result = cur.fetchall()
result_df = pandas.DataFrame(result)
result_df
# Out:
#              Database
# 0       classicmodels
# 1             db_book
# 2         f24_project
# 3         hw1b_ng2695
# 4  information_schema
# 5               mysql
# 6  performance_schema
# 7                 sys
# 8    w4111_hw2_ng2695

# %% [markdown]
# ### SQLAlchemy

# %%
from sqlalchemy import create_engine
default_engine = create_engine(db_url)

# %%
result_df = pandas.read_sql(
    "show databases", con=default_engine
)
result_df
# Out:
#              Database
# 0       classicmodels
# 1             db_book
# 2         f24_project
# 3         hw1b_ng2695
# 4  information_schema
# 5               mysql
# 6  performance_schema
# 7                 sys
# 8    w4111_hw2_ng2695

# %% [markdown]
# ## MongoDB Atlas

# %%
# TODO Student -- This should be the same as what you provided in the data loading notebook
#
# You will need to replace with your settings.
#
mongo_db_pw="3ZOGE7vkjPRB2io0"
mongodb_user="ng2695"

# %%
# TODO Student -- This should be the same as what you provided in the data loading notebook
#
# You can get the URL and info below from looking at the connect instructions for you MongoDB Atlas instance.
#
mongo_db_url = f"mongodb+srv://{mongodb_user}:{mongo_db_pw}@w4111hw.aajrd.mongodb.net/?retryWrites=true&w=majority&appName=W4111HW"

# %%
mongo_client = pymongo.MongoClient(mongo_db_url)

# %%
# Your list of databases will be different.
#
list(mongo_client.list_databases())
# Out:
# [{'name': 'f24_project_got', 'sizeOnDisk': 499712, 'empty': False},
#  {'name': 'sample_mflix', 'sizeOnDisk': 128372736, 'empty': False},
#  {'name': 'admin', 'sizeOnDisk': 393216, 'empty': False},
#  {'name': 'local', 'sizeOnDisk': 8016089088, 'empty': False}]

# %% [markdown]
# ## Neo4j

# %%
# TODO Student -- This should be the same as what you provided in the data loading notebook

# You need to have created a Neo4j Aura DB with a user ID and information.
# Please make sure you copied the information for connecting.
# You can download this information when you create your instance.
# The download will be a text file with the information below.
# You will have to modify the file you download to wrap the strings with "
#
NEO4J_URI="neo4j+ssc://152bd215.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="Q1DShtnmlomcYoqFIT1_rv3XL4t-4ooCmWvKZUzWelc"
AURA_INSTANCEID="152bd215"
AURA_INSTANCENAME="Instance01"

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
URI = NEO4J_URI
AUTH = (NEO4J_USERNAME, NEO4J_PASSWORD)

with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()

# %% [markdown]
# __Note:__ You should have already created a Neo4j account and loaded the Movie Database.

# %%
# The following code assumes that you followed the tutorial for the Movie Database and loaded the data.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    # driver.verify_connectivity()
    
    records, summary, keys = driver.execute_query(
        "MATCH (p:Person) where p.name='Tom Hanks' RETURN p.name AS name, p.born as birth_year ",
    )
    
    # Loop through results and do something with them
    # There is probably an easier way to do this.
    #
    person_records = []
    for person in records:
        new_p = dict(person)
        person_records.append(new_p)
    
    # Summary information
    print("The query `{query}` returned {records_count} records in {time} ms.".format(
        query=summary.query, records_count=len(records),
        time=summary.result_available_after,
    ))
# Out:
# The query `MATCH (p:Person) where p.name='Tom Hanks' RETURN p.name AS name, p.born as birth_year ` returned 1 records in 24 ms.

# %%
results_df = pandas.DataFrame(person_records)
results_df.head(10)
# Out:
#         name  birth_year
# 0  Tom Hanks        1956

# %% [markdown]
# # IMDB

# %% [markdown]
# ## Overview

# %% [markdown]
# __You should have created f24_project during data loading.__

# %%
# %sql use f24_project;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
# []

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 14 rows affected.
# [('got_episode_title_basics',),
#  ('got_episodes',),
#  ('got_names_episodes',),
#  ('name_basics',),
#  ('name_basics_fixed',),
#  ('nconst_profession',),
#  ('neo4j_characters',),
#  ('temp_relationships',),
#  ('title_basics',),
#  ('title_basics_fixed',),
#  ('title_principals',),
#  ('title_principals_fixed',),
#  ('title_ratings',),
#  ('valid_professions',)]

# %% [markdown]
# These tables need scheme improvement. The improvements involve changes to individual tables, splitting tables and linking tables. In the larger, original datasets, indexes are crucial. This is less of an issue in the reduced dataset, but we should create indexes anyway.
#
# We will start improving and refactoring individual tables.

# %% [markdown]
# ## name_basics

# %%
# %sql select * from name_basics limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 10 rows affected.
# [('nm0389698', 'B.J. Hogg', 1955.0, 2020.0, 'actor,music_department', 'tt0986233,tt1240982,tt0970411,tt0944947'),
#  ('nm0269923', 'Michael Feast', 1946.0, None, 'actor,composer,soundtrack', 'tt0120879,tt0472160,tt0362192,tt0810823'),
#  ('nm0727778', 'David Rintoul', 1948.0, None, 'actor,archive_footage', 'tt1139328,tt4786824,tt6079772,tt1007029'),
#  ('nm6729880', 'Chuku Modu', 1990.0, None, 'actor,writer,producer', 'tt4154664,tt2674426,tt0944947,tt6470478'),
#  ('nm0853583', 'Owen Teale', 1961.0, None, 'actor,writer,archive_footage', 'tt0102797,tt0944947,tt0485301,tt0462396'),
#  ('nm0203801', 'Karl Davies', 1982.0, None, 'actor,producer', 'tt3428912,tt7366338,tt0944947,tt12879632'),
#  ('nm8257864', 'Megan Parkinson', None, None, 'actress,director,writer', 'tt0944947,tt26934073,tt4276618,tt6636246'),
#  ('nm0571654', 'Fintan McKeown', None, None, 'actor', 'tt0112178,tt0110116,tt0166396,tt0944947'),
#  ('nm1528121', 'Philip McGinley', 1981.0, None, 'actor,archive_footage', 'tt0944947,tt1446714,tt0053494,tt4015216'),
#  ('nm0000980', 'Jim Broadbent', 1949.0, None, 'actor,writer,producer', 'tt0203009,tt1431181,tt1007029,tt0425112')]

# %% [markdown]
# There are four obvious problems with this schema:
# 1. ```primaryName``` is not an atomic domain.
# 2. ```primaryProfession``` is a multi-valued attribute, and the attribute values come from a fixed domain. The values are not arbitrary strings. "Canary" and "Battleship" are not professions in this context.
# 3. ```knownForTitles``` is also multi-valued and also has a foreign key dependency on other tables.
# 4. ```birthYear``` and ```deathYear``` are floats/doubles because we used Pandas for import, and Pandas import "detects" numbers.
#
# Our first tasks are ```primaryName, primaryProfession, birthYear``` and ```deathYear.``` We are not going to use ```knownForTitles``` in the project or homeworks.

# %% [markdown]
# A little examination of ```primaryName``` indicates that the format is complex and may have middle names, nicknames, titles, ... ... This is hard to fix in SQL or stored procedures. So, we will use a heuristic library -- [nameparser.](https://pypi.org/project/nameparser/)

# %%
#
# %pip install nameparser
#
from nameparser import HumanName

# %%
funny_name = "Dr. Donald F. (Snowball) Ferguson, III"

# %%
cool_name = HumanName(funny_name)

# %%
cool_name.as_dict()
# Out:
# {'title': 'Dr.',
#  'first': 'Donald',
#  'middle': 'F.',
#  'last': 'Ferguson',
#  'suffix': 'III',
#  'nickname': 'Snowball'}

# %% [markdown]
# The following is an improvement in the table schema that is ["good enough for government work."](https://en.wiktionary.org/wiki/close_enough_for_government_work)

# %%
# %%sql
#
# drop table if exists f24_project.nconst_profession;
# drop table if exists f24_project.title_principals_fixed;
# drop table if exists f24_project.name_basics_fixed;
#
# create table if not exists f24_project.name_basics_fixed
# (
#     nconst      varchar(16) not null
#         primary key,
#     title       varchar(32) null,
#     first_name  varchar(64) null,
#     middle_name varchar(64) null,
#     last_name   varchar(64) not null,
#     suffix      varchar(32) null,
#     nickname    varchar(64) null,
#     birth_year  int         null,
#     death_year  int         null,
#     constraint check_name
#         check ((`death_year` >= `birth_year`) or (`death_year` is null) or (`birth_year` is null))
# );
#
# create index name_basics_fixed_last_name_first_name_index
#     on f24_project.name_basics_fixed (last_name, first_name);
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# The first task is to heuristically fix ```primaryName``` and load into ```name_basics_fixed```

# %%
# TODO Student -- Students must implement this function.
#
def insert_name_basics_fixed(nconst, last_name,
                             title=None, first_name=None, middle_name=None, suffix=None, nickname=None,
                             birth_year=None, death_year=None):
    """
    The input are the column values for the name_basics_fixed table. The function does the insert.
    :param nconst: IMDB nconst from name_basics
    :param last_name: Last name value from HumanName
    :param title: Title value from HumanName
    :param first_name: First name value from HumanName
    :param middle_name: Middle name value from HumanName
    :param suffix: Suffix value from HumanName
    :param nickname: Nickname value from HumanName
    :param birth_year: birthYear from name_basics
    :param death_year: deathYear from name_basics
    :return:The number of rows inserted, which should 1.
    """

    # The number of rows inserted.
    result = 0

    # TODO Student -- Your code goes here.
    with get_mysql_con() as con:
        cursor = con.cursor()
        sql = """
            insert into f24_project.name_basics_fixed 
            values (%s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        values = (nconst, title, first_name, middle_name, last_name, suffix, nickname, birth_year, death_year)
        result = cursor.execute(sql, values)
        con.commit()

    return result

# %% [markdown]
# The following is a simple test of the function you implemented above.

# %%
try:
    result = insert_name_basics_fixed(
        "nm999",
        "Ferguson",
        "Dr.", "Donald", "F.", "III", "Snowball",
        1920, 2000)
    print("Insert result = ", result)
except Exception as e:
    print("Oops, e = ", e)
# Out:
# Insert result =  1

# %%
# %sql select * from f24_project.name_basics_fixed where last_name='Ferguson'
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 1 rows affected.
# [('nm999', 'Dr.', 'Donald', 'F.', 'Ferguson', 'III', 'Snowball', 1920, 2000)]

# %%
# Let's get rid of the test data.
#
# %sql delete from f24_project.name_basics_fixed where nconst='nm999';
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 1 rows affected.
# []

# %% [markdown]
# The following function will load the fixed table from the original table. It calls the function you wrote above.

# %%
def load_name_basics_fixed(delete_existing_data=False):
    """
    This function loads name_basics_fixed by calling the previous function insert_name_basics_fixed. If delete_existing_data is True,
    the function deletes the existing rows before inserting the new rows.
    """

    if delete_existing_data:
        # Note that the "%sql" only works in an ipython-note and does not work in python in general.
        # Things like %xyz are notebook magics.
        #
        # %sql delete from name_basics_fixed;

    # The with xxx() is common in python for connections, opening files, ... ...
    # Python automatically calls close() when the code exits the with block.
    #
    with get_mysql_con() as con:
        
        cursor = con.cursor()

        # This statement will query the original name_basics and produce a result set. Since it used a cursor,
        # the result is a cursor on the query result set. The data does not transfer from the DBMS to the python
        # runtime until you fetch the data. This is the behavior of cursors.
        #
        # The code casts the dates from float to unsigned, which is a funny way to say integer.
        #
        # It turns out that either the original data or the subsetting work to prepare the data
        # created duplicates. So, we use distinct.
        #
        sql = """
            select distinct 
                nconst, primaryName, cast(birthYear as unsigned) as birthYear, cast(deathYear as unsigned) as deathYear,
                primaryProfession, knownForTitles
                from f24_project.name_basics
        """

        # Execute the query and position the cursor.
        no_of_rows = cursor.execute(sql)

        # Count the number of rows inserted.
        rows_inserted = 0

        # We have used fetchall() in examples. This gets all of the data from the DBMS and loads into the
        # calling application. If the result set is huge, this call can swamp the network, calling application,
        # ... Since the notebook display is in a browser, huge datasets will cause the browser to lock up or crash.
        # So, we are going to "page through the result" and fetch in chunks.
        #
        done = False
        while not done:

            # Fetch a page of rows.
            the_names = cursor.fetchmany(20)

            # For each row in the page.
            for t in the_names:

                # Heuristically map the primaryName to the new format.
                #
                mapped_name = HumanName(t['primaryName']).as_dict()
                to_insert = dict()
                to_insert['title'] = mapped_name.get('title', None)
                to_insert['first_name'] = mapped_name.get('first', None)
                to_insert['middle_name'] = mapped_name.get('middle', None)
                to_insert['last_name'] = mapped_name.get('last', None)
                to_insert['suffix'] = mapped_name.get('suffix', None)
                to_insert['nickname'] = mapped_name.get('nickname', None)

                # Insert the row into name_basics_fixed in the new format.
                # "result" will be the number of rows inserted.
                try:
                    result = insert_name_basics_fixed(
                        t['nconst'],
                        to_insert['last_name'],
                        to_insert['title'],
                        to_insert['first_name'],
                        to_insert['middle_name'],
                        to_insert['suffix'],
                        to_insert['nickname'],
                        t['birthYear'],
                        t['deathYear']
                    )
                except Exception as e:
                    print("Exception happened, e = ", "\nfor row", e, t)

                # If we did not insert one row, something happened.
                if result != 1:
                    print("Something weird happened with ", t)

                # Count the number of rows inserted.
                rows_inserted += result

            # If we did not get a full page of data, we processed the last page.
            if len(the_names) < 20:
                done = True

        print("Read ", no_of_rows, "Inserted", rows_inserted)

# %%
# Call the function.
load_name_basics_fixed(delete_existing_data=True)
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
# Read  348 Inserted 348

# %%
# TODO Student. Test the load.
#
# %sql use f24_project;

# %sql select * from name_basics_fixed limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 10 rows affected.
# [('nm0000293', '', 'Sean', '', 'Bean', '', '', 1959, None),
#  ('nm0000596', '', 'Jonathan', '', 'Pryce', '', '', 1947, None),
#  ('nm0000980', '', 'Jim', '', 'Broadbent', '', '', 1949, None),
#  ('nm0001097', '', 'Charles', '', 'Dance', '', '', 1946, None),
#  ('nm0001290', '', 'Richard', 'E.', 'Grant', '', '', 1957, None),
#  ('nm0001354', '', 'Ciarán', '', 'Hinds', '', '', 1953, None),
#  ('nm0001671', '', 'Diana', '', 'Rigg', '', '', 1938, 2020),
#  ('nm0002103', '', 'Julian', '', 'Glover', '', '', 1935, None),
#  ('nm0004355', '', 'Roger', '', 'Ashton-Griffiths', '', '', 1957, None),
#  ('nm0004692', '', 'Mark', '', 'Addy', '', '', 1964, None)]

# %% [markdown]
# ## primaryProfession

# %% [markdown]
# The common technique for handling multi-valued attributes is to create a second table with an entry for each value
# and a foreign key to the original table. The following SQL DDL creates two tables:
# 1. ```valid_professions``` contains the allowed value for ```primaryProfession.``` If there were a few allowed values, we could use an ```ENUM.``` Since there are many, we use a "lookup table."
# 2. ```nconst_professions``` is an associative entity between a ```name_basics_fixed``` and the ```professions.```

# %%
# %%sql
#
# use f24_project;
#
#
# drop table if exists f24_project.nconst_profession;
# drop table if exists f24_project.valid_professions;
#
#
# create table if not exists f24_project.valid_professions
# (
#     profession_id    int auto_increment
#         primary key,
#     profession_label varchar(32) not null,
#     constraint valid_professions_pk
#         unique (profession_label)
# );
#
# create table if not exists f24_project.nconst_profession
# (
#     nconst        varchar(16) not null,
#     profession_id int         not null,
#     primary key (nconst, profession_id),
#     constraint nconst_profession_name_basics_fixed_nconst_fk
#         foreign key (nconst) references f24_project.name_basics_fixed (nconst),
#     constraint nconst_profession_valid_professions_profession_id_fk
#         foreign key (profession_id) references f24_project.valid_professions (profession_id)
# );
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# In the cells below, you must load ```valid_professions``` and ```nconst_profession.```
#
# __You must use SQL. You cannot use python, Pandas, ... ...__
#
# Your SQL can assume that there are at most 3 primaryProfessions. The following SQL validates the assumption.

# %%
# %%sql
#
# with one as (
#     select
#         primaryProfession,
#         replace(primaryProfession, ",", "") as without_delimmeter,
#         (length(primaryProfession) - length(replace(primaryProfession, ",", "")) + 1) as no_of_professions
#     from name_basics
# )
# select * from one order by no_of_professions desc limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 10 rows affected.
# [('actor,miscellaneous,stunts', 'actormiscellaneousstunts', 3),
#  ('actor,composer,soundtrack', 'actorcomposersoundtrack', 3),
#  ('assistant_director,actor,miscellaneous', 'assistant_directoractormiscellaneous', 3),
#  ('actor,writer,producer', 'actorwriterproducer', 3),
#  ('actor,writer,archive_footage', 'actorwriterarchive_footage', 3),
#  ('actress,soundtrack,archive_footage', 'actresssoundtrackarchive_footage', 3),
#  ('actress,director,writer', 'actressdirectorwriter', 3),
#  ('actor,stunts,miscellaneous', 'actorstuntsmiscellaneous', 3),
#  ('actor,director,writer', 'actordirectorwriter', 3),
#  ('actor,writer,producer', 'actorwriterproducer', 3)]

# %%
# %%sql
#
# /*
#     TODO Student -- Put your SQL below.
# */
#
# insert into f24_project.valid_professions (profession_label)
# with recursive split_strings as (
#     select
#         substring_index(primaryProfession, ',', 1) as part,
#         substring(primaryProfession, length(substring_index(primaryProfession, ',', 1)) + 2) as remaining_string
#     from name_basics
#     where primaryProfession is not null
#     union all
#     select
#         substring_index(remaining_string, ',', 1),
#         substring(remaining_string, length(substring_index(remaining_string, ',', 1)) + 2)
#     from split_strings
#     where remaining_string != ''
# )
# select distinct part from split_strings where part != '';
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 32 rows affected.
# []

# %%
# %%sql
#
# /*
#     TODO Student -- Put your SQL below.
# */
#
# insert ignore into f24_project.nconst_profession (nconst, profession_id)
# with recursive split_strings as (
#     select
#         nb.nconst,
#         substring_index(nb.primaryProfession, ',', 1) as part,
#         substring(nb.primaryProfession, length(substring_index(nb.primaryProfession, ',', 1)) + 2) as remaining_string
#     from f24_project.name_basics nb
#     where nb.primaryProfession is not null
#     union all
#     select
#         nb.nconst,
#         substring_index(ss.remaining_string, ',', 1) as part,
#         substring(ss.remaining_string, length(substring_index(ss.remaining_string, ',', 1)) + 2) as remaining_string
#     from split_strings ss
#     join f24_project.name_basics nb on ss.nconst = nb.nconst
#     where ss.remaining_string != ''
# )
# select ss.nconst, vp.profession_id from split_strings ss join f24_project.valid_professions vp
# on ss.part = vp.profession_label where ss.part != '';
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 734 rows affected.
# []

# %% [markdown]
# Now we can do a little test.

# %%
# %%sql
#
# with one as (
#     select
#         *
#     from
#         name_basics_fixed join nconst_profession using(nconst)
# ),
#     two as (
#         select nconst, profession_id from name_basics_fixed join nconst_profession using(nconst)
#     ),
# three as (
#     select two.nconst, group_concat(profession_label) as
#         all_professions from two join valid_professions using(profession_id) group by nconst
#     )
# select nconst, primaryProfession, three.all_professions from three join name_basics using(nconst)
#     order by nconst
# limit 20;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 20 rows affected.
# [('nm0000293', 'actor,producer,animation_department', 'actor,animation_department,producer'),
#  ('nm0000596', 'actor,producer,soundtrack', 'actor,producer,soundtrack'),
#  ('nm0000980', 'actor,writer,producer', 'actor,writer,producer'),
#  ('nm0001097', 'actor,producer,director', 'actor,producer,director'),
#  ('nm0001290', 'actor,director,writer', 'actor,director,writer'),
#  ('nm0001354', 'actor,soundtrack,archive_footage', 'actor,soundtrack,archive_footage'),
#  ('nm0001671', 'actress,costume_department,costume_designer', 'costume_department,costume_designer,actress'),
#  ('nm0002103', 'actor,soundtrack,archive_footage', 'actor,soundtrack,archive_footage'),
#  ('nm0004355', 'actor,writer,director', 'director,actor,writer'),
#  ('nm0004692', 'actor,music_department,soundtrack', 'actor,soundtrack,music_department'),
#  ('nm0015382', 'actor,director,writer', 'actor,director,writer'),
#  ('nm0019885', 'actor,producer,soundtrack', 'actor,soundtrack,producer'),
#  ('nm0050520', 'actor,miscellaneous', 'miscellaneous,actor'),
#  ('nm0050959', 'actor,producer,soundtrack', 'soundtrack,actor,producer'),
#  ('nm0057965', 'actor,miscellaneous', 'actor,miscellaneous'),
#  ('nm0064155', 'actor,director,writer', 'director,actor,writer'),
#  ('nm0065874', 'actor,archive_footage', 'actor,archive_footage'),
#  ('nm0072855', 'actor', 'actor'),
#  ('nm0087432', 'actor,archive_footage', 'archive_footage,actor'),
#  ('nm0103195', 'actor,location_management,soundtrack', 'location_management,soundtrack,actor')]

# %% [markdown]
# ## knownForTitles

# %% [markdown]
# I think you have had enough fun with ```name_basics``` for now.

# %% [markdown]
# ## title_basics

# %% [markdown]
# We can find the mapping of actors to shows using ```name_basics_fixed, title_principals``` and ```title_nasics.```
#
# For bringing together some interesting information, we are not going to be concerned about some of the fields.
#
# The following script does the subsetting and cleanup for you so that you do not need to do so.

# %%
# %%sql
#
# drop table if exists title_principals_fixed;
# drop table if exists title_basics_fixed;
#
# /*
#     Create the fixed title_principals_fixed as just the columns that interest us.
# */
# create table title_principals_fixed as select distinct nconst, tconst from title_principals;
#
# /*
#     Add a primary key to ensure we only connect a name_basics_fixed to a title_basics_fixed one time.
# */
# alter table title_principals_fixed
#     modify nconst varchar(16) null;
# alter table title_principals_fixed
#     modify tconst varchar(16) null;
# alter table title_principals_fixed
#     add constraint title_principals_fixed_pk
#         primary key (nconst, tconst);
#
# /*
#     Creating the primary key gives us an index for joining with name_basics_fixed.
#     Add an index for joining with title_basics_fixed
# */
# create index title_principals_fixed_tconst_index
#     on title_principals_fixed (tconst);
#
# /*
#     Get the interesting columns from title_basics
# */
# create table title_basics_fixed as
#     select tconst,
#            primaryTitle as primary_title,
#            originalTitle as original_title,
#            startYear as start_year,
#            endYear as end_year,
#         runtimeMinutes as runtime_minutes
#     from title_basics;
#
# /*
#     Set a primary key.
# */
# alter table title_basics_fixed
#     modify tconst varchar(16) null;
# alter table title_basics_fixed
#     add constraint title_basics_fixed_pk
#         primary key (tconst);
#
# /*
#     Change the doubles to int. We loaded with Pandas which maps numbers to doubles.
# */
# alter table title_basics_fixed
#     modify start_year int null;
# alter table title_basics_fixed
#     modify end_year int null;
#
# /*
#     Add foreign keys in the associative entity.
# */
# alter table title_principals_fixed
#     add constraint title_principals_fixed_title_basics_fixed_tconst_fk
#         foreign key (tconst) references title_basics_fixed (tconst);
# alter table title_principals_fixed
#     add constraint title_principals_fixed_title_basics_fixed_nconst_fk
#         foreign key (nconst) references name_basics_fixed (nconst);
#
# /*
#     If I got that correct, it was a miracle.
# */
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 32427 rows affected.
# 32427 rows affected.
# 32427 rows affected.
# 0 rows affected.
# 0 rows affected.
# 29058 rows affected.
# 29058 rows affected.
# 0 rows affected.
# 29058 rows affected.
# 29058 rows affected.
# 32427 rows affected.
# 32427 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# # Game of Thrones

# %% [markdown]
# ## Overview

# %% [markdown]
# In IMDB, we know which actors were in which "episodes."
#
#
# In the load of MongoDB we have information about episodes.
#
#
# Let's build a table of the form:
# - ```tconst, primary_title``` from ```title_basics_fixed```
# - ```seasonNum, episodeNum``` from ```episodes``` in MongodDB.
#
#
# You will do this in 3 steps.
# 1. Create a temporary table ```got_episodes``` in MySQL of the form ```tconst, seasonNum, episodesNum``` getting information from your MongoDB database.<br><br>
# 3. Create a table ```got_imdb_title_basics``` by joining ```title_basics_fixed``` and the temporary table.<br><br>
# 4. Do some cleanup of the resulting table.

# %% [markdown]
# ## Temporary Table ```got_episodes```

# %% [markdown]
# The first step is to write an aggregation. Your data loading notebook had an example.
#
# Let's refresh our MongoDB connection and then write the aggregation. You implement your aggregation below.
#
# To help, here is my answer.
#
# | <img src="aggregation_1.jpg"> |
# | :---: |
# | __GoT Episode Summary__ |

# %%
mongo_client = pymongo.MongoClient(mongo_db_url)

# %%
# TODO Student -- Write your aggregation here. See below to see what the answer looks like.
#
# Aggregation pipeline
#
pipeline = [
    {
        "$project": {
            "_id": 0,
            "season_num": "$seasonNum",
            "episode_num": "$episodeNum",
            "episode_title": "$episodeTitle",
            "tconst": {
                "$arrayElemAt": [
                    {"$split": ["$episodeLink", "/"]}, 
                    2
                ]
            }
        }
    }
]

# Execute the aggregation pipeline
result = mongo_client.f24_project_got.episodes.aggregate(pipeline)

# %%
# Load into a dataframe and show your result.
#
result_df = pandas.DataFrame(list(result))
result_df
# Out:
#     season_num  episode_num                          episode_title     tconst
# 0            1            1                       Winter Is Coming  tt1480055
# 1            1            2                          The Kingsroad  tt1668746
# 2            1            3                              Lord Snow  tt1829962
# 3            1            4  Cripples, Bastards, and Broken Things  tt1829963
# 4            1            5                  The Wolf and the Lion  tt1829964
# ..         ...          ...                                    ...        ...
# 68           8            2         A Knight of the Seven Kingdoms  tt6027908
# 69           8            3                         The Long Night  tt6027912
# 70           8            4                 The Last of the Starks  tt6027914
# 71           8            5                              The Bells  tt6027916
# 72           8            6                        The Iron Throne  tt6027920
#
# [73 rows x 4 columns]

# %%
# Save in the temporary table.
#
result_df.to_sql(
    "got_episodes", schema="f24_project", if_exists="replace", index=False, con=default_engine
)
# Out:
# 73

# %%
# %sql select * from f24_project.got_episodes;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 73 rows affected.
# [(1, 1, 'Winter Is Coming', 'tt1480055'),
#  (1, 2, 'The Kingsroad', 'tt1668746'),
#  (1, 3, 'Lord Snow', 'tt1829962'),
#  (1, 4, 'Cripples, Bastards, and Broken Things', 'tt1829963'),
#  (1, 5, 'The Wolf and the Lion', 'tt1829964'),
#  (1, 6, 'A Golden Crown', 'tt1837862'),
#  (1, 7, 'You Win or You Die', 'tt1837863'),
#  (1, 8, 'The Pointy End', 'tt1837864'),
#  (1, 9, 'Baelor', 'tt1851398'),
#  (1, 10, 'Fire and Blood', 'tt1851397'),
#  (2, 1, 'The North Remembers', 'tt1971833'),
#  (2, 2, 'The Night Lands', 'tt2069318'),
#  (2, 3, 'What Is Dead May Never Die', 'tt2070135'),
#  (2, 4, 'Garden of Bones', 'tt2069319'),
#  (2, 5, 'The Ghost of Harrenhal', 'tt2074658'),
#  (2, 6, 'The Old Gods and the New', 'tt2085238'),
#  (2, 7, 'A Man Without Honor', 'tt2085239'),
#  (2, 8, 'The Prince of Winterfell', 'tt2085240'),
#  (2, 9, 'Blackwater', 'tt2084342'),
#  (2, 10, 'Valar Morghulis', 'tt2112510'),
#  (3, 1, 'Valar Dohaeris', 'tt2178782'),
#  (3, 2, 'Dark Wings, Dark Words', 'tt2178772'),
#  (3, 3, 'Walk of Punishment', 'tt2178802'),
#  (3, 4, 'And Now His Watch Is Ended', 'tt2178798'),
#  (3, 5, 'Kissed by Fire', 'tt2178788'),
#  (3, 6, 'The Climb', 'tt2178812'),
#  (3, 7, 'The Bear and the Maiden Fair', 'tt2178814'),
#  (3, 8, 'Second Sons', 'tt2178806'),
#  (3, 9, 'The Rains of Castamere', 'tt2178784'),
#  (3, 10, 'Mhysa', 'tt2178796'),
#  (4, 1, 'Two Swords', 'tt2816136'),
#  (4, 2, 'The Lion and the Rose', 'tt2832378'),
#  (4, 3, 'Breaker of Chains', 'tt2972426'),
#  (4, 4, 'Oathkeeper', 'tt2972428'),
#  (4, 5, 'First of His Name', 'tt3060856'),
#  (4, 6, 'The Laws of Gods and Men', 'tt3060910'),
#  (4, 7, 'Mockingbird', 'tt3060876'),
#  (4, 8, 'The Mountain and the Viper', 'tt3060782'),
#  (4, 9, 'The Watchers on the Wall', 'tt3060858'),
#  (4, 10, 'The Children', 'tt3060860'),
#  (5, 1, 'The Wars to Come', 'tt3658012'),
#  (5, 2, 'The House of Black and White', 'tt3846626'),
#  (5, 3, 'High Sparrow', 'tt3866836'),
#  (5, 4, 'Sons of the Harpy', 'tt3866838'),
#  (5, 5, 'Kill the Boy', 'tt3866840'),
#  (5, 6, 'Unbowed, Unbent, Unbroken', 'tt3866842'),
#  (5, 7, 'The Gift', 'tt3866846'),
#  (5, 8, 'Hardhome', 'tt3866850'),
#  (5, 9, 'The Dance of Dragons', 'tt3866826'),
#  (5, 10, "Mother's Mercy", 'tt3866862'),
#  (6, 1, 'The Red Woman', 'tt3658014'),
#  (6, 2, 'Home', 'tt4077554'),
#  (6, 3, 'Oathbreaker', 'tt4131606'),
#  (6, 4, 'Book of the Stranger', 'tt4283016'),
#  (6, 5, 'The Door', 'tt4283028'),
#  (6, 6, 'Blood of My Blood', 'tt4283054'),
#  (6, 7, 'The Broken Man', 'tt4283060'),
#  (6, 8, 'No One', 'tt4283074'),
#  (6, 9, 'Battle of the Bastards', 'tt4283088'),
#  (6, 10, 'The Winds of Winter', 'tt4283094'),
#  (7, 1, 'Dragonstone', 'tt5654088'),
#  (7, 2, 'Stormborn', 'tt5655178'),
#  (7, 3, "The Queen's Justice", 'tt5775840'),
#  (7, 4, 'The Spoils of War', 'tt5775846'),
#  (7, 5, 'Eastwatch', 'tt5775854'),
#  (7, 6, 'Beyond the Wall', 'tt5775864'),
#  (7, 7, 'The Dragon and the Wolf', 'tt5775874'),
#  (8, 1, 'Winterfell', 'tt5924366'),
#  (8, 2, 'A Knight of the Seven Kingdoms', 'tt6027908'),
#  (8, 3, 'The Long Night', 'tt6027912'),
#  (8, 4, 'The Last of the Starks', 'tt6027914'),
#  (8, 5, 'The Bells', 'tt6027916'),
#  (8, 6, 'The Iron Throne', 'tt6027920')]

# %%
# %%sql
#
# drop table if exists f24_project.got_episode_title_basics;
#
# create table got_episode_title_basics as
# select
#     tconst, primary_title, season_num,
#     episode_num, episode_title
# from got_episodes join title_basics_fixed using(tconst)
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 73 rows affected.
# []

# %%
# %sql select * from got_episode_title_basics
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 73 rows affected.
# [('tt1480055', 'Winter Is Coming', 1, 1, 'Winter Is Coming'),
#  ('tt1668746', 'The Kingsroad', 1, 2, 'The Kingsroad'),
#  ('tt1829962', 'Lord Snow', 1, 3, 'Lord Snow'),
#  ('tt1829963', 'Cripples, Bastards, and Broken Things', 1, 4, 'Cripples, Bastards, and Broken Things'),
#  ('tt1829964', 'The Wolf and the Lion', 1, 5, 'The Wolf and the Lion'),
#  ('tt1837862', 'A Golden Crown', 1, 6, 'A Golden Crown'),
#  ('tt1837863', 'You Win or You Die', 1, 7, 'You Win or You Die'),
#  ('tt1837864', 'The Pointy End', 1, 8, 'The Pointy End'),
#  ('tt1851398', 'Baelor', 1, 9, 'Baelor'),
#  ('tt1851397', 'Fire and Blood', 1, 10, 'Fire and Blood'),
#  ('tt1971833', 'The North Remembers', 2, 1, 'The North Remembers'),
#  ('tt2069318', 'The Night Lands', 2, 2, 'The Night Lands'),
#  ('tt2070135', 'What Is Dead May Never Die', 2, 3, 'What Is Dead May Never Die'),
#  ('tt2069319', 'Garden of Bones', 2, 4, 'Garden of Bones'),
#  ('tt2074658', 'The Ghost of Harrenhal', 2, 5, 'The Ghost of Harrenhal'),
#  ('tt2085238', 'The Old Gods and the New', 2, 6, 'The Old Gods and the New'),
#  ('tt2085239', 'A Man Without Honor', 2, 7, 'A Man Without Honor'),
#  ('tt2085240', 'The Prince of Winterfell', 2, 8, 'The Prince of Winterfell'),
#  ('tt2084342', 'Blackwater', 2, 9, 'Blackwater'),
#  ('tt2112510', 'Valar Morghulis', 2, 10, 'Valar Morghulis'),
#  ('tt2178782', 'Valar Dohaeris', 3, 1, 'Valar Dohaeris'),
#  ('tt2178772', 'Dark Wings, Dark Words', 3, 2, 'Dark Wings, Dark Words'),
#  ('tt2178802', 'Walk of Punishment', 3, 3, 'Walk of Punishment'),
#  ('tt2178798', 'And Now His Watch Is Ended', 3, 4, 'And Now His Watch Is Ended'),
#  ('tt2178788', 'Kissed by Fire', 3, 5, 'Kissed by Fire'),
#  ('tt2178812', 'The Climb', 3, 6, 'The Climb'),
#  ('tt2178814', 'The Bear and the Maiden Fair', 3, 7, 'The Bear and the Maiden Fair'),
#  ('tt2178806', 'Second Sons', 3, 8, 'Second Sons'),
#  ('tt2178784', 'The Rains of Castamere', 3, 9, 'The Rains of Castamere'),
#  ('tt2178796', 'Mhysa', 3, 10, 'Mhysa'),
#  ('tt2816136', 'Two Swords', 4, 1, 'Two Swords'),
#  ('tt2832378', 'The Lion and the Rose', 4, 2, 'The Lion and the Rose'),
#  ('tt2972426', 'Breaker of Chains', 4, 3, 'Breaker of Chains'),
#  ('tt2972428', 'Oathkeeper', 4, 4, 'Oathkeeper'),
#  ('tt3060856', 'First of His Name', 4, 5, 'First of His Name'),
#  ('tt3060910', 'The Laws of Gods and Men', 4, 6, 'The Laws of Gods and Men'),
#  ('tt3060876', 'Mockingbird', 4, 7, 'Mockingbird'),
#  ('tt3060782', 'The Mountain and the Viper', 4, 8, 'The Mountain and the Viper'),
#  ('tt3060858', 'The Watchers on the Wall', 4, 9, 'The Watchers on the Wall'),
#  ('tt3060860', 'The Children', 4, 10, 'The Children'),
#  ('tt3658012', 'The Wars to Come', 5, 1, 'The Wars to Come'),
#  ('tt3846626', 'The House of Black and White', 5, 2, 'The House of Black and White'),
#  ('tt3866836', 'High Sparrow', 5, 3, 'High Sparrow'),
#  ('tt3866838', 'Sons of the Harpy', 5, 4, 'Sons of the Harpy'),
#  ('tt3866840', 'Kill the Boy', 5, 5, 'Kill the Boy'),
#  ('tt3866842', 'Unbowed, Unbent, Unbroken', 5, 6, 'Unbowed, Unbent, Unbroken'),
#  ('tt3866846', 'The Gift', 5, 7, 'The Gift'),
#  ('tt3866850', 'Hardhome', 5, 8, 'Hardhome'),
#  ('tt3866826', 'The Dance of Dragons', 5, 9, 'The Dance of Dragons'),
#  ('tt3866862', "Mother's Mercy", 5, 10, "Mother's Mercy"),
#  ('tt3658014', 'The Red Woman', 6, 1, 'The Red Woman'),
#  ('tt4077554', 'Home', 6, 2, 'Home'),
#  ('tt4131606', 'Oathbreaker', 6, 3, 'Oathbreaker'),
#  ('tt4283016', 'Book of the Stranger', 6, 4, 'Book of the Stranger'),
#  ('tt4283028', 'The Door', 6, 5, 'The Door'),
#  ('tt4283054', 'Blood of My Blood', 6, 6, 'Blood of My Blood'),
#  ('tt4283060', 'The Broken Man', 6, 7, 'The Broken Man'),
#  ('tt4283074', 'No One', 6, 8, 'No One'),
#  ('tt4283088', 'Battle of the Bastards', 6, 9, 'Battle of the Bastards'),
#  ('tt4283094', 'The Winds of Winter', 6, 10, 'The Winds of Winter'),
#  ('tt5654088', 'Dragonstone', 7, 1, 'Dragonstone'),
#  ('tt5655178', 'Stormborn', 7, 2, 'Stormborn'),
#  ('tt5775840', "The Queen's Justice", 7, 3, "The Queen's Justice"),
#  ('tt5775846', 'The Spoils of War', 7, 4, 'The Spoils of War'),
#  ('tt5775854', 'Eastwatch', 7, 5, 'Eastwatch'),
#  ('tt5775864', 'Beyond the Wall', 7, 6, 'Beyond the Wall'),
#  ('tt5775874', 'The Dragon and the Wolf', 7, 7, 'The Dragon and the Wolf'),
#  ('tt5924366', 'Winterfell', 8, 1, 'Winterfell'),
#  ('tt6027908', 'A Knight of the Seven Kingdoms', 8, 2, 'A Knight of the Seven Kingdoms'),
#  ('tt6027912', 'The Long Night', 8, 3, 'The Long Night'),
#  ('tt6027914', 'The Last of the Starks', 8, 4, 'The Last of the Starks'),
#  ('tt6027916', 'The Bells', 8, 5, 'The Bells'),
#  ('tt6027920', 'The Iron Throne', 8, 6, 'The Iron Throne')]

# %% [markdown]
# We can now create a view to show us how IMDB and GoT data align on some information.

# %%
# %%sql
#
# drop view if exists got_names_episodes;
#
# create view got_names_episodes as
# with one as  (
#     select * from got_episode_title_basics join title_principals_fixed using(tconst)
# )
# select
#     nconst, first_name, last_name,
#     tconst, season_num, episode_num, episode_title
# from one join name_basics_fixed using(nconst);
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %sql select * from got_names_episodes limit 10
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 10 rows affected.
# [('nm0000293', 'Sean', 'Bean', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm0004692', 'Mark', 'Addy', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm0182666', 'Nikolaj', 'Coster-Waldau', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm0265610', 'Michelle', 'Fairley', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm0322513', 'Iain', 'Glen', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm0372176', 'Lena', 'Headey', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm0516003', 'Harry', 'Lloyd', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm1414435', 'Robert', 'Sterne', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm3229685', 'Kit', 'Harington', 'tt1480055', 1, 1, 'Winter Is Coming'),
#  ('nm3592338', 'Emilia', 'Clarke', 'tt1480055', 1, 1, 'Winter Is Coming')]

# %% [markdown]
# # Neo4j

# %% [markdown]
# ## Overview

# %% [markdown]
# Neo4j is a graph database. Graph databases are excellent for "networks" of "social connections." Those of you who have watched Game of Thrones know that the social connections can be a little unsettling. The connections between characters are in the characters collection. Let's take a look at an example. ```Sansa Stark``` has quite a few connections.

# %%
result = mongo_client.f24_project_got.characters.find({"characterName": "Sansa Stark"})

# %%
result = list(result)

# %%
result[0]
# Out:
# {'_id': ObjectId('6753ac0dedad7a377c536654'),
#  'characterName': 'Sansa Stark',
#  'houseName': 'Stark',
#  'characterImageThumb': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1._SX100_SY140_.jpg',
#  'characterImageFull': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1_SY1000_CR0,0,806,1000_AL_.jpg',
#  'characterLink': '/character/ch0158137/',
#  'actorName': 'Sophie Turner',
#  'actorLink': '/name/nm3849842/',
#  'royal': True,
#  'siblings': ['Robb Stark', 'Arya Stark', 'Bran Stark', 'Rickon Stark'],
#  'marriedEngaged': ['Joffrey Baratheon', 'Tyrion Lannister', 'Ramsay Snow'],
#  'guardedBy': ['Lady'],
#  'parents': ['Eddard Stark', 'Catelyn Stark']}

# %% [markdown]
# Some attributes a simple properties and some are a list of related characters. In this document,
# - ```characterName, houseName, characterImageThumb, characterImageFull, characterLink, actorName, actorLink,``` and ```royal``` are simple attributes.
# - ```siblings, marriedEngaged, guardedBy,``` and ```parents``` are relationships.
#
# This dataset is small and we can examine each document. In a very large dataset we would do some random sampling. The first step is to find the top level elements and their types. A relationship set is a list in these documents.

# %%
result = mongo_client.f24_project_got.characters.find({}, {"_id": 0})
result = list(result)

simple_attributes = set()
list_attributes = set()

for r in result:
    for k,v in r.items():
        if type(v) == list:
            list_attributes.add(k)
        else:
            simple_attributes.add(k)

# %%
simple_attributes
# Out:
# {'actorLink',
#  'actorName',
#  'characterImageFull',
#  'characterImageThumb',
#  'characterLink',
#  'characterName',
#  'houseName',
#  'kingsguard',
#  'nickname',
#  'royal'}

# %%
list_attributes
# Out:
# {'abducted',
#  'abductedBy',
#  'actors',
#  'allies',
#  'guardedBy',
#  'guardianOf',
#  'houseName',
#  'killed',
#  'killedBy',
#  'marriedEngaged',
#  'parentOf',
#  'parents',
#  'servedBy',
#  'serves',
#  'sibling',
#  'siblings'}

# %% [markdown]
# Looking at the attribute names provides condidence that we know the simple and relationship attributes. We want to create list of relationships of the form: ```(source_character, relationship_type, target_character).``` We will temporarily create a table in the relational database and then add to Neo4j.
#
# __Note:__ We will ignore ```actors``` because we already loaded the information and it is a list of documents."

# %%
fixed_list_attributes = [l for l in list_attributes if l != 'actors']
list_attributes = fixed_list_attributes
list_attributes
# Out:
# ['guardianOf',
#  'marriedEngaged',
#  'killed',
#  'sibling',
#  'killedBy',
#  'parentOf',
#  'parents',
#  'guardedBy',
#  'allies',
#  'abductedBy',
#  'houseName',
#  'abducted',
#  'servedBy',
#  'serves',
#  'siblings']

# %%
# TODO Students must implement this function.
#
# Hint: Use an aggregation and unwind operator.
#
def get_relationship(the_collection, relationship_attribute):

    the_aggregation = [
        {
            "$unwind": f"${relationship_attribute}"
        },
        {
            "$project": {
                "_id": 0,
                "sourceCharacter": "$characterName",
                "relationship_type": f"{relationship_attribute}",
                "targetCharacter": f"${relationship_attribute}"
            }
        }
    ]

    result = the_collection.aggregate(the_aggregation)
    result = list(result)
    return result

# %%
# This is a simple test of calling your function with "killed"
# My answer is below this test cell.
#
result = get_relationship(mongo_client.f24_project_got.characters, "killed")
result_df = pandas.DataFrame(result)
result_df
# Out:
#         sourceCharacter relationship_type     targetCharacter
# 0    Aerys II Targaryen            killed       Brandon Stark
# 1    Aerys II Targaryen            killed       Rickard Stark
# 2        Alliser Thorne            killed            Jon Snow
# 3           Amory Lorch            killed               Yoren
# 4            Arya Stark            killed  Red Keep Stableboy
# ..                  ...               ...                 ...
# 217             Wun Wun            killed      Lyanna Mormont
# 218             Ygritte            killed             Old Man
# 219             Ygritte            killed              Guymon
# 220             Ygritte            killed   Mole's Town Whore
# 221             Ygritte            killed               Pypar
#
# [222 rows x 3 columns]

# %% [markdown]
# | <img src="killed.jpg"> |
# | :---: |
# | __Killed Relationship Example__ |

# %% [markdown]
# The following code will produce and save a table of relationships.

# %%
all_relationships = []

for r in list_attributes:
    result = get_relationship(mongo_client.f24_project_got.characters, r)
    all_relationships.extend(result)

for a in all_relationships:
    if type(a.get("targetCharacter", None)) != str:
        print("Oops", a)


all_relationships_df = pandas.DataFrame(all_relationships)
all_relationships_df
# Out:
#        sourceCharacter relationship_type     targetCharacter
# 0               Drogon        guardianOf  Daenerys Targaryen
# 1         Eddard Stark        guardianOf            Jon Snow
# 2                Ghost        guardianOf            Jon Snow
# 3            Grey Wind        guardianOf          Robb Stark
# 4      Jaime Lannister        guardianOf  Aerys II Targaryen
# ..                 ...               ...                 ...
# 935  Viserys Targaryen          siblings  Daenerys Targaryen
# 936  Viserys Targaryen          siblings   Rhaegar Targaryen
# 937   Willem Lannister          siblings    Lancel Lannister
# 938   Willem Lannister          siblings    Martyn Lannister
# 939       Yara Greyjoy          siblings       Theon Greyjoy
#
# [940 rows x 3 columns]

# %%
all_relationships_df.to_sql(
    "temp_relationships", schema="f24_project",
    con=default_engine, index=False, if_exists="replace"
)
# Out:
# 940

# %% [markdown]
# We are not quite done, because remember that we added character IDs when we loaded the original data. We want to use the IDs when adding relationships to the Neo4j data.
#
#
# In the cell below, write a Neo4j cypher query that returns the ```characterName``` and ```character_id.```

# %%
# Student TODO
#
neo4j_q = """
    match (c:Character:IMDB) return c.character_id as character_id, 
                                    c.characterName as characterName
                                    order by c.characterName
"""

# %% [markdown]
# The following cell is a simple test.

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    q = neo4j_q + " limit 4"

    records, summary, keys = driver.execute_query(
        q
    )

# %% [markdown]
# If you do not get an error, the following code cell will produce a result to versify the test. My answer to the test is:
#
# | <img src="neo_test_1.jpg" > |
# | :---: |
# | __Simple Neo4j Test Result__ |

# %%
for r in records:
    print(dict(r.items()))
# Out:
# {'character_id': 'ch_1', 'characterName': 'Addam Marbrand'}
# {'character_id': 'ch_2', 'characterName': 'Aegon Targaryen'}
# {'character_id': 'ch_3', 'characterName': 'Aeron Greyjoy'}
# {'character_id': 'ch_4', 'characterName': 'Aerys II Targaryen'}

# %% [markdown]
# We will load this into a temporary table and use a ```JOIN``` to get a table of relationships.

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    q = neo4j_q

    records, summary, keys = driver.execute_query(
        q
    )

neo4j_characters = [dict(r.items()) for r in records]
neo4j_characters_df = pandas.DataFrame(neo4j_characters)

# %%
neo4j_characters_df.to_sql(
    "neo4j_characters", schema="f24_project",
    con=default_engine, index=False, if_exists="replace"
)
# Out:
# 391

# %%
# TODO Test the insert. My code example result follows.
#
# %sql select * from neo4j_characters
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 391 rows affected.
# [('ch_1', 'Addam Marbrand'),
#  ('ch_2', 'Aegon Targaryen'),
#  ('ch_3', 'Aeron Greyjoy'),
#  ('ch_4', 'Aerys II Targaryen'),
#  ('ch_5', 'Akho'),
#  ('ch_6', 'Alliser Thorne'),
#  ('ch_7', 'Alton Lannister'),
#  ('ch_8', 'Alys Karstark'),
#  ('ch_9', 'Amory Lorch'),
#  ('ch_10', 'Anguy'),
#  ('ch_11', 'Archmaester Marwyn'),
#  ('ch_12', 'Areo Hotah'),
#  ('ch_13', 'Armeca'),
#  ('ch_14', 'Arthur'),
#  ('ch_15', 'Arthur Dayne'),
#  ('ch_16', 'Arya Stark'),
#  ('ch_17', 'Baby Sam'),
#  ('ch_18', 'Balon Greyjoy'),
#  ('ch_19', 'Baratheon Guard'),
#  ('ch_20', 'Barristan Selmy'),
#  ('ch_21', 'Benjen Stark'),
#  ('ch_22', 'Beric Dondarrion'),
#  ('ch_23', 'Bianca'),
#  ('ch_24', 'Biter'),
#  ('ch_25', 'Black Lorren'),
#  ('ch_26', 'Black Walder Rivers'),
#  ('ch_27', 'Bobono'),
#  ('ch_28', 'Bowen Marsh'),
#  ('ch_30', 'Bran Stark'),
#  ('ch_29', 'Brandon Stark'),
#  ('ch_31', 'Brea'),
#  ('ch_32', 'Brienne of Tarth'),
#  ('ch_33', 'Bronn'),
#  ('ch_34', 'Brother Ray'),
#  ('ch_35', 'Brynden Tully'),
#  ('ch_36', 'Captain of the Archers'),
#  ('ch_37', 'Catelyn Stark'),
#  ('ch_38', 'Catspaw Assassin'),
#  ('ch_39', 'Cersei Lannister'),
#  ('ch_40', 'Child of the Forest'),
#  ('ch_41', 'Citadel Maester'),
#  ('ch_42', 'Colen of Greenpools'),
#  ('ch_43', 'Craster'),
#  ('ch_44', 'Daario Naharis'),
#  ('ch_45', 'Daenerys Targaryen'),
#  ('ch_46', 'Dagmer Cleftjaw'),
#  ('ch_47', 'Daisy'),
#  ('ch_48', 'Davos Seaworth'),
#  ('ch_49', 'Dickon Tarly'),
#  ('ch_50', 'Dongo the Giant'),
#  ('ch_51', 'Donnel Waynwood'),
#  ('ch_52', 'Dontos Hollard'),
#  ('ch_53', 'Doran Martell'),
#  ('ch_54', 'Doreah'),
#  ('ch_55', 'Dothraki Bloodrider #1'),
#  ('ch_56', 'Dothraki Bloodrider #2'),
#  ('ch_57', 'Drennan'),
#  ('ch_58', 'Drogon'),
#  ('ch_59', 'Drowned Priest'),
#  ('ch_60', 'Eddard Stark'),
#  ('ch_61', 'Eddison Tollett'),
#  ('ch_62', 'Edmure Tully'),
#  ('ch_64', 'Elia Martell'),
#  ('ch_63', 'Ellaria Sand'),
#  ('ch_65', 'Eon Hunter'),
#  ('ch_66', 'Euron Greyjoy'),
#  ('ch_67', 'Faceless Man'),
#  ('ch_68', 'Farlen'),
#  ('ch_69', 'Gared'),
#  ('ch_70', 'Gatins'),
#  ('ch_71', 'Gendry'),
#  ('ch_72', 'Gerold Hightower'),
#  ('ch_73', 'Ghost'),
#  ('ch_74', 'Gilly'),
#  ('ch_75', 'Goldcloak'),
#  ('ch_76', 'Goldcloak'),
#  ('ch_77', 'Goldcloak #1'),
#  ('ch_78', 'Goldcloak #2'),
#  ('ch_79', 'Grand Maester Pycelle'),
#  ('ch_80', 'Great Master #1'),
#  ('ch_81', 'Great Master #2'),
#  ('ch_82', 'Great Master #3'),
#  ('ch_83', 'Great Master #4'),
#  ('ch_84', 'Great Master #5'),
#  ('ch_85', 'Great Master #6'),
#  ('ch_86', 'Great Master #7'),
#  ('ch_87', 'Greatjon Umber'),
#  ('ch_88', 'Gregor Clegane'),
#  ('ch_89', 'Greizhen mo Ullhor'),
#  ('ch_90', 'Grenn'),
#  ('ch_91', 'Grey Wind'),
#  ('ch_92', 'Grey Worm'),
#  ('ch_93', 'Hallyne'),
#  ('ch_94', 'Handmaid'),
#  ('ch_95', 'Handmaid'),
#  ('ch_96', 'Harald Karstark'),
#  ('ch_97', 'Harry Strickland'),
#  ('ch_98', 'High Priestess'),
#  ('ch_99', 'High Septon'),
#  ('ch_100', 'High Septon'),
#  ('ch_101', 'High Sparrow'),
#  ('ch_102', 'Hizdahr zo Loraq'),
#  ('ch_103', 'Hodor'),
#  ('ch_104', 'Hoster Tully'),
#  ('ch_105', 'Hot Pie'),
#  ('ch_106', 'Howland Reed'),
#  ('ch_107', 'Hugh of the Vale'),
#  ('ch_108', 'Illyrio Mopatis'),
#  ('ch_109', 'Ilyn Payne'),
#  ('ch_110', 'Irri'),
#  ('ch_111', 'Izembaro'),
#  ('ch_112', 'Jacks'),
#  ('ch_113', 'Jafer Flowers'),
#  ('ch_114', 'Jaime Lannister'),
#  ('ch_115', 'Janos Slynt'),
#  ('ch_116', "Jaqen H'ghar"),
#  ('ch_117', "Jaqen's Disguise"),
#  ('ch_118', 'Jaremy Rykker'),
#  ('ch_119', 'Jeor Mormont'),
#  ('ch_120', 'Jhiqui'),
#  ('ch_121', 'Joffrey Baratheon'),
#  ('ch_122', 'Jojen Reed'),
#  ('ch_123', 'Jon Arryn'),
#  ('ch_124', 'Jon Snow'),
#  ('ch_125', 'Jonos Bracken'),
#  ('ch_126', 'Jorah Mormont'),
#  ('ch_127', 'Jory Cassel'),
#  ('ch_128', 'Joyeuse Erenford'),
#  ('ch_129', 'Karl Tanner'),
#  ('ch_130', 'Karsi'),
#  ('ch_131', 'Kayla'),
#  ('ch_132', 'Kegs'),
#  ('ch_133', 'Kevan Lannister'),
#  ('ch_134', 'Khal Drogo'),
#  ('ch_135', 'Khal Moro'),
#  ('ch_136', 'Khal Rhalko'),
#  ('ch_137', 'King Joffrey Baratheon Dwarf'),
#  ('ch_138', 'King Renly Baratheon Dwarf'),
#  ('ch_139', 'King Robb Stark Dwarf'),
#  ('ch_140', 'King Stannis Baratheon Dwarf'),
#  ('ch_141', "King's Landing Rioter #1"),
#  ('ch_142', "King's Landing Rioter #2"),
#  ('ch_143', "King's Landing Rioter #3"),
#  ('ch_144', 'Kinvara'),
#  ('ch_145', 'Kitty Frey'),
#  ('ch_146', 'Knight of House Frey'),
#  ('ch_147', 'Knight of House Lynderly'),
#  ('ch_148', 'Kovarro'),
#  ('ch_149', 'Kraznys mo Nakloz'),
#  ('ch_150', 'Kurleket'),
#  ('ch_151', 'Lady'),
#  ('ch_152', 'Lady Crane'),
#  ('ch_153', 'Lancel Lannister'),
#  ('ch_154', 'Lannister Captain'),
#  ('ch_155', 'Lannister Captain'),
#  ('ch_156', 'Lannister Guardsman'),
#  ('ch_157', 'Lannister Messenger'),
#  ('ch_158', 'Lannister Scout'),
#  ('ch_159', 'Lead Dornish Guard'),
#  ('ch_160', 'Leaf'),
#  ('ch_161', 'Lem Lemoncloak'),
#  ('ch_162', 'Leo Lefford'),
#  ('ch_163', 'Lhara'),
#  ('ch_164', 'Little Bird'),
#  ('ch_165', 'Little Bird'),
#  ('ch_166', 'Little Bird #3'),
#  ('ch_167', 'Little Bird #4'),
#  ('ch_168', 'Little Bird #5'),
#  ('ch_169', 'Little Bird #6'),
#  ('ch_170', 'Little Bird #7'),
#  ('ch_171', 'Loboda'),
#  ('ch_172', 'Locke'),
#  ('ch_173', 'Lollys Stokeworth'),
#  ('ch_174', 'Lommy Greenhands'),
#  ('ch_175', 'Loras Tyrell'),
#  ('ch_176', 'Lord Galbart Glover'),
#  ('ch_177', 'Lord Portan'),
#  ('ch_178', 'Lord Varys'),
#  ('ch_179', 'Lordsport Dockhand'),
#  ('ch_180', 'Lothar Frey'),
#  ('ch_181', "Loyal Night's Watchman #1"),
#  ('ch_182', "Loyal Night's Watchman #2"),
#  ('ch_183', 'Lyanna Mormont'),
#  ('ch_184', 'Lyanna Stark'),
#  ('ch_185', 'Lysa Arryn'),
#  ('ch_186', 'Mace Tyrell'),
#  ('ch_187', 'Maester Aemon'),
#  ('ch_188', 'Maester Cressen'),
#  ('ch_189', 'Maester Luwin'),
#  ('ch_190', 'Maester Wolkan'),
#  ('ch_191', 'Mag the Mighty'),
#  ('ch_192', 'Maggy'),
#  ('ch_193', 'Mago'),
#  ('ch_194', 'Male Prostitute'),
#  ('ch_195', 'Malko'),
#  ('ch_196', 'Mance Rayder'),
#  ('ch_197', 'Mandon Moore'),
#  ('ch_198', 'Manservant'),
#  ('ch_199', 'Marei'),
#  ('ch_200', 'Margaery Tyrell'),
#  ('ch_201', "Margaery's Handmaiden"),
#  ('ch_202', 'Marillion'),
#  ('ch_203', 'Martyn Lannister'),
#  ('ch_204', 'Masha Heddle'),
#  ('ch_205', 'Matthos Seaworth'),
#  ('ch_206', 'Meera Reed'),
#  ('ch_207', 'Meereen Slave Master'),
#  ('ch_208', 'Melessa Tarly'),
#  ('ch_209', 'Melisandre'),
#  ('ch_210', 'Merchant Captain'),
#  ('ch_211', 'Mero'),
#  ('ch_212', 'Meryn Trant'),
#  ('ch_213', 'Mhaegen'),
#  ('ch_214', 'Mikken'),
#  ('ch_215', 'Mirelle'),
#  ('ch_216', 'Mirri Maz Duur'),
#  ('ch_217', 'Missandei'),
#  ('ch_218', 'Mord'),
#  ('ch_219', 'Mossador'),
#  ('ch_220', 'Musician #1'),
#  ('ch_221', 'Musician #1'),
#  ('ch_222', 'Musician #2'),
#  ('ch_223', 'Musician #2'),
#  ('ch_224', 'Musician #3'),
#  ('ch_225', 'Musician #3'),
#  ('ch_226', 'Musician #4'),
#  ('ch_227', 'Musician #5'),
#  ('ch_228', 'Mycah'),
#  ('ch_229', 'Myranda'),
#  ('ch_230', 'Myrcella Baratheon'),
#  ('ch_231', 'Ned Umber'),
#  ('ch_232', "Night's Watch Deserter"),
#  ('ch_233', "Night's Watch Messenger"),
#  ('ch_234', "Night's Watch Officer"),
#  ('ch_235', "Night's Watch Officer"),
#  ('ch_236', "Night's Watchman"),
#  ('ch_237', "Night's Watchman"),
#  ('ch_238', "Night's Watchman"),
#  ('ch_239', "Night's Watchman #1"),
#  ('ch_240', "Night's Watchman #2"),
#  ('ch_241', "Night's Watchman #2"),
#  ('ch_242', 'Northman Rioter'),
#  ('ch_243', 'Nymeria'),
#  ('ch_244', 'Nymeria Sand'),
#  ('ch_245', 'Obara Sand'),
#  ('ch_246', 'Oberyn Martell'),
#  ('ch_247', 'Old Nan'),
#  ('ch_248', 'Old Woman Prisoner'),
#  ('ch_249', 'Olenna Tyrell'),
#  ('ch_250', 'Olly'),
#  ('ch_251', 'Olyvar'),
#  ('ch_252', 'Orell'),
#  ('ch_253', 'Ornela'),
#  ('ch_254', 'Osha'),
#  ('ch_255', 'Othell Yarwyck'),
#  ('ch_256', 'Othor'),
#  ('ch_257', 'Pentoshi Servant'),
#  ('ch_258', 'Petyr Baelish'),
#  ('ch_259', 'Podrick Payne'),
#  ('ch_260', 'Polliver'),
#  ('ch_261', 'Prendahl na Ghezn'),
#  ('ch_262', 'Pyat Pree'),
#  ('ch_263', 'Pypar'),
#  ('ch_264', 'Qhono'),
#  ('ch_265', 'Qhorin Halfhand'),
#  ('ch_266', 'Qotho'),
#  ('ch_267', 'Quaithe'),
#  ('ch_268', 'Qyburn'),
#  ('ch_269', 'Rakharo'),
#  ('ch_270', 'Ramsay Snow'),
#  ('ch_271', 'Randyll Tarly'),
#  ('ch_272', 'Rast'),
#  ('ch_273', 'Rattleshirt'),
#  ('ch_274', 'Razdal mo Eraz'),
#  ('ch_275', 'Red Keep Stableboy'),
#  ('ch_276', 'Red Priestess'),
#  ('ch_277', 'Red Priestess'),
#  ('ch_278', 'Renly Baratheon'),
#  ('ch_279', 'Rhaegal'),
#  ('ch_280', 'Rhaegar Targaryen'),
#  ('ch_281', 'Rhaego'),
#  ('ch_282', 'Rhaella Targaryen'),
#  ('ch_283', 'Rhaenys Targaryen'),
#  ('ch_284', 'Rickard Karstark'),
#  ('ch_285', 'Rickard Stark'),
#  ('ch_286', 'Rickon Stark'),
#  ('ch_287', 'Robb Stark'),
#  ('ch_288', 'Robert Baratheon'),
#  ('ch_289', 'Robett Glover'),
#  ('ch_290', 'Robin Arryn'),
#  ('ch_291', 'Rodrik Cassel'),
#  ('ch_292', 'Roose Bolton'),
#  ('ch_293', 'Rorge'),
#  ('ch_294', 'Ros'),
#  ('ch_295', 'Roslin Frey'),
#  ('ch_296', 'Royal Steward'),
#  ('ch_297', 'Ryger Rivers'),
#  ('ch_298', 'Salladhor Saan'),
#  ('ch_299', 'Samwell Tarly'),
#  ('ch_300', 'Sandor Clegane'),
#  ('ch_301', 'Sansa Stark'),
#  ('ch_302', 'Selyse Baratheon'),
#  ('ch_303', 'Septa Moelle'),
#  ('ch_304', 'Septa Mordane'),
#  ('ch_305', 'Septa Scolera'),
#  ('ch_306', 'Septa Unella'),
#  ('ch_307', 'Septon'),
#  ('ch_308', 'Septon'),
#  ('ch_309', 'Ser Endrew Tarth'),
#  ('ch_310', 'Shae'),
#  ('ch_311', 'Shagga'),
#  ('ch_312', 'Shaggydog'),
#  ('ch_313', 'Shireen Baratheon'),
#  ('ch_314', 'Silk King'),
#  ('ch_315', 'Smalljon Umber'),
#  ('ch_316', 'Spice King'),
#  ('ch_317', 'Stannis Baratheon'),
#  ('ch_318', 'Stark Bannerman'),
#  ('ch_319', 'Stark Guard'),
#  ('ch_320', 'Stark Guard'),
#  ('ch_321', 'Stark Guard'),
#  ('ch_322', 'Stark Guard'),
#  ('ch_323', 'Steelshanks Walton'),
#  ('ch_324', 'Stevron Frey'),
#  ('ch_325', 'Stiv'),
#  ('ch_326', 'Styr'),
#  ('ch_327', 'Summer'),
#  ('ch_328', 'Syrio Forel'),
#  ('ch_329', 'Talisa Maegyr'),
#  ('ch_330', 'Talla Tarly'),
#  ('ch_331', 'Ternesio Terys'),
#  ('ch_332', 'The Bear'),
#  ('ch_333', 'The Night King'),
#  ('ch_334', 'The Tickler'),
#  ('ch_335', 'The Waif'),
#  ('ch_336', 'Thenn Warg'),
#  ('ch_337', 'Theon Greyjoy'),
#  ('ch_338', 'Thin Man'),
#  ('ch_339', 'Thoros of Myr'),
#  ('ch_340', 'Three-Eyed Raven'),
#  ('ch_341', 'Timett'),
#  ('ch_342', 'Tobho Mott'),
#  ('ch_343', 'Todder'),
#  ('ch_344', 'Tomard'),
#  ('ch_345', 'Tommen Baratheon'),
#  ('ch_346', 'Tormund Giantsbane'),
#  ('ch_347', 'Trystane Martell'),
#  ('ch_348', 'Tycho Nestoris'),
#  ('ch_349', 'Tyene Sand'),
#  ('ch_350', 'Tyrion Lannister'),
#  ('ch_351', 'Tywin Lannister'),
#  ('ch_352', 'Vala'),
#  ('ch_353', 'Vardis Egen'),
#  ('ch_354', 'Varly'),
#  ('ch_355', 'Viserion'),
#  ('ch_356', 'Viserys Targaryen'),
#  ('ch_357', 'Walda Bolton'),
#  ('ch_358', 'Walder Frey'),
#  ('ch_359', 'Wallen'),
#  ('ch_360', 'Warlock'),
#  ('ch_361', 'Waymar Royce'),
#  ('ch_362', 'Wedding Band'),
#  ('ch_363', 'White Walker'),
#  ('ch_364', 'White Walker'),
#  ('ch_365', 'White Walker'),
#  ('ch_366', 'White Walker #2'),
#  ('ch_367', 'Wight Wildling Girl'),
#  ('ch_368', 'Wildling Rioter'),
#  ('ch_369', 'Will'),
#  ('ch_370', 'Willem Lannister'),
#  ('ch_371', 'Willis Wode'),
#  ('ch_372', 'Wine Merchant'),
#  ('ch_373', 'Winterfell Shepherd'),
#  ('ch_374', 'Wun Wun'),
#  ('ch_375', 'Wyllis'),
#  ('ch_376', 'Xaro Xhoan Daxos'),
#  ('ch_377', 'Yara Greyjoy'),
#  ('ch_378', 'Yezzan zo Qaggaz'),
#  ('ch_379', 'Ygritte'),
#  ('ch_380', 'Yohn Royce'),
#  ('ch_381', 'Yoren'),
#  ('ch_382', 'Young Benjen Stark'),
#  ('ch_383', 'Young Cersei Lannister'),
#  ('ch_384', 'Young Lyanna Stark'),
#  ('ch_385', 'Young Nan'),
#  ('ch_386', 'Young Ned'),
#  ('ch_387', 'Young Ned Stark'),
#  ('ch_388', 'Young Rodrik Cassel'),
#  ('ch_389', 'Zanrush'),
#  (None, None),
#  (None, None)]

# %% [markdown]
# | <img src="neo_characters_sql.jpg" > |
# | :---: |
# | __Neo4j SQL Test Result__ |

# %% [markdown]
# You have had as much SQL fun as you can have for one HW. So, I will do the join for you.
#
# OK. So, I used a subquery. Sue me. I used the ```min()``` function because we accidentially loaded some duplicates.
#
# Dirty data in data engineering is part of the "fun."
#
# | <img src="fun.jpg" width="700px;"> |
# | :---: |
# | __Data Engineering is Fun!__

# %%
# %%sql
#
# select
#     (select min(character_id) from neo4j_characters where characterName=temp_relationships.sourceCharacter)
#         as source_character_id,
#     sourceCharacter,
#     relationship_type,
#     (select min(character_id) from neo4j_characters where characterName=temp_relationships.targetCharacter)
#         as target_character_id,
#     targetCharacter
# from
#     temp_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 940 rows affected.
# [('ch_58', 'Drogon', 'guardianOf', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_60', 'Eddard Stark', 'guardianOf', 'ch_124', 'Jon Snow'),
#  ('ch_73', 'Ghost', 'guardianOf', 'ch_124', 'Jon Snow'),
#  ('ch_91', 'Grey Wind', 'guardianOf', 'ch_287', 'Robb Stark'),
#  ('ch_114', 'Jaime Lannister', 'guardianOf', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_114', 'Jaime Lannister', 'guardianOf', 'ch_288', 'Robert Baratheon'),
#  ('ch_114', 'Jaime Lannister', 'guardianOf', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_123', 'Jon Arryn', 'guardianOf', 'ch_60', 'Eddard Stark'),
#  ('ch_123', 'Jon Arryn', 'guardianOf', 'ch_288', 'Robert Baratheon'),
#  ('ch_151', 'Lady', 'guardianOf', 'ch_301', 'Sansa Stark'),
#  ('ch_243', 'Nymeria', 'guardianOf', 'ch_16', 'Arya Stark'),
#  ('ch_279', 'Rhaegal', 'guardianOf', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_312', 'Shaggydog', 'guardianOf', 'ch_286', 'Rickon Stark'),
#  ('ch_327', 'Summer', 'guardianOf', 'ch_30', 'Bran Stark'),
#  ('ch_355', 'Viserion', 'guardianOf', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_4', 'Aerys II Targaryen', 'marriedEngaged', 'ch_282', 'Rhaella Targaryen'),
#  ('ch_33', 'Bronn', 'marriedEngaged', 'ch_173', 'Lollys Stokeworth'),
#  ('ch_37', 'Catelyn Stark', 'marriedEngaged', 'ch_60', 'Eddard Stark'),
#  ('ch_37', 'Catelyn Stark', 'marriedEngaged', 'ch_29', 'Brandon Stark'),
#  ('ch_39', 'Cersei Lannister', 'marriedEngaged', 'ch_288', 'Robert Baratheon'),
#  ('ch_45', 'Daenerys Targaryen', 'marriedEngaged', 'ch_134', 'Khal Drogo'),
#  ('ch_60', 'Eddard Stark', 'marriedEngaged', 'ch_37', 'Catelyn Stark'),
#  ('ch_62', 'Edmure Tully', 'marriedEngaged', 'ch_295', 'Roslin Frey'),
#  ('ch_63', 'Ellaria Sand', 'marriedEngaged', 'ch_246', 'Oberyn Martell'),
#  ('ch_64', 'Elia Martell', 'marriedEngaged', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_74', 'Gilly', 'marriedEngaged', 'ch_299', 'Samwell Tarly'),
#  ('ch_121', 'Joffrey Baratheon', 'marriedEngaged', 'ch_301', 'Sansa Stark'),
#  ('ch_121', 'Joffrey Baratheon', 'marriedEngaged', 'ch_200', 'Margaery Tyrell'),
#  ('ch_124', 'Jon Snow', 'marriedEngaged', 'ch_379', 'Ygritte'),
#  ('ch_128', 'Joyeuse Erenford', 'marriedEngaged', 'ch_358', 'Walder Frey'),
#  ('ch_134', 'Khal Drogo', 'marriedEngaged', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_145', 'Kitty Frey', 'marriedEngaged', 'ch_358', 'Walder Frey'),
#  ('ch_173', 'Lollys Stokeworth', 'marriedEngaged', 'ch_33', 'Bronn'),
#  ('ch_184', 'Lyanna Stark', 'marriedEngaged', 'ch_288', 'Robert Baratheon'),
#  ('ch_184', 'Lyanna Stark', 'marriedEngaged', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_185', 'Lysa Arryn', 'marriedEngaged', 'ch_258', 'Petyr Baelish'),
#  ('ch_200', 'Margaery Tyrell', 'marriedEngaged', 'ch_278', 'Renly Baratheon'),
#  ('ch_200', 'Margaery Tyrell', 'marriedEngaged', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_200', 'Margaery Tyrell', 'marriedEngaged', 'ch_345', 'Tommen Baratheon'),
#  ('ch_208', 'Melessa Tarly', 'marriedEngaged', 'ch_271', 'Randyll Tarly'),
#  ('ch_230', 'Myrcella Baratheon', 'marriedEngaged', 'ch_347', 'Trystane Martell'),
#  ('ch_246', 'Oberyn Martell', 'marriedEngaged', 'ch_63', 'Ellaria Sand'),
#  ('ch_258', 'Petyr Baelish', 'marriedEngaged', 'ch_185', 'Lysa Arryn'),
#  ('ch_270', 'Ramsay Snow', 'marriedEngaged', 'ch_301', 'Sansa Stark'),
#  ('ch_271', 'Randyll Tarly', 'marriedEngaged', 'ch_208', 'Melessa Tarly'),
#  ('ch_278', 'Renly Baratheon', 'marriedEngaged', 'ch_200', 'Margaery Tyrell'),
#  ('ch_280', 'Rhaegar Targaryen', 'marriedEngaged', 'ch_64', 'Elia Martell'),
#  ('ch_280', 'Rhaegar Targaryen', 'marriedEngaged', 'ch_184', 'Lyanna Stark'),
#  ('ch_282', 'Rhaella Targaryen', 'marriedEngaged', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_287', 'Robb Stark', 'marriedEngaged', 'ch_295', 'Roslin Frey'),
#  ('ch_287', 'Robb Stark', 'marriedEngaged', 'ch_329', 'Talisa Maegyr'),
#  ('ch_288', 'Robert Baratheon', 'marriedEngaged', 'ch_184', 'Lyanna Stark'),
#  ('ch_288', 'Robert Baratheon', 'marriedEngaged', 'ch_39', 'Cersei Lannister'),
#  ('ch_292', 'Roose Bolton', 'marriedEngaged', 'ch_357', 'Walda Bolton'),
#  ('ch_295', 'Roslin Frey', 'marriedEngaged', 'ch_287', 'Robb Stark'),
#  ('ch_295', 'Roslin Frey', 'marriedEngaged', 'ch_62', 'Edmure Tully'),
#  ('ch_299', 'Samwell Tarly', 'marriedEngaged', 'ch_74', 'Gilly'),
#  ('ch_301', 'Sansa Stark', 'marriedEngaged', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_301', 'Sansa Stark', 'marriedEngaged', 'ch_350', 'Tyrion Lannister'),
#  ('ch_301', 'Sansa Stark', 'marriedEngaged', 'ch_270', 'Ramsay Snow'),
#  ('ch_302', 'Selyse Baratheon', 'marriedEngaged', 'ch_317', 'Stannis Baratheon'),
#  ('ch_317', 'Stannis Baratheon', 'marriedEngaged', 'ch_302', 'Selyse Baratheon'),
#  ('ch_329', 'Talisa Maegyr', 'marriedEngaged', 'ch_287', 'Robb Stark'),
#  ('ch_345', 'Tommen Baratheon', 'marriedEngaged', 'ch_200', 'Margaery Tyrell'),
#  ('ch_347', 'Trystane Martell', 'marriedEngaged', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_350', 'Tyrion Lannister', 'marriedEngaged', 'ch_301', 'Sansa Stark'),
#  ('ch_357', 'Walda Bolton', 'marriedEngaged', 'ch_292', 'Roose Bolton'),
#  ('ch_358', 'Walder Frey', 'marriedEngaged', 'ch_128', 'Joyeuse Erenford'),
#  ('ch_358', 'Walder Frey', 'marriedEngaged', 'ch_145', 'Kitty Frey'),
#  ('ch_379', 'Ygritte', 'marriedEngaged', 'ch_124', 'Jon Snow'),
#  ('ch_4', 'Aerys II Targaryen', 'killed', 'ch_29', 'Brandon Stark'),
#  ('ch_4', 'Aerys II Targaryen', 'killed', 'ch_285', 'Rickard Stark'),
#  ('ch_6', 'Alliser Thorne', 'killed', 'ch_124', 'Jon Snow'),
#  ('ch_9', 'Amory Lorch', 'killed', 'ch_381', 'Yoren'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_275', 'Red Keep Stableboy'),
#  ('ch_16', 'Arya Stark', 'killed', None, 'Frey Soldier #1'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_260', 'Polliver'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_293', 'Rorge'),
#  ('ch_16', 'Arya Stark', 'killed', None, 'Ghita'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_212', 'Meryn Trant'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_335', 'The Waif'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_26', 'Black Walder Rivers'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_180', 'Lothar Frey'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_358', 'Walder Frey'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_258', 'Petyr Baelish'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_333', 'The Night King'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_363', 'White Walker'),
#  ('ch_16', 'Arya Stark', 'killed', 'ch_355', 'Viserion'),
#  ('ch_26', 'Black Walder Rivers', 'killed', 'ch_37', 'Catelyn Stark'),
#  ('ch_28', 'Bowen Marsh', 'killed', 'ch_124', 'Jon Snow'),
#  ('ch_32', 'Brienne of Tarth', 'killed', None, 'Soldier Tom'),
#  ('ch_32', 'Brienne of Tarth', 'killed', 'ch_317', 'Stannis Baratheon'),
#  ('ch_32', 'Brienne of Tarth', 'killed', None, 'Bolton Officer'),
#  ('ch_33', 'Bronn', 'killed', 'ch_353', 'Vardis Egen'),
#  ('ch_33', 'Bronn', 'killed', 'ch_205', 'Matthos Seaworth'),
#  ('ch_33', 'Bronn', 'killed', 'ch_159', 'Lead Dornish Guard'),
#  ('ch_37', 'Catelyn Stark', 'killed', 'ch_128', 'Joyeuse Erenford'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_153', 'Lancel Lannister'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_101', 'High Sparrow'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_175', 'Loras Tyrell'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_186', 'Mace Tyrell'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_200', 'Margaery Tyrell'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_133', 'Kevan Lannister'),
#  ('ch_39', 'Cersei Lannister', 'killed', 'ch_349', 'Tyene Sand'),
#  ('ch_44', 'Daario Naharis', 'killed', 'ch_211', 'Mero'),
#  ('ch_44', 'Daario Naharis', 'killed', 'ch_261', 'Prendahl na Ghezn'),
#  ('ch_44', 'Daario Naharis', 'killed', None, 'Oznak zo Pahl'),
#  ('ch_44', 'Daario Naharis', 'killed', 'ch_219', 'Mossador'),
#  ('ch_44', 'Daario Naharis', 'killed', None, 'Iggo'),
#  ('ch_44', 'Daario Naharis', 'killed', 'ch_5', 'Akho'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_134', 'Khal Drogo'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_216', 'Mirri Maz Duur'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_54', 'Doreah'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_376', 'Xaro Xhoan Daxos'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_136', 'Khal Rhalko'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', None, 'Khal Brozho'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', None, 'Khal Qorro'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', None, 'Khal Forzho'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_135', 'Khal Moro'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_55', 'Dothraki Bloodrider #1'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_56', 'Dothraki Bloodrider #2'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_271', 'Randyll Tarly'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_49', 'Dickon Tarly'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', None, 'Eleanor'),
#  ('ch_45', 'Daenerys Targaryen', 'killed', None, "Eleanor's Daughter"),
#  ('ch_45', 'Daenerys Targaryen', 'killed', 'ch_178', 'Lord Varys'),
#  ('ch_54', 'Doreah', 'killed', 'ch_110', 'Irri'),
#  ('ch_58', 'Drogon', 'killed', 'ch_262', 'Pyat Pree'),
#  ('ch_58', 'Drogon', 'killed', 'ch_149', 'Kraznys mo Nakloz'),
#  ('ch_58', 'Drogon', 'killed', None, 'Zalla'),
#  ('ch_60', 'Eddard Stark', 'killed', 'ch_15', 'Arthur Dayne'),
#  ('ch_60', 'Eddard Stark', 'killed', 'ch_369', 'Will'),
#  ('ch_60', 'Eddard Stark', 'killed', 'ch_151', 'Lady'),
#  ('ch_60', 'Eddard Stark', 'killed', 'ch_72', 'Gerold Hightower'),
#  ('ch_63', 'Ellaria Sand', 'killed', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_63', 'Ellaria Sand', 'killed', 'ch_53', 'Doran Martell'),
#  ('ch_66', 'Euron Greyjoy', 'killed', 'ch_18', 'Balon Greyjoy'),
#  ('ch_66', 'Euron Greyjoy', 'killed', 'ch_245', 'Obara Sand'),
#  ('ch_66', 'Euron Greyjoy', 'killed', 'ch_244', 'Nymeria Sand'),
#  ('ch_66', 'Euron Greyjoy', 'killed', 'ch_279', 'Rhaegal'),
#  ('ch_71', 'Gendry', 'killed', None, 'Kevin Eldon'),
#  ('ch_71', 'Gendry', 'killed', None, 'Laurence Spellman'),
#  ('ch_73', 'Ghost', 'killed', 'ch_272', 'Rast'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_64', 'Elia Martell'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_283', 'Rhaenys Targaryen'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_2', 'Aegon Targaryen'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_107', 'Hugh of the Vale'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_246', 'Oberyn Martell'),
#  ('ch_88', 'Gregor Clegane', 'killed', None, "King's Landing Boaster"),
#  ('ch_88', 'Gregor Clegane', 'killed', None, 'Faith Militant'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_217', 'Missandei'),
#  ('ch_88', 'Gregor Clegane', 'killed', 'ch_268', 'Qyburn'),
#  ('ch_90', 'Grenn', 'killed', 'ch_191', 'Mag the Mighty'),
#  ('ch_91', 'Grey Wind', 'killed', None, 'Rennick'),
#  ('ch_92', 'Grey Worm', 'killed', None, 'Belicho Paenymion'),
#  ('ch_92', 'Grey Worm', 'killed', 'ch_274', 'Razdal mo Eraz'),
#  ('ch_92', 'Grey Worm', 'killed', 'ch_97', 'Harry Strickland'),
#  ('ch_103', 'Hodor', 'killed', 'ch_172', 'Locke'),
#  ('ch_106', 'Howland Reed', 'killed', 'ch_15', 'Arthur Dayne'),
#  ('ch_109', 'Ilyn Payne', 'killed', 'ch_60', 'Eddard Stark'),
#  ('ch_114', 'Jaime Lannister', 'killed', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_114', 'Jaime Lannister', 'killed', 'ch_127', 'Jory Cassel'),
#  ('ch_114', 'Jaime Lannister', 'killed', 'ch_7', 'Alton Lannister'),
#  ('ch_114', 'Jaime Lannister', 'killed', None, 'Torrhen Karstark'),
#  ('ch_114', 'Jaime Lannister', 'killed', 'ch_249', 'Olenna Tyrell'),
#  ('ch_114', 'Jaime Lannister', 'killed', 'ch_66', 'Euron Greyjoy'),
#  ('ch_115', 'Janos Slynt', 'killed', None, 'Barra'),
#  ('ch_116', "Jaqen H'ghar", 'killed', 'ch_334', 'The Tickler'),
#  ('ch_116', "Jaqen H'ghar", 'killed', 'ch_9', 'Amory Lorch'),
#  ('ch_116', "Jaqen H'ghar", 'killed', None, 'Despondent Man'),
#  ('ch_121', 'Joffrey Baratheon', 'killed', 'ch_294', 'Ros'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_256', 'Othor'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_265', 'Qhorin Halfhand'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_252', 'Orell'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_129', 'Karl Tanner'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_326', 'Styr'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_196', 'Mance Rayder'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_115', 'Janos Slynt'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_363', 'White Walker'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_6', 'Alliser Thorne'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_255', 'Othell Yarwyck'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_28', 'Bowen Marsh'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_250', 'Olly'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_184', 'Lyanna Stark'),
#  ('ch_124', 'Jon Snow', 'killed', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_126', 'Jorah Mormont', 'killed', 'ch_266', 'Qotho'),
#  ('ch_126', 'Jorah Mormont', 'killed', None, 'Norvoshi Pit Fighter'),
#  ('ch_126', 'Jorah Mormont', 'killed', None, 'Meereenese Champion'),
#  ('ch_129', 'Karl Tanner', 'killed', 'ch_43', 'Craster'),
#  ('ch_134', 'Khal Drogo', 'killed', 'ch_356', 'Viserys Targaryen'),
#  ('ch_134', 'Khal Drogo', 'killed', 'ch_193', 'Mago'),
#  ('ch_161', 'Lem Lemoncloak', 'killed', 'ch_34', 'Brother Ray'),
#  ('ch_180', 'Lothar Frey', 'killed', 'ch_329', 'Talisa Maegyr'),
#  ('ch_183', 'Lyanna Mormont', 'killed', 'ch_374', 'Wun Wun'),
#  ('ch_185', 'Lysa Arryn', 'killed', 'ch_123', 'Jon Arryn'),
#  ('ch_188', 'Maester Cressen', 'killed', 'ch_188', 'Maester Cressen'),
#  ('ch_191', 'Mag the Mighty', 'killed', 'ch_90', 'Grenn'),
#  ('ch_191', 'Mag the Mighty', 'killed', None, 'Donnel Hill'),
#  ('ch_191', 'Mag the Mighty', 'killed', None, 'Cooper'),
#  ('ch_206', 'Meera Reed', 'killed', 'ch_122', 'Jojen Reed'),
#  ('ch_206', 'Meera Reed', 'killed', 'ch_363', 'White Walker'),
#  ('ch_209', 'Melisandre', 'killed', 'ch_278', 'Renly Baratheon'),
#  ('ch_209', 'Melisandre', 'killed', None, 'Axell Florent'),
#  ('ch_209', 'Melisandre', 'killed', 'ch_196', 'Mance Rayder'),
#  ('ch_209', 'Melisandre', 'killed', 'ch_313', 'Shireen Baratheon'),
#  ('ch_212', 'Meryn Trant', 'killed', 'ch_328', 'Syrio Forel'),
#  ('ch_216', 'Mirri Maz Duur', 'killed', 'ch_281', 'Rhaego'),
#  ('ch_219', 'Mossador', 'killed', None, 'Son of the Harpy'),
#  ('ch_245', 'Obara Sand', 'killed', 'ch_210', 'Merchant Captain'),
#  ('ch_245', 'Obara Sand', 'killed', 'ch_347', 'Trystane Martell'),
#  ('ch_249', 'Olenna Tyrell', 'killed', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_250', 'Olly', 'killed', 'ch_379', 'Ygritte'),
#  ('ch_250', 'Olly', 'killed', 'ch_124', 'Jon Snow'),
#  ('ch_254', 'Osha', 'killed', 'ch_57', 'Drennan'),
#  ('ch_254', 'Osha', 'killed', 'ch_189', 'Maester Luwin'),
#  ('ch_255', 'Othell Yarwyck', 'killed', 'ch_124', 'Jon Snow'),
#  ('ch_258', 'Petyr Baelish', 'killed', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_258', 'Petyr Baelish', 'killed', 'ch_52', 'Dontos Hollard'),
#  ('ch_258', 'Petyr Baelish', 'killed', 'ch_185', 'Lysa Arryn'),
#  ('ch_259', 'Podrick Payne', 'killed', 'ch_197', 'Mandon Moore'),
#  ('ch_259', 'Podrick Payne', 'killed', None, 'Bolton Soldier'),
#  ('ch_260', 'Polliver', 'killed', 'ch_174', 'Lommy Greenhands'),
#  ('ch_262', 'Pyat Pree', 'killed', 'ch_316', 'Spice King'),
#  ('ch_262', 'Pyat Pree', 'killed', 'ch_314', 'Silk King'),
#  ('ch_270', 'Ramsay Snow', 'killed', None, 'Master Torturer'),
#  ('ch_270', 'Ramsay Snow', 'killed', None, 'Medger Cerwyn'),
#  ('ch_270', 'Ramsay Snow', 'killed', None, 'Lady Cerwyn'),
#  ('ch_270', 'Ramsay Snow', 'killed', None, 'Unidentified Cerwyn'),
#  ('ch_270', 'Ramsay Snow', 'killed', None, 'Old Woman'),
#  ('ch_270', 'Ramsay Snow', 'killed', 'ch_292', 'Roose Bolton'),
#  ('ch_270', 'Ramsay Snow', 'killed', 'ch_254', 'Osha'),
#  ('ch_270', 'Ramsay Snow', 'killed', 'ch_286', 'Rickon Stark'),
#  ('ch_270', 'Ramsay Snow', 'killed', 'ch_374', 'Wun Wun'),
#  ('ch_272', 'Rast', 'killed', 'ch_119', 'Jeor Mormont'),
#  ('ch_279', 'Rhaegal', 'killed', 'ch_262', 'Pyat Pree'),
#  ('ch_279', 'Rhaegal', 'killed', 'ch_80', 'Great Master #1'),
#  ('ch_284', 'Rickard Karstark', 'killed', 'ch_203', 'Martyn Lannister'),
#  ('ch_284', 'Rickard Karstark', 'killed', 'ch_370', 'Willem Lannister'),
#  ('ch_287', 'Robb Stark', 'killed', 'ch_359', 'Wallen'),
#  ('ch_287', 'Robb Stark', 'killed', 'ch_284', 'Rickard Karstark'),
#  ('ch_288', 'Robert Baratheon', 'killed', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_292', 'Roose Bolton', 'killed', 'ch_287', 'Robb Stark'),
#  ('ch_299', 'Samwell Tarly', 'killed', 'ch_363', 'White Walker'),
#  ('ch_299', 'Samwell Tarly', 'killed', 'ch_336', 'Thenn Warg'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_228', 'Mycah'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Kings Landing Rioter #1'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Kings Landing Rioter #2'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Kings Landing Rioter #3'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_22', 'Beric Dondarrion'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Frey Soldier #2'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Lowell'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Dying Man'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_24', 'Biter'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Steve'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Riddell'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_70', 'Gatins'),
#  ('ch_300', 'Sandor Clegane', 'killed', None, 'Morgan'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_161', 'Lem Lemoncloak'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_88', 'Gregor Clegane'),
#  ('ch_300', 'Sandor Clegane', 'killed', 'ch_300', 'Sandor Clegane'),
#  ('ch_302', 'Selyse Baratheon', 'killed', 'ch_302', 'Selyse Baratheon'),
#  ('ch_315', 'Smalljon Umber', 'killed', 'ch_312', 'Shaggydog'),
#  ('ch_317', 'Stannis Baratheon', 'killed', None, 'Gordy'),
#  ('ch_317', 'Stannis Baratheon', 'killed', None, 'Simpson'),
#  ('ch_326', 'Styr', 'killed', None, "Olly's Mother"),
#  ('ch_327', 'Summer', 'killed', 'ch_38', 'Catspaw Assassin'),
#  ('ch_333', 'The Night King', 'killed', 'ch_340', 'Three-Eyed Raven'),
#  ('ch_333', 'The Night King', 'killed', 'ch_355', 'Viserion'),
#  ('ch_333', 'The Night King', 'killed', 'ch_231', 'Ned Umber'),
#  ('ch_333', 'The Night King', 'killed', 'ch_337', 'Theon Greyjoy'),
#  ('ch_334', 'The Tickler', 'killed', None, 'Tortured Prisoner'),
#  ('ch_335', 'The Waif', 'killed', 'ch_152', 'Lady Crane'),
#  ('ch_337', 'Theon Greyjoy', 'killed', 'ch_325', 'Stiv'),
#  ('ch_337', 'Theon Greyjoy', 'killed', 'ch_291', 'Rodrik Cassel'),
#  ('ch_337', 'Theon Greyjoy', 'killed', 'ch_229', 'Myranda'),
#  ('ch_337', 'Theon Greyjoy', 'killed', None, 'Bolton Soldier'),
#  ('ch_337', 'Theon Greyjoy', 'killed', None, 'Harrag'),
#  ('ch_345', 'Tommen Baratheon', 'killed', 'ch_345', 'Tommen Baratheon'),
#  ('ch_346', 'Tormund Giantsbane', 'killed', 'ch_273', 'Rattleshirt'),
#  ('ch_346', 'Tormund Giantsbane', 'killed', 'ch_315', 'Smalljon Umber'),
#  ('ch_349', 'Tyene Sand', 'killed', 'ch_12', 'Areo Hotah'),
#  ('ch_349', 'Tyene Sand', 'killed', None, 'Maester Caleotte'),
#  ('ch_350', 'Tyrion Lannister', 'killed', 'ch_310', 'Shae'),
#  ('ch_350', 'Tyrion Lannister', 'killed', 'ch_351', 'Tywin Lannister'),
#  ('ch_355', 'Viserion', 'killed', 'ch_262', 'Pyat Pree'),
#  ('ch_355', 'Viserion', 'killed', 'ch_80', 'Great Master #1'),
#  ('ch_363', 'White Walker', 'killed', 'ch_171', 'Loboda'),
#  ('ch_374', 'Wun Wun', 'killed', 'ch_183', 'Lyanna Mormont'),
#  ('ch_379', 'Ygritte', 'killed', None, 'Old Man'),
#  ('ch_379', 'Ygritte', 'killed', None, 'Guymon'),
#  ('ch_379', 'Ygritte', 'killed', None, "Mole's Town Whore"),
#  ('ch_379', 'Ygritte', 'killed', 'ch_263', 'Pypar'),
#  ('ch_283', 'Rhaenys Targaryen', 'sibling', 'ch_2', 'Aegon Targaryen'),
#  ('ch_283', 'Rhaenys Targaryen', 'sibling', 'ch_124', 'Jon Snow'),
#  ('ch_2', 'Aegon Targaryen', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_4', 'Aerys II Targaryen', 'killedBy', 'ch_114', 'Jaime Lannister'),
#  ('ch_5', 'Akho', 'killedBy', 'ch_44', 'Daario Naharis'),
#  ('ch_6', 'Alliser Thorne', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_7', 'Alton Lannister', 'killedBy', 'ch_114', 'Jaime Lannister'),
#  ('ch_9', 'Amory Lorch', 'killedBy', 'ch_116', "Jaqen H'ghar"),
#  ('ch_12', 'Areo Hotah', 'killedBy', 'ch_349', 'Tyene Sand'),
#  ('ch_15', 'Arthur Dayne', 'killedBy', 'ch_106', 'Howland Reed'),
#  ('ch_15', 'Arthur Dayne', 'killedBy', 'ch_60', 'Eddard Stark'),
#  ('ch_18', 'Balon Greyjoy', 'killedBy', 'ch_66', 'Euron Greyjoy'),
#  ('ch_20', 'Barristan Selmy', 'killedBy', None, 'Sons of the Harpy'),
#  ('ch_21', 'Benjen Stark', 'killedBy', None, 'Wights'),
#  ('ch_22', 'Beric Dondarrion', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_22', 'Beric Dondarrion', 'killedBy', None, 'Wights'),
#  ('ch_24', 'Biter', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_26', 'Black Walder Rivers', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_28', 'Bowen Marsh', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_29', 'Brandon Stark', 'killedBy', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_34', 'Brother Ray', 'killedBy', 'ch_161', 'Lem Lemoncloak'),
#  ('ch_37', 'Catelyn Stark', 'killedBy', 'ch_26', 'Black Walder Rivers'),
#  ('ch_38', 'Catspaw Assassin', 'killedBy', 'ch_327', 'Summer'),
#  ('ch_39', 'Cersei Lannister', 'killedBy', None, 'Roof collapse'),
#  ('ch_43', 'Craster', 'killedBy', 'ch_129', 'Karl Tanner'),
#  ('ch_45', 'Daenerys Targaryen', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_49', 'Dickon Tarly', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_50', 'Dongo the Giant', 'killedBy', 'ch_236', "Night's Watchman"),
#  ('ch_52', 'Dontos Hollard', 'killedBy', 'ch_258', 'Petyr Baelish'),
#  ('ch_53', 'Doran Martell', 'killedBy', 'ch_63', 'Ellaria Sand'),
#  ('ch_54', 'Doreah', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_55', 'Dothraki Bloodrider #1', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_56', 'Dothraki Bloodrider #2', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_57', 'Drennan', 'killedBy', 'ch_254', 'Osha'),
#  ('ch_60', 'Eddard Stark', 'killedBy', 'ch_109', 'Ilyn Payne'),
#  ('ch_61', 'Eddison Tollett', 'killedBy', None, 'Wight'),
#  ('ch_64', 'Elia Martell', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_66', 'Euron Greyjoy', 'killedBy', 'ch_114', 'Jaime Lannister'),
#  ('ch_69', 'Gared', 'killedBy', 'ch_363', 'White Walker'),
#  ('ch_70', 'Gatins', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_72', 'Gerold Hightower', 'killedBy', 'ch_60', 'Eddard Stark'),
#  ('ch_79', 'Grand Maester Pycelle', 'killedBy', None, 'Little Birds'),
#  ('ch_80', 'Great Master #1', 'killedBy', None, 'Rebel Slaves'),
#  ('ch_80', 'Great Master #1', 'killedBy', 'ch_355', 'Viserion'),
#  ('ch_80', 'Great Master #1', 'killedBy', 'ch_279', 'Rhaegal'),
#  ('ch_88', 'Gregor Clegane', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_89', 'Greizhen mo Ullhor', 'killedBy', None, 'Unsullied'),
#  ('ch_90', 'Grenn', 'killedBy', 'ch_191', 'Mag the Mighty'),
#  ('ch_91', 'Grey Wind', 'killedBy', None, 'Frey Crossbowmen'),
#  ('ch_97', 'Harry Strickland', 'killedBy', 'ch_92', 'Grey Worm'),
#  ('ch_100', 'High Septon', 'killedBy', None, 'Kings Landing Rioters'),
#  ('ch_101', 'High Sparrow', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_102', 'Hizdahr zo Loraq', 'killedBy', None, 'Sons of the Harpy'),
#  ('ch_103', 'Hodor', 'killedBy', None, 'Wights'),
#  ('ch_107', 'Hugh of the Vale', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_110', 'Irri', 'killedBy', 'ch_54', 'Doreah'),
#  ('ch_113', 'Jafer Flowers', 'killedBy', 'ch_363', 'White Walker'),
#  ('ch_114', 'Jaime Lannister', 'killedBy', None, 'Roof collapse'),
#  ('ch_115', 'Janos Slynt', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_119', 'Jeor Mormont', 'killedBy', 'ch_272', 'Rast'),
#  ('ch_121', 'Joffrey Baratheon', 'killedBy', 'ch_258', 'Petyr Baelish'),
#  ('ch_121', 'Joffrey Baratheon', 'killedBy', 'ch_249', 'Olenna Tyrell'),
#  ('ch_122', 'Jojen Reed', 'killedBy', 'ch_206', 'Meera Reed'),
#  ('ch_123', 'Jon Arryn', 'killedBy', 'ch_185', 'Lysa Arryn'),
#  ('ch_124', 'Jon Snow', 'killedBy', 'ch_6', 'Alliser Thorne'),
#  ('ch_124', 'Jon Snow', 'killedBy', 'ch_255', 'Othell Yarwyck'),
#  ('ch_124', 'Jon Snow', 'killedBy', 'ch_28', 'Bowen Marsh'),
#  ('ch_124', 'Jon Snow', 'killedBy', 'ch_250', 'Olly'),
#  ('ch_126', 'Jorah Mormont', 'killedBy', None, 'Wights'),
#  ('ch_127', 'Jory Cassel', 'killedBy', 'ch_114', 'Jaime Lannister'),
#  ('ch_128', 'Joyeuse Erenford', 'killedBy', 'ch_37', 'Catelyn Stark'),
#  ('ch_129', 'Karl Tanner', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_130', 'Karsi', 'killedBy', None, 'Pack of Wights'),
#  ('ch_132', 'Kegs', 'killedBy', None, 'Wildling'),
#  ('ch_133', 'Kevan Lannister', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_134', 'Khal Drogo', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_135', 'Khal Moro', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_136', 'Khal Rhalko', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_141', "King's Landing Rioter #1", 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_142', "King's Landing Rioter #2", 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_143', "King's Landing Rioter #3", 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_149', 'Kraznys mo Nakloz', 'killedBy', 'ch_58', 'Drogon'),
#  ('ch_150', 'Kurleket', 'killedBy', None, 'Mountain Clansman'),
#  ('ch_151', 'Lady', 'killedBy', 'ch_60', 'Eddard Stark'),
#  ('ch_152', 'Lady Crane', 'killedBy', 'ch_335', 'The Waif'),
#  ('ch_153', 'Lancel Lannister', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_159', 'Lead Dornish Guard', 'killedBy', 'ch_33', 'Bronn'),
#  ('ch_160', 'Leaf', 'killedBy', None, 'Wights'),
#  ('ch_161', 'Lem Lemoncloak', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_171', 'Loboda', 'killedBy', 'ch_363', 'White Walker'),
#  ('ch_172', 'Locke', 'killedBy', 'ch_103', 'Hodor'),
#  ('ch_174', 'Lommy Greenhands', 'killedBy', 'ch_260', 'Polliver'),
#  ('ch_175', 'Loras Tyrell', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_178', 'Lord Varys', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_180', 'Lothar Frey', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_183', 'Lyanna Mormont', 'killedBy', 'ch_374', 'Wun Wun'),
#  ('ch_184', 'Lyanna Stark', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_185', 'Lysa Arryn', 'killedBy', 'ch_258', 'Petyr Baelish'),
#  ('ch_186', 'Mace Tyrell', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_187', 'Maester Aemon', 'killedBy', None, 'Old Age'),
#  ('ch_188', 'Maester Cressen', 'killedBy', 'ch_188', 'Maester Cressen'),
#  ('ch_189', 'Maester Luwin', 'killedBy', 'ch_254', 'Osha'),
#  ('ch_191', 'Mag the Mighty', 'killedBy', 'ch_90', 'Grenn'),
#  ('ch_191', 'Mag the Mighty', 'killedBy', None, 'Donnel Hill'),
#  ('ch_191', 'Mag the Mighty', 'killedBy', None, 'Cooper'),
#  ('ch_193', 'Mago', 'killedBy', 'ch_134', 'Khal Drogo'),
#  ('ch_196', 'Mance Rayder', 'killedBy', 'ch_209', 'Melisandre'),
#  ('ch_196', 'Mance Rayder', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_197', 'Mandon Moore', 'killedBy', 'ch_259', 'Podrick Payne'),
#  ('ch_200', 'Margaery Tyrell', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_203', 'Martyn Lannister', 'killedBy', 'ch_284', 'Rickard Karstark'),
#  ('ch_205', 'Matthos Seaworth', 'killedBy', 'ch_33', 'Bronn'),
#  ('ch_209', 'Melisandre', 'killedBy', None, 'Old Age'),
#  ('ch_210', 'Merchant Captain', 'killedBy', 'ch_245', 'Obara Sand'),
#  ('ch_211', 'Mero', 'killedBy', 'ch_44', 'Daario Naharis'),
#  ('ch_212', 'Meryn Trant', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_216', 'Mirri Maz Duur', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_217', 'Missandei', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_219', 'Mossador', 'killedBy', 'ch_44', 'Daario Naharis'),
#  ('ch_228', 'Mycah', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_229', 'Myranda', 'killedBy', 'ch_337', 'Theon Greyjoy'),
#  ('ch_230', 'Myrcella Baratheon', 'killedBy', 'ch_63', 'Ellaria Sand'),
#  ('ch_231', 'Ned Umber', 'killedBy', 'ch_333', 'The Night King'),
#  ('ch_244', 'Nymeria Sand', 'killedBy', 'ch_66', 'Euron Greyjoy'),
#  ('ch_245', 'Obara Sand', 'killedBy', 'ch_66', 'Euron Greyjoy'),
#  ('ch_246', 'Oberyn Martell', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_249', 'Olenna Tyrell', 'killedBy', 'ch_114', 'Jaime Lannister'),
#  ('ch_250', 'Olly', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_252', 'Orell', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_254', 'Osha', 'killedBy', 'ch_270', 'Ramsay Snow'),
#  ('ch_255', 'Othell Yarwyck', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_256', 'Othor', 'killedBy', 'ch_363', 'White Walker'),
#  ('ch_256', 'Othor', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_258', 'Petyr Baelish', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_260', 'Polliver', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_261', 'Prendahl na Ghezn', 'killedBy', 'ch_44', 'Daario Naharis'),
#  ('ch_262', 'Pyat Pree', 'killedBy', 'ch_58', 'Drogon'),
#  ('ch_262', 'Pyat Pree', 'killedBy', 'ch_355', 'Viserion'),
#  ('ch_262', 'Pyat Pree', 'killedBy', 'ch_279', 'Rhaegal'),
#  ('ch_263', 'Pypar', 'killedBy', 'ch_379', 'Ygritte'),
#  ('ch_265', 'Qhorin Halfhand', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_266', 'Qotho', 'killedBy', 'ch_126', 'Jorah Mormont'),
#  ('ch_268', 'Qyburn', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_269', 'Rakharo', 'killedBy', None, "Khal Jhaqo's Khalasar"),
#  ('ch_270', 'Ramsay Snow', 'killedBy', None, "Ramsay Snow's Hounds"),
#  ('ch_271', 'Randyll Tarly', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_272', 'Rast', 'killedBy', 'ch_73', 'Ghost'),
#  ('ch_273', 'Rattleshirt', 'killedBy', 'ch_346', 'Tormund Giantsbane'),
#  ('ch_274', 'Razdal mo Eraz', 'killedBy', 'ch_92', 'Grey Worm'),
#  ('ch_275', 'Red Keep Stableboy', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_278', 'Renly Baratheon', 'killedBy', 'ch_209', 'Melisandre'),
#  ('ch_279', 'Rhaegal', 'killedBy', 'ch_66', 'Euron Greyjoy'),
#  ('ch_280', 'Rhaegar Targaryen', 'killedBy', 'ch_288', 'Robert Baratheon'),
#  ('ch_281', 'Rhaego', 'killedBy', 'ch_216', 'Mirri Maz Duur'),
#  ('ch_283', 'Rhaenys Targaryen', 'killedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_284', 'Rickard Karstark', 'killedBy', 'ch_287', 'Robb Stark'),
#  ('ch_285', 'Rickard Stark', 'killedBy', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_286', 'Rickon Stark', 'killedBy', 'ch_270', 'Ramsay Snow'),
#  ('ch_287', 'Robb Stark', 'killedBy', 'ch_292', 'Roose Bolton'),
#  ('ch_288', 'Robert Baratheon', 'killedBy', None, 'Boar'),
#  ('ch_291', 'Rodrik Cassel', 'killedBy', 'ch_337', 'Theon Greyjoy'),
#  ('ch_292', 'Roose Bolton', 'killedBy', 'ch_270', 'Ramsay Snow'),
#  ('ch_293', 'Rorge', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_294', 'Ros', 'killedBy', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_300', 'Sandor Clegane', 'killedBy', 'ch_300', 'Sandor Clegane'),
#  ('ch_302', 'Selyse Baratheon', 'killedBy', 'ch_302', 'Selyse Baratheon'),
#  ('ch_304', 'Septa Mordane', 'killedBy', 'ch_156', 'Lannister Guardsman'),
#  ('ch_310', 'Shae', 'killedBy', 'ch_350', 'Tyrion Lannister'),
#  ('ch_312', 'Shaggydog', 'killedBy', 'ch_315', 'Smalljon Umber'),
#  ('ch_313', 'Shireen Baratheon', 'killedBy', 'ch_209', 'Melisandre'),
#  ('ch_314', 'Silk King', 'killedBy', 'ch_262', 'Pyat Pree'),
#  ('ch_315', 'Smalljon Umber', 'killedBy', 'ch_346', 'Tormund Giantsbane'),
#  ('ch_316', 'Spice King', 'killedBy', 'ch_262', 'Pyat Pree'),
#  ('ch_317', 'Stannis Baratheon', 'killedBy', 'ch_32', 'Brienne of Tarth'),
#  ('ch_325', 'Stiv', 'killedBy', 'ch_337', 'Theon Greyjoy'),
#  ('ch_326', 'Styr', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_327', 'Summer', 'killedBy', None, 'Wights'),
#  ('ch_328', 'Syrio Forel', 'killedBy', 'ch_212', 'Meryn Trant'),
#  ('ch_329', 'Talisa Maegyr', 'killedBy', 'ch_180', 'Lothar Frey'),
#  ('ch_333', 'The Night King', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_334', 'The Tickler', 'killedBy', 'ch_116', "Jaqen H'ghar"),
#  ('ch_335', 'The Waif', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_336', 'Thenn Warg', 'killedBy', 'ch_299', 'Samwell Tarly'),
#  ('ch_337', 'Theon Greyjoy', 'killedBy', 'ch_333', 'The Night King'),
#  ('ch_340', 'Three-Eyed Raven', 'killedBy', 'ch_333', 'The Night King'),
#  ('ch_345', 'Tommen Baratheon', 'killedBy', 'ch_345', 'Tommen Baratheon'),
#  ('ch_347', 'Trystane Martell', 'killedBy', 'ch_245', 'Obara Sand'),
#  ('ch_349', 'Tyene Sand', 'killedBy', 'ch_39', 'Cersei Lannister'),
#  ('ch_351', 'Tywin Lannister', 'killedBy', 'ch_350', 'Tyrion Lannister'),
#  ('ch_353', 'Vardis Egen', 'killedBy', 'ch_33', 'Bronn'),
#  ('ch_354', 'Varly', 'killedBy', 'ch_75', 'Goldcloak'),
#  ('ch_355', 'Viserion', 'killedBy', 'ch_333', 'The Night King'),
#  ('ch_355', 'Viserion', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_356', 'Viserys Targaryen', 'killedBy', 'ch_134', 'Khal Drogo'),
#  ('ch_357', 'Walda Bolton', 'killedBy', None, "Ramsay Snow's Hounds"),
#  ('ch_358', 'Walder Frey', 'killedBy', 'ch_16', 'Arya Stark'),
#  ('ch_359', 'Wallen', 'killedBy', 'ch_287', 'Robb Stark'),
#  ('ch_361', 'Waymar Royce', 'killedBy', 'ch_363', 'White Walker'),
#  ('ch_363', 'White Walker', 'killedBy', 'ch_299', 'Samwell Tarly'),
#  ('ch_363', 'White Walker', 'killedBy', 'ch_124', 'Jon Snow'),
#  ('ch_369', 'Will', 'killedBy', 'ch_60', 'Eddard Stark'),
#  ('ch_370', 'Willem Lannister', 'killedBy', 'ch_284', 'Rickard Karstark'),
#  ('ch_371', 'Willis Wode', 'killedBy', None, 'Mountain Clansman'),
#  ('ch_374', 'Wun Wun', 'killedBy', 'ch_270', 'Ramsay Snow'),
#  ('ch_374', 'Wun Wun', 'killedBy', 'ch_183', 'Lyanna Mormont'),
#  ('ch_376', 'Xaro Xhoan Daxos', 'killedBy', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_379', 'Ygritte', 'killedBy', 'ch_250', 'Olly'),
#  ('ch_381', 'Yoren', 'killedBy', 'ch_9', 'Amory Lorch'),
#  ('ch_4', 'Aerys II Targaryen', 'parentOf', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_4', 'Aerys II Targaryen', 'parentOf', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_4', 'Aerys II Targaryen', 'parentOf', 'ch_356', 'Viserys Targaryen'),
#  ('ch_18', 'Balon Greyjoy', 'parentOf', 'ch_377', 'Yara Greyjoy'),
#  ('ch_18', 'Balon Greyjoy', 'parentOf', 'ch_337', 'Theon Greyjoy'),
#  ('ch_37', 'Catelyn Stark', 'parentOf', 'ch_287', 'Robb Stark'),
#  ('ch_37', 'Catelyn Stark', 'parentOf', 'ch_301', 'Sansa Stark'),
#  ('ch_37', 'Catelyn Stark', 'parentOf', 'ch_16', 'Arya Stark'),
#  ('ch_37', 'Catelyn Stark', 'parentOf', 'ch_30', 'Bran Stark'),
#  ('ch_37', 'Catelyn Stark', 'parentOf', 'ch_286', 'Rickon Stark'),
#  ('ch_39', 'Cersei Lannister', 'parentOf', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_39', 'Cersei Lannister', 'parentOf', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_39', 'Cersei Lannister', 'parentOf', 'ch_345', 'Tommen Baratheon'),
#  ('ch_45', 'Daenerys Targaryen', 'parentOf', 'ch_281', 'Rhaego'),
#  ('ch_48', 'Davos Seaworth', 'parentOf', 'ch_205', 'Matthos Seaworth'),
#  ('ch_53', 'Doran Martell', 'parentOf', 'ch_347', 'Trystane Martell'),
#  ('ch_60', 'Eddard Stark', 'parentOf', 'ch_287', 'Robb Stark'),
#  ('ch_60', 'Eddard Stark', 'parentOf', 'ch_301', 'Sansa Stark'),
#  ('ch_60', 'Eddard Stark', 'parentOf', 'ch_16', 'Arya Stark'),
#  ('ch_60', 'Eddard Stark', 'parentOf', 'ch_30', 'Bran Stark'),
#  ('ch_60', 'Eddard Stark', 'parentOf', 'ch_286', 'Rickon Stark'),
#  ('ch_63', 'Ellaria Sand', 'parentOf', 'ch_349', 'Tyene Sand'),
#  ('ch_64', 'Elia Martell', 'parentOf', 'ch_283', 'Rhaenys Targaryen'),
#  ('ch_64', 'Elia Martell', 'parentOf', 'ch_2', 'Aegon Targaryen'),
#  ('ch_74', 'Gilly', 'parentOf', 'ch_17', 'Baby Sam'),
#  ('ch_87', 'Greatjon Umber', 'parentOf', 'ch_315', 'Smalljon Umber'),
#  ('ch_96', 'Harald Karstark', 'parentOf', 'ch_8', 'Alys Karstark'),
#  ('ch_106', 'Howland Reed', 'parentOf', 'ch_122', 'Jojen Reed'),
#  ('ch_106', 'Howland Reed', 'parentOf', 'ch_206', 'Meera Reed'),
#  ('ch_114', 'Jaime Lannister', 'parentOf', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_114', 'Jaime Lannister', 'parentOf', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_114', 'Jaime Lannister', 'parentOf', 'ch_345', 'Tommen Baratheon'),
#  ('ch_119', 'Jeor Mormont', 'parentOf', 'ch_126', 'Jorah Mormont'),
#  ('ch_130', 'Karsi', 'parentOf', None, 'Johnna'),
#  ('ch_130', 'Karsi', 'parentOf', None, 'Willa'),
#  ('ch_133', 'Kevan Lannister', 'parentOf', 'ch_153', 'Lancel Lannister'),
#  ('ch_133', 'Kevan Lannister', 'parentOf', 'ch_203', 'Martyn Lannister'),
#  ('ch_133', 'Kevan Lannister', 'parentOf', 'ch_370', 'Willem Lannister'),
#  ('ch_134', 'Khal Drogo', 'parentOf', 'ch_281', 'Rhaego'),
#  ('ch_184', 'Lyanna Stark', 'parentOf', 'ch_124', 'Jon Snow'),
#  ('ch_186', 'Mace Tyrell', 'parentOf', 'ch_200', 'Margaery Tyrell'),
#  ('ch_186', 'Mace Tyrell', 'parentOf', 'ch_175', 'Loras Tyrell'),
#  ('ch_208', 'Melessa Tarly', 'parentOf', 'ch_49', 'Dickon Tarly'),
#  ('ch_208', 'Melessa Tarly', 'parentOf', 'ch_299', 'Samwell Tarly'),
#  ('ch_208', 'Melessa Tarly', 'parentOf', 'ch_330', 'Talla Tarly'),
#  ('ch_246', 'Oberyn Martell', 'parentOf', 'ch_245', 'Obara Sand'),
#  ('ch_246', 'Oberyn Martell', 'parentOf', 'ch_244', 'Nymeria Sand'),
#  ('ch_246', 'Oberyn Martell', 'parentOf', 'ch_349', 'Tyene Sand'),
#  ('ch_249', 'Olenna Tyrell', 'parentOf', 'ch_186', 'Mace Tyrell'),
#  ('ch_271', 'Randyll Tarly', 'parentOf', 'ch_49', 'Dickon Tarly'),
#  ('ch_271', 'Randyll Tarly', 'parentOf', 'ch_299', 'Samwell Tarly'),
#  ('ch_271', 'Randyll Tarly', 'parentOf', 'ch_330', 'Talla Tarly'),
#  ('ch_280', 'Rhaegar Targaryen', 'parentOf', 'ch_124', 'Jon Snow'),
#  ('ch_280', 'Rhaegar Targaryen', 'parentOf', 'ch_283', 'Rhaenys Targaryen'),
#  ('ch_280', 'Rhaegar Targaryen', 'parentOf', 'ch_2', 'Aegon Targaryen'),
#  ('ch_282', 'Rhaella Targaryen', 'parentOf', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_282', 'Rhaella Targaryen', 'parentOf', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_282', 'Rhaella Targaryen', 'parentOf', 'ch_356', 'Viserys Targaryen'),
#  ('ch_284', 'Rickard Karstark', 'parentOf', 'ch_96', 'Harald Karstark'),
#  ('ch_285', 'Rickard Stark', 'parentOf', 'ch_29', 'Brandon Stark'),
#  ('ch_285', 'Rickard Stark', 'parentOf', 'ch_21', 'Benjen Stark'),
#  ('ch_285', 'Rickard Stark', 'parentOf', 'ch_60', 'Eddard Stark'),
#  ('ch_285', 'Rickard Stark', 'parentOf', 'ch_184', 'Lyanna Stark'),
#  ('ch_288', 'Robert Baratheon', 'parentOf', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_288', 'Robert Baratheon', 'parentOf', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_288', 'Robert Baratheon', 'parentOf', 'ch_345', 'Tommen Baratheon'),
#  ('ch_292', 'Roose Bolton', 'parentOf', 'ch_270', 'Ramsay Snow'),
#  ('ch_299', 'Samwell Tarly', 'parentOf', 'ch_17', 'Baby Sam'),
#  ('ch_302', 'Selyse Baratheon', 'parentOf', 'ch_313', 'Shireen Baratheon'),
#  ('ch_317', 'Stannis Baratheon', 'parentOf', 'ch_313', 'Shireen Baratheon'),
#  ('ch_351', 'Tywin Lannister', 'parentOf', 'ch_114', 'Jaime Lannister'),
#  ('ch_351', 'Tywin Lannister', 'parentOf', 'ch_39', 'Cersei Lannister'),
#  ('ch_351', 'Tywin Lannister', 'parentOf', 'ch_350', 'Tyrion Lannister'),
#  ('ch_358', 'Walder Frey', 'parentOf', 'ch_26', 'Black Walder Rivers'),
#  ('ch_358', 'Walder Frey', 'parentOf', 'ch_180', 'Lothar Frey'),
#  ('ch_358', 'Walder Frey', 'parentOf', 'ch_295', 'Roslin Frey'),
#  ('ch_358', 'Walder Frey', 'parentOf', 'ch_297', 'Ryger Rivers'),
#  ('ch_380', 'Yohn Royce', 'parentOf', 'ch_361', 'Waymar Royce'),
#  ('ch_2', 'Aegon Targaryen', 'parents', 'ch_64', 'Elia Martell'),
#  ('ch_2', 'Aegon Targaryen', 'parents', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_8', 'Alys Karstark', 'parents', 'ch_96', 'Harald Karstark'),
#  ('ch_16', 'Arya Stark', 'parents', 'ch_60', 'Eddard Stark'),
#  ('ch_16', 'Arya Stark', 'parents', 'ch_37', 'Catelyn Stark'),
#  ('ch_17', 'Baby Sam', 'parents', 'ch_299', 'Samwell Tarly'),
#  ('ch_17', 'Baby Sam', 'parents', 'ch_74', 'Gilly'),
#  ('ch_21', 'Benjen Stark', 'parents', 'ch_285', 'Rickard Stark'),
#  ('ch_26', 'Black Walder Rivers', 'parents', 'ch_358', 'Walder Frey'),
#  ('ch_29', 'Brandon Stark', 'parents', 'ch_285', 'Rickard Stark'),
#  ('ch_30', 'Bran Stark', 'parents', 'ch_60', 'Eddard Stark'),
#  ('ch_30', 'Bran Stark', 'parents', 'ch_37', 'Catelyn Stark'),
#  ('ch_37', 'Catelyn Stark', 'parents', 'ch_104', 'Hoster Tully'),
#  ('ch_39', 'Cersei Lannister', 'parents', 'ch_351', 'Tywin Lannister'),
#  ('ch_45', 'Daenerys Targaryen', 'parents', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_45', 'Daenerys Targaryen', 'parents', 'ch_282', 'Rhaella Targaryen'),
#  ('ch_49', 'Dickon Tarly', 'parents', 'ch_271', 'Randyll Tarly'),
#  ('ch_49', 'Dickon Tarly', 'parents', 'ch_208', 'Melessa Tarly'),
#  ('ch_60', 'Eddard Stark', 'parents', 'ch_285', 'Rickard Stark'),
#  ('ch_71', 'Gendry', 'parents', 'ch_288', 'Robert Baratheon'),
#  ('ch_74', 'Gilly', 'parents', 'ch_43', 'Craster'),
#  ('ch_96', 'Harald Karstark', 'parents', 'ch_284', 'Rickard Karstark'),
#  ('ch_114', 'Jaime Lannister', 'parents', 'ch_351', 'Tywin Lannister'),
#  ('ch_121', 'Joffrey Baratheon', 'parents', 'ch_288', 'Robert Baratheon'),
#  ('ch_121', 'Joffrey Baratheon', 'parents', 'ch_39', 'Cersei Lannister'),
#  ('ch_121', 'Joffrey Baratheon', 'parents', 'ch_114', 'Jaime Lannister'),
#  ('ch_122', 'Jojen Reed', 'parents', 'ch_106', 'Howland Reed'),
#  ('ch_124', 'Jon Snow', 'parents', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_124', 'Jon Snow', 'parents', 'ch_184', 'Lyanna Stark'),
#  ('ch_126', 'Jorah Mormont', 'parents', 'ch_119', 'Jeor Mormont'),
#  ('ch_153', 'Lancel Lannister', 'parents', 'ch_133', 'Kevan Lannister'),
#  ('ch_175', 'Loras Tyrell', 'parents', 'ch_186', 'Mace Tyrell'),
#  ('ch_180', 'Lothar Frey', 'parents', 'ch_358', 'Walder Frey'),
#  ('ch_184', 'Lyanna Stark', 'parents', 'ch_285', 'Rickard Stark'),
#  ('ch_185', 'Lysa Arryn', 'parents', 'ch_104', 'Hoster Tully'),
#  ('ch_200', 'Margaery Tyrell', 'parents', 'ch_186', 'Mace Tyrell'),
#  ('ch_203', 'Martyn Lannister', 'parents', 'ch_133', 'Kevan Lannister'),
#  ('ch_205', 'Matthos Seaworth', 'parents', 'ch_48', 'Davos Seaworth'),
#  ('ch_206', 'Meera Reed', 'parents', 'ch_106', 'Howland Reed'),
#  ('ch_230', 'Myrcella Baratheon', 'parents', 'ch_288', 'Robert Baratheon'),
#  ('ch_230', 'Myrcella Baratheon', 'parents', 'ch_39', 'Cersei Lannister'),
#  ('ch_230', 'Myrcella Baratheon', 'parents', 'ch_114', 'Jaime Lannister'),
#  ('ch_244', 'Nymeria Sand', 'parents', 'ch_246', 'Oberyn Martell'),
#  ('ch_245', 'Obara Sand', 'parents', 'ch_246', 'Oberyn Martell'),
#  ('ch_270', 'Ramsay Snow', 'parents', 'ch_292', 'Roose Bolton'),
#  ('ch_280', 'Rhaegar Targaryen', 'parents', 'ch_282', 'Rhaella Targaryen'),
#  ('ch_280', 'Rhaegar Targaryen', 'parents', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_281', 'Rhaego', 'parents', 'ch_134', 'Khal Drogo'),
#  ('ch_281', 'Rhaego', 'parents', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_283', 'Rhaenys Targaryen', 'parents', 'ch_64', 'Elia Martell'),
#  ('ch_283', 'Rhaenys Targaryen', 'parents', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_286', 'Rickon Stark', 'parents', 'ch_60', 'Eddard Stark'),
#  ('ch_286', 'Rickon Stark', 'parents', 'ch_37', 'Catelyn Stark'),
#  ('ch_287', 'Robb Stark', 'parents', 'ch_60', 'Eddard Stark'),
#  ('ch_287', 'Robb Stark', 'parents', 'ch_37', 'Catelyn Stark'),
#  ('ch_290', 'Robin Arryn', 'parents', 'ch_123', 'Jon Arryn'),
#  ('ch_290', 'Robin Arryn', 'parents', 'ch_185', 'Lysa Arryn'),
#  ('ch_295', 'Roslin Frey', 'parents', 'ch_358', 'Walder Frey'),
#  ('ch_297', 'Ryger Rivers', 'parents', 'ch_358', 'Walder Frey'),
#  ('ch_299', 'Samwell Tarly', 'parents', 'ch_271', 'Randyll Tarly'),
#  ('ch_299', 'Samwell Tarly', 'parents', 'ch_208', 'Melessa Tarly'),
#  ('ch_301', 'Sansa Stark', 'parents', 'ch_60', 'Eddard Stark'),
#  ('ch_301', 'Sansa Stark', 'parents', 'ch_37', 'Catelyn Stark'),
#  ('ch_313', 'Shireen Baratheon', 'parents', 'ch_317', 'Stannis Baratheon'),
#  ('ch_313', 'Shireen Baratheon', 'parents', 'ch_302', 'Selyse Baratheon'),
#  ('ch_315', 'Smalljon Umber', 'parents', 'ch_87', 'Greatjon Umber'),
#  ('ch_330', 'Talla Tarly', 'parents', 'ch_271', 'Randyll Tarly'),
#  ('ch_330', 'Talla Tarly', 'parents', 'ch_208', 'Melessa Tarly'),
#  ('ch_337', 'Theon Greyjoy', 'parents', 'ch_18', 'Balon Greyjoy'),
#  ('ch_345', 'Tommen Baratheon', 'parents', 'ch_288', 'Robert Baratheon'),
#  ('ch_345', 'Tommen Baratheon', 'parents', 'ch_39', 'Cersei Lannister'),
#  ('ch_345', 'Tommen Baratheon', 'parents', 'ch_114', 'Jaime Lannister'),
#  ('ch_347', 'Trystane Martell', 'parents', 'ch_53', 'Doran Martell'),
#  ('ch_349', 'Tyene Sand', 'parents', 'ch_246', 'Oberyn Martell'),
#  ('ch_349', 'Tyene Sand', 'parents', 'ch_63', 'Ellaria Sand'),
#  ('ch_350', 'Tyrion Lannister', 'parents', 'ch_351', 'Tywin Lannister'),
#  ('ch_356', 'Viserys Targaryen', 'parents', 'ch_282', 'Rhaella Targaryen'),
#  ('ch_356', 'Viserys Targaryen', 'parents', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_361', 'Waymar Royce', 'parents', 'ch_380', 'Yohn Royce'),
#  ('ch_370', 'Willem Lannister', 'parents', 'ch_133', 'Kevan Lannister'),
#  ('ch_377', 'Yara Greyjoy', 'parents', 'ch_18', 'Balon Greyjoy'),
#  ('ch_16', 'Arya Stark', 'guardedBy', 'ch_243', 'Nymeria'),
#  ('ch_30', 'Bran Stark', 'guardedBy', 'ch_327', 'Summer'),
#  ('ch_45', 'Daenerys Targaryen', 'guardedBy', 'ch_58', 'Drogon'),
#  ('ch_45', 'Daenerys Targaryen', 'guardedBy', 'ch_279', 'Rhaegal'),
#  ('ch_45', 'Daenerys Targaryen', 'guardedBy', 'ch_355', 'Viserion'),
#  ('ch_60', 'Eddard Stark', 'guardedBy', 'ch_123', 'Jon Arryn'),
#  ('ch_124', 'Jon Snow', 'guardedBy', 'ch_60', 'Eddard Stark'),
#  ('ch_124', 'Jon Snow', 'guardedBy', 'ch_73', 'Ghost'),
#  ('ch_286', 'Rickon Stark', 'guardedBy', 'ch_312', 'Shaggydog'),
#  ('ch_287', 'Robb Stark', 'guardedBy', 'ch_91', 'Grey Wind'),
#  ('ch_288', 'Robert Baratheon', 'guardedBy', 'ch_123', 'Jon Arryn'),
#  ('ch_301', 'Sansa Stark', 'guardedBy', 'ch_151', 'Lady'),
#  ('ch_60', 'Eddard Stark', 'allies', 'ch_106', 'Howland Reed'),
#  ('ch_60', 'Eddard Stark', 'allies', 'ch_288', 'Robert Baratheon'),
#  ('ch_106', 'Howland Reed', 'allies', 'ch_60', 'Eddard Stark'),
#  ('ch_123', 'Jon Arryn', 'allies', 'ch_288', 'Robert Baratheon'),
#  ('ch_288', 'Robert Baratheon', 'allies', 'ch_123', 'Jon Arryn'),
#  ('ch_288', 'Robert Baratheon', 'allies', 'ch_60', 'Eddard Stark'),
#  ('ch_288', 'Robert Baratheon', 'allies', 'ch_351', 'Tywin Lannister'),
#  ('ch_351', 'Tywin Lannister', 'allies', 'ch_288', 'Robert Baratheon'),
#  ('ch_184', 'Lyanna Stark', 'abductedBy', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_2', 'Aegon Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_3', 'Aeron Greyjoy', 'houseName', None, 'Greyjoy'),
#  ('ch_4', 'Aerys II Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_7', 'Alton Lannister', 'houseName', None, 'Lannister'),
#  ('ch_16', 'Arya Stark', 'houseName', None, 'Stark'),
#  ('ch_18', 'Balon Greyjoy', 'houseName', None, 'Greyjoy'),
#  ('ch_19', 'Baratheon Guard', 'houseName', None, 'Baratheon'),
#  ('ch_21', 'Benjen Stark', 'houseName', None, 'Stark'),
#  ('ch_26', 'Black Walder Rivers', 'houseName', None, 'Frey'),
#  ('ch_29', 'Brandon Stark', 'houseName', None, 'Stark'),
#  ('ch_30', 'Bran Stark', 'houseName', None, 'Stark'),
#  ('ch_35', 'Brynden Tully', 'houseName', None, 'Tully'),
#  ('ch_37', 'Catelyn Stark', 'houseName', None, 'Stark'),
#  ('ch_37', 'Catelyn Stark', 'houseName', None, 'Tully'),
#  ('ch_39', 'Cersei Lannister', 'houseName', None, 'Lannister'),
#  ('ch_39', 'Cersei Lannister', 'houseName', None, 'Baratheon'),
#  ('ch_45', 'Daenerys Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_53', 'Doran Martell', 'houseName', None, 'Martell'),
#  ('ch_58', 'Drogon', 'houseName', None, 'Targaryen'),
#  ('ch_60', 'Eddard Stark', 'houseName', None, 'Stark'),
#  ('ch_62', 'Edmure Tully', 'houseName', None, 'Tully'),
#  ('ch_63', 'Ellaria Sand', 'houseName', None, 'Martell'),
#  ('ch_64', 'Elia Martell', 'houseName', None, 'Martell'),
#  ('ch_66', 'Euron Greyjoy', 'houseName', None, 'Greyjoy'),
#  ('ch_71', 'Gendry', 'houseName', None, 'Baratheon'),
#  ('ch_73', 'Ghost', 'houseName', None, 'Stark'),
#  ('ch_91', 'Grey Wind', 'houseName', None, 'Stark'),
#  ('ch_104', 'Hoster Tully', 'houseName', None, 'Tully'),
#  ('ch_114', 'Jaime Lannister', 'houseName', None, 'Lannister'),
#  ('ch_119', 'Jeor Mormont', 'houseName', None, 'Mormont'),
#  ('ch_121', 'Joffrey Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_124', 'Jon Snow', 'houseName', None, 'Stark'),
#  ('ch_124', 'Jon Snow', 'houseName', None, 'Targaryen'),
#  ('ch_126', 'Jorah Mormont', 'houseName', None, 'Mormont'),
#  ('ch_133', 'Kevan Lannister', 'houseName', None, 'Lannister'),
#  ('ch_145', 'Kitty Frey', 'houseName', None, 'Frey'),
#  ('ch_151', 'Lady', 'houseName', None, 'Stark'),
#  ('ch_153', 'Lancel Lannister', 'houseName', None, 'Lannister'),
#  ('ch_175', 'Loras Tyrell', 'houseName', None, 'Tyrell'),
#  ('ch_180', 'Lothar Frey', 'houseName', None, 'Frey'),
#  ('ch_183', 'Lyanna Mormont', 'houseName', None, 'Mormont'),
#  ('ch_184', 'Lyanna Stark', 'houseName', None, 'Stark'),
#  ('ch_185', 'Lysa Arryn', 'houseName', None, 'Arryn'),
#  ('ch_185', 'Lysa Arryn', 'houseName', None, 'Tully'),
#  ('ch_186', 'Mace Tyrell', 'houseName', None, 'Tyrell'),
#  ('ch_187', 'Maester Aemon', 'houseName', None, 'Targaryen'),
#  ('ch_200', 'Margaery Tyrell', 'houseName', None, 'Tyrell'),
#  ('ch_203', 'Martyn Lannister', 'houseName', None, 'Lannister'),
#  ('ch_230', 'Myrcella Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_231', 'Ned Umber', 'houseName', None, 'Umber'),
#  ('ch_243', 'Nymeria', 'houseName', None, 'Stark'),
#  ('ch_244', 'Nymeria Sand', 'houseName', None, 'Martell'),
#  ('ch_245', 'Obara Sand', 'houseName', None, 'Martell'),
#  ('ch_246', 'Oberyn Martell', 'houseName', None, 'Martell'),
#  ('ch_249', 'Olenna Tyrell', 'houseName', None, 'Tyrell'),
#  ('ch_270', 'Ramsay Snow', 'houseName', None, 'Bolton'),
#  ('ch_278', 'Renly Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_279', 'Rhaegal', 'houseName', None, 'Targaryen'),
#  ('ch_280', 'Rhaegar Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_282', 'Rhaella Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_283', 'Rhaenys Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_285', 'Rickard Stark', 'houseName', None, 'Stark'),
#  ('ch_286', 'Rickon Stark', 'houseName', None, 'Stark'),
#  ('ch_287', 'Robb Stark', 'houseName', None, 'Stark'),
#  ('ch_288', 'Robert Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_292', 'Roose Bolton', 'houseName', None, 'Bolton'),
#  ('ch_295', 'Roslin Frey', 'houseName', None, 'Frey'),
#  ('ch_301', 'Sansa Stark', 'houseName', None, 'Stark'),
#  ('ch_302', 'Selyse Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_312', 'Shaggydog', 'houseName', None, 'Stark'),
#  ('ch_313', 'Shireen Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_317', 'Stannis Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_324', 'Stevron Frey', 'houseName', None, 'Frey'),
#  ('ch_327', 'Summer', 'houseName', None, 'Stark'),
#  ('ch_330', 'Talla Tarly', 'houseName', None, 'Tarly'),
#  ('ch_337', 'Theon Greyjoy', 'houseName', None, 'Greyjoy'),
#  ('ch_345', 'Tommen Baratheon', 'houseName', None, 'Baratheon'),
#  ('ch_347', 'Trystane Martell', 'houseName', None, 'Martell'),
#  ('ch_349', 'Tyene Sand', 'houseName', None, 'Martell'),
#  ('ch_350', 'Tyrion Lannister', 'houseName', None, 'Lannister'),
#  ('ch_351', 'Tywin Lannister', 'houseName', None, 'Lannister'),
#  ('ch_355', 'Viserion', 'houseName', None, 'Targaryen'),
#  ('ch_356', 'Viserys Targaryen', 'houseName', None, 'Targaryen'),
#  ('ch_357', 'Walda Bolton', 'houseName', None, 'Bolton'),
#  ('ch_357', 'Walda Bolton', 'houseName', None, 'Frey'),
#  ('ch_358', 'Walder Frey', 'houseName', None, 'Frey'),
#  ('ch_370', 'Willem Lannister', 'houseName', None, 'Lannister'),
#  ('ch_377', 'Yara Greyjoy', 'houseName', None, 'Greyjoy'),
#  ('ch_382', 'Young Benjen Stark', 'houseName', None, 'Stark'),
#  ('ch_383', 'Young Cersei Lannister', 'houseName', None, 'Lannister'),
#  ('ch_384', 'Young Lyanna Stark', 'houseName', None, 'Stark'),
#  ('ch_386', 'Young Ned', 'houseName', None, 'Stark'),
#  ('ch_387', 'Young Ned Stark', 'houseName', None, 'Stark'),
#  ('ch_280', 'Rhaegar Targaryen', 'abducted', 'ch_184', 'Lyanna Stark'),
#  ('ch_4', 'Aerys II Targaryen', 'servedBy', 'ch_15', 'Arthur Dayne'),
#  ('ch_4', 'Aerys II Targaryen', 'servedBy', 'ch_114', 'Jaime Lannister'),
#  ('ch_32', 'Brienne of Tarth', 'servedBy', 'ch_259', 'Podrick Payne'),
#  ('ch_45', 'Daenerys Targaryen', 'servedBy', 'ch_20', 'Barristan Selmy'),
#  ('ch_45', 'Daenerys Targaryen', 'servedBy', 'ch_44', 'Daario Naharis'),
#  ('ch_45', 'Daenerys Targaryen', 'servedBy', 'ch_92', 'Grey Worm'),
#  ('ch_45', 'Daenerys Targaryen', 'servedBy', 'ch_126', 'Jorah Mormont'),
#  ('ch_45', 'Daenerys Targaryen', 'servedBy', 'ch_217', 'Missandei'),
#  ('ch_45', 'Daenerys Targaryen', 'servedBy', 'ch_350', 'Tyrion Lannister'),
#  ('ch_351', 'Tywin Lannister', 'servedBy', 'ch_88', 'Gregor Clegane'),
#  ('ch_12', 'Areo Hotah', 'serves', 'ch_53', 'Doran Martell'),
#  ('ch_15', 'Arthur Dayne', 'serves', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_20', 'Barristan Selmy', 'serves', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_32', 'Brienne of Tarth', 'serves', 'ch_278', 'Renly Baratheon'),
#  ('ch_32', 'Brienne of Tarth', 'serves', 'ch_37', 'Catelyn Stark'),
#  ('ch_32', 'Brienne of Tarth', 'serves', 'ch_301', 'Sansa Stark'),
#  ('ch_32', 'Brienne of Tarth', 'serves', 'ch_30', 'Bran Stark'),
#  ('ch_44', 'Daario Naharis', 'serves', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_48', 'Davos Seaworth', 'serves', 'ch_317', 'Stannis Baratheon'),
#  ('ch_48', 'Davos Seaworth', 'serves', 'ch_124', 'Jon Snow'),
#  ('ch_88', 'Gregor Clegane', 'serves', 'ch_351', 'Tywin Lannister'),
#  ('ch_88', 'Gregor Clegane', 'serves', 'ch_39', 'Cersei Lannister'),
#  ('ch_92', 'Grey Worm', 'serves', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_126', 'Jorah Mormont', 'serves', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_127', 'Jory Cassel', 'serves', 'ch_60', 'Eddard Stark'),
#  ('ch_217', 'Missandei', 'serves', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_259', 'Podrick Payne', 'serves', 'ch_350', 'Tyrion Lannister'),
#  ('ch_259', 'Podrick Payne', 'serves', 'ch_32', 'Brienne of Tarth'),
#  ('ch_259', 'Podrick Payne', 'serves', 'ch_30', 'Bran Stark'),
#  ('ch_268', 'Qyburn', 'serves', 'ch_39', 'Cersei Lannister'),
#  ('ch_291', 'Rodrik Cassel', 'serves', 'ch_60', 'Eddard Stark'),
#  ('ch_350', 'Tyrion Lannister', 'serves', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_2', 'Aegon Targaryen', 'siblings', 'ch_283', 'Rhaenys Targaryen'),
#  ('ch_2', 'Aegon Targaryen', 'siblings', 'ch_124', 'Jon Snow'),
#  ('ch_3', 'Aeron Greyjoy', 'siblings', 'ch_18', 'Balon Greyjoy'),
#  ('ch_3', 'Aeron Greyjoy', 'siblings', 'ch_66', 'Euron Greyjoy'),
#  ('ch_4', 'Aerys II Targaryen', 'siblings', 'ch_282', 'Rhaella Targaryen'),
#  ('ch_16', 'Arya Stark', 'siblings', 'ch_287', 'Robb Stark'),
#  ('ch_16', 'Arya Stark', 'siblings', 'ch_301', 'Sansa Stark'),
#  ('ch_16', 'Arya Stark', 'siblings', 'ch_30', 'Bran Stark'),
#  ('ch_16', 'Arya Stark', 'siblings', 'ch_286', 'Rickon Stark'),
#  ('ch_18', 'Balon Greyjoy', 'siblings', 'ch_66', 'Euron Greyjoy'),
#  ('ch_18', 'Balon Greyjoy', 'siblings', 'ch_3', 'Aeron Greyjoy'),
#  ('ch_21', 'Benjen Stark', 'siblings', 'ch_29', 'Brandon Stark'),
#  ('ch_21', 'Benjen Stark', 'siblings', 'ch_184', 'Lyanna Stark'),
#  ('ch_21', 'Benjen Stark', 'siblings', 'ch_60', 'Eddard Stark'),
#  ('ch_29', 'Brandon Stark', 'siblings', 'ch_184', 'Lyanna Stark'),
#  ('ch_29', 'Brandon Stark', 'siblings', 'ch_21', 'Benjen Stark'),
#  ('ch_29', 'Brandon Stark', 'siblings', 'ch_60', 'Eddard Stark'),
#  ('ch_30', 'Bran Stark', 'siblings', 'ch_287', 'Robb Stark'),
#  ('ch_30', 'Bran Stark', 'siblings', 'ch_301', 'Sansa Stark'),
#  ('ch_30', 'Bran Stark', 'siblings', 'ch_16', 'Arya Stark'),
#  ('ch_30', 'Bran Stark', 'siblings', 'ch_286', 'Rickon Stark'),
#  ('ch_35', 'Brynden Tully', 'siblings', 'ch_104', 'Hoster Tully'),
#  ('ch_37', 'Catelyn Stark', 'siblings', 'ch_185', 'Lysa Arryn'),
#  ('ch_37', 'Catelyn Stark', 'siblings', 'ch_62', 'Edmure Tully'),
#  ('ch_39', 'Cersei Lannister', 'siblings', 'ch_114', 'Jaime Lannister'),
#  ('ch_39', 'Cersei Lannister', 'siblings', 'ch_350', 'Tyrion Lannister'),
#  ('ch_45', 'Daenerys Targaryen', 'siblings', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_45', 'Daenerys Targaryen', 'siblings', 'ch_356', 'Viserys Targaryen'),
#  ('ch_49', 'Dickon Tarly', 'siblings', 'ch_299', 'Samwell Tarly'),
#  ('ch_49', 'Dickon Tarly', 'siblings', 'ch_330', 'Talla Tarly'),
#  ('ch_53', 'Doran Martell', 'siblings', 'ch_64', 'Elia Martell'),
#  ('ch_53', 'Doran Martell', 'siblings', 'ch_246', 'Oberyn Martell'),
#  ('ch_58', 'Drogon', 'siblings', 'ch_279', 'Rhaegal'),
#  ('ch_58', 'Drogon', 'siblings', 'ch_355', 'Viserion'),
#  ('ch_60', 'Eddard Stark', 'siblings', 'ch_29', 'Brandon Stark'),
#  ('ch_60', 'Eddard Stark', 'siblings', 'ch_21', 'Benjen Stark'),
#  ('ch_60', 'Eddard Stark', 'siblings', 'ch_184', 'Lyanna Stark'),
#  ('ch_62', 'Edmure Tully', 'siblings', 'ch_37', 'Catelyn Stark'),
#  ('ch_62', 'Edmure Tully', 'siblings', 'ch_185', 'Lysa Arryn'),
#  ('ch_64', 'Elia Martell', 'siblings', 'ch_53', 'Doran Martell'),
#  ('ch_64', 'Elia Martell', 'siblings', 'ch_246', 'Oberyn Martell'),
#  ('ch_66', 'Euron Greyjoy', 'siblings', 'ch_18', 'Balon Greyjoy'),
#  ('ch_66', 'Euron Greyjoy', 'siblings', 'ch_3', 'Aeron Greyjoy'),
#  ('ch_73', 'Ghost', 'siblings', 'ch_91', 'Grey Wind'),
#  ('ch_73', 'Ghost', 'siblings', 'ch_151', 'Lady'),
#  ('ch_73', 'Ghost', 'siblings', 'ch_243', 'Nymeria'),
#  ('ch_73', 'Ghost', 'siblings', 'ch_327', 'Summer'),
#  ('ch_73', 'Ghost', 'siblings', 'ch_312', 'Shaggydog'),
#  ('ch_91', 'Grey Wind', 'siblings', 'ch_151', 'Lady'),
#  ('ch_91', 'Grey Wind', 'siblings', 'ch_243', 'Nymeria'),
#  ('ch_91', 'Grey Wind', 'siblings', 'ch_327', 'Summer'),
#  ('ch_91', 'Grey Wind', 'siblings', 'ch_312', 'Shaggydog'),
#  ('ch_91', 'Grey Wind', 'siblings', 'ch_73', 'Ghost'),
#  ('ch_114', 'Jaime Lannister', 'siblings', 'ch_39', 'Cersei Lannister'),
#  ('ch_114', 'Jaime Lannister', 'siblings', 'ch_350', 'Tyrion Lannister'),
#  ('ch_121', 'Joffrey Baratheon', 'siblings', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_121', 'Joffrey Baratheon', 'siblings', 'ch_345', 'Tommen Baratheon'),
#  ('ch_122', 'Jojen Reed', 'siblings', 'ch_206', 'Meera Reed'),
#  ('ch_133', 'Kevan Lannister', 'siblings', 'ch_351', 'Tywin Lannister'),
#  ('ch_151', 'Lady', 'siblings', 'ch_91', 'Grey Wind'),
#  ('ch_151', 'Lady', 'siblings', 'ch_243', 'Nymeria'),
#  ('ch_151', 'Lady', 'siblings', 'ch_327', 'Summer'),
#  ('ch_151', 'Lady', 'siblings', 'ch_312', 'Shaggydog'),
#  ('ch_151', 'Lady', 'siblings', 'ch_73', 'Ghost'),
#  ('ch_153', 'Lancel Lannister', 'siblings', 'ch_203', 'Martyn Lannister'),
#  ('ch_153', 'Lancel Lannister', 'siblings', 'ch_370', 'Willem Lannister'),
#  ('ch_175', 'Loras Tyrell', 'siblings', 'ch_200', 'Margaery Tyrell'),
#  ('ch_184', 'Lyanna Stark', 'siblings', 'ch_29', 'Brandon Stark'),
#  ('ch_184', 'Lyanna Stark', 'siblings', 'ch_21', 'Benjen Stark'),
#  ('ch_184', 'Lyanna Stark', 'siblings', 'ch_60', 'Eddard Stark'),
#  ('ch_185', 'Lysa Arryn', 'siblings', None, 'Catelyn Tully'),
#  ('ch_185', 'Lysa Arryn', 'siblings', 'ch_62', 'Edmure Tully'),
#  ('ch_200', 'Margaery Tyrell', 'siblings', 'ch_175', 'Loras Tyrell'),
#  ('ch_203', 'Martyn Lannister', 'siblings', 'ch_153', 'Lancel Lannister'),
#  ('ch_203', 'Martyn Lannister', 'siblings', 'ch_370', 'Willem Lannister'),
#  ('ch_230', 'Myrcella Baratheon', 'siblings', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_230', 'Myrcella Baratheon', 'siblings', 'ch_345', 'Tommen Baratheon'),
#  ('ch_243', 'Nymeria', 'siblings', 'ch_91', 'Grey Wind'),
#  ('ch_243', 'Nymeria', 'siblings', 'ch_151', 'Lady'),
#  ('ch_243', 'Nymeria', 'siblings', 'ch_327', 'Summer'),
#  ('ch_243', 'Nymeria', 'siblings', 'ch_312', 'Shaggydog'),
#  ('ch_243', 'Nymeria', 'siblings', 'ch_73', 'Ghost'),
#  ('ch_246', 'Oberyn Martell', 'siblings', 'ch_53', 'Doran Martell'),
#  ('ch_246', 'Oberyn Martell', 'siblings', 'ch_64', 'Elia Martell'),
#  ('ch_278', 'Renly Baratheon', 'siblings', 'ch_288', 'Robert Baratheon'),
#  ('ch_278', 'Renly Baratheon', 'siblings', 'ch_317', 'Stannis Baratheon'),
#  ('ch_279', 'Rhaegal', 'siblings', 'ch_58', 'Drogon'),
#  ('ch_279', 'Rhaegal', 'siblings', 'ch_355', 'Viserion'),
#  ('ch_280', 'Rhaegar Targaryen', 'siblings', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_280', 'Rhaegar Targaryen', 'siblings', 'ch_356', 'Viserys Targaryen'),
#  ('ch_282', 'Rhaella Targaryen', 'siblings', 'ch_4', 'Aerys II Targaryen'),
#  ('ch_286', 'Rickon Stark', 'siblings', 'ch_287', 'Robb Stark'),
#  ('ch_286', 'Rickon Stark', 'siblings', 'ch_301', 'Sansa Stark'),
#  ('ch_286', 'Rickon Stark', 'siblings', 'ch_16', 'Arya Stark'),
#  ('ch_286', 'Rickon Stark', 'siblings', 'ch_30', 'Bran Stark'),
#  ('ch_287', 'Robb Stark', 'siblings', 'ch_301', 'Sansa Stark'),
#  ('ch_287', 'Robb Stark', 'siblings', 'ch_16', 'Arya Stark'),
#  ('ch_287', 'Robb Stark', 'siblings', 'ch_30', 'Bran Stark'),
#  ('ch_287', 'Robb Stark', 'siblings', 'ch_286', 'Rickon Stark'),
#  ('ch_288', 'Robert Baratheon', 'siblings', 'ch_317', 'Stannis Baratheon'),
#  ('ch_288', 'Robert Baratheon', 'siblings', 'ch_278', 'Renly Baratheon'),
#  ('ch_299', 'Samwell Tarly', 'siblings', 'ch_49', 'Dickon Tarly'),
#  ('ch_299', 'Samwell Tarly', 'siblings', 'ch_330', 'Talla Tarly'),
#  ('ch_300', 'Sandor Clegane', 'siblings', 'ch_88', 'Gregor Clegane'),
#  ('ch_301', 'Sansa Stark', 'siblings', 'ch_287', 'Robb Stark'),
#  ('ch_301', 'Sansa Stark', 'siblings', 'ch_16', 'Arya Stark'),
#  ('ch_301', 'Sansa Stark', 'siblings', 'ch_30', 'Bran Stark'),
#  ('ch_301', 'Sansa Stark', 'siblings', 'ch_286', 'Rickon Stark'),
#  ('ch_312', 'Shaggydog', 'siblings', 'ch_91', 'Grey Wind'),
#  ('ch_312', 'Shaggydog', 'siblings', 'ch_151', 'Lady'),
#  ('ch_312', 'Shaggydog', 'siblings', 'ch_243', 'Nymeria'),
#  ('ch_312', 'Shaggydog', 'siblings', 'ch_327', 'Summer'),
#  ('ch_312', 'Shaggydog', 'siblings', 'ch_73', 'Ghost'),
#  ('ch_317', 'Stannis Baratheon', 'siblings', 'ch_288', 'Robert Baratheon'),
#  ('ch_317', 'Stannis Baratheon', 'siblings', 'ch_278', 'Renly Baratheon'),
#  ('ch_327', 'Summer', 'siblings', 'ch_91', 'Grey Wind'),
#  ('ch_327', 'Summer', 'siblings', 'ch_151', 'Lady'),
#  ('ch_327', 'Summer', 'siblings', 'ch_243', 'Nymeria'),
#  ('ch_327', 'Summer', 'siblings', 'ch_312', 'Shaggydog'),
#  ('ch_327', 'Summer', 'siblings', 'ch_73', 'Ghost'),
#  ('ch_330', 'Talla Tarly', 'siblings', 'ch_49', 'Dickon Tarly'),
#  ('ch_330', 'Talla Tarly', 'siblings', 'ch_299', 'Samwell Tarly'),
#  ('ch_337', 'Theon Greyjoy', 'siblings', 'ch_377', 'Yara Greyjoy'),
#  ('ch_345', 'Tommen Baratheon', 'siblings', 'ch_121', 'Joffrey Baratheon'),
#  ('ch_345', 'Tommen Baratheon', 'siblings', 'ch_230', 'Myrcella Baratheon'),
#  ('ch_350', 'Tyrion Lannister', 'siblings', 'ch_39', 'Cersei Lannister'),
#  ('ch_350', 'Tyrion Lannister', 'siblings', 'ch_114', 'Jaime Lannister'),
#  ('ch_355', 'Viserion', 'siblings', 'ch_58', 'Drogon'),
#  ('ch_355', 'Viserion', 'siblings', 'ch_279', 'Rhaegal'),
#  ('ch_356', 'Viserys Targaryen', 'siblings', 'ch_45', 'Daenerys Targaryen'),
#  ('ch_356', 'Viserys Targaryen', 'siblings', 'ch_280', 'Rhaegar Targaryen'),
#  ('ch_370', 'Willem Lannister', 'siblings', 'ch_153', 'Lancel Lannister'),
#  ('ch_370', 'Willem Lannister', 'siblings', 'ch_203', 'Martyn Lannister'),
#  ('ch_377', 'Yara Greyjoy', 'siblings', 'ch_337', 'Theon Greyjoy')]

# %% [markdown]
# The result of my query is
#
# | <img src="relationships_2_load.jpg"> |
# | :---: |
# | __Data Engineering is Fun!__

# %% [markdown]
# This is where things get really fun. We will load the relationships into Neo4j.
#
# Write a Cypher query that creates the relationships with a label of the form "xxx" where "xxx" is the relationship_type.
#
# To test and debug, you can
# 1. Set ```source_character_id``` and ```target_character_id``` in the cell below.
# 2. Run the cell to get your query.
# 3. Copy and paste into the Neo4j console.
# 4. Run the query and examine the result.
#
# My result looks like.
#
# | <img src="neo4j_screen_1.jpg" > |
# | :---: |
# | __Neo4j Test Result Screen__ |

# %%
# TODO Student -- Set you query below.
#
source_character_id= "ch_4"
target_character_id= "ch_45"
relationship_type="parentOf"
# match p=(source :Character:IMDB)-[:parentOf]->(target :Character:IMDB) return p
create_relationship_q = f"""
MERGE (source :Character:IMDB {{character_id: "{source_character_id}"}})
MERGE (target :Character:IMDB {{character_id: "{target_character_id}"}})
CREATE (source)-[:{relationship_type}]->(target)
"""

# Print the query to copy.
#
print(create_relationship_q)
# Out:
# MERGE (source :Character:IMDB {character_id: "ch_4"})
# MERGE (target :Character:IMDB {character_id: "ch_45"})
# CREATE (source)-[:parentOf]->(target)

# %% [markdown]
# Now the fun really begins. Super fun. The following query gets the information that will drive loading.

# %%
# %%sql
#
# info_to_load << select
#     (select min(character_id) from neo4j_characters where characterName=temp_relationships.sourceCharacter)
#         as source_character_id,
#     sourceCharacter,
#     relationship_type,
#     (select min(character_id) from neo4j_characters where characterName=temp_relationships.targetCharacter)
#         as target_character_id,
#     targetCharacter
# from
#     temp_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 940 rows affected.
# Returning data to local variable info_to_load

# %%
info_to_load = [r for r in info_to_load.dicts()]

# %%
info_to_load
# Out:
# [{'source_character_id': 'ch_58',
#   'sourceCharacter': 'Drogon',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_60',
#   'sourceCharacter': 'Eddard Stark',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_73',
#   'sourceCharacter': 'Ghost',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_287',
#   'targetCharacter': 'Robb Stark'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_4',
#   'targetCharacter': 'Aerys II Targaryen'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_288',
#   'targetCharacter': 'Robert Baratheon'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_123',
#   'sourceCharacter': 'Jon Arryn',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_60',
#   'targetCharacter': 'Eddard Stark'},
#  {'source_character_id': 'ch_123',
#   'sourceCharacter': 'Jon Arryn',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_288',
#   'targetCharacter': 'Robert Baratheon'},
#  {'source_character_id': 'ch_151',
#   'sourceCharacter': 'Lady',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_301',
#   'targetCharacter': 'Sansa Stark'},
#  {'source_character_id': 'ch_243',
#   'sourceCharacter': 'Nymeria',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_16',
#   'targetCharacter': 'Arya Stark'},
#  {'source_character_id': 'ch_279',
#   'sourceCharacter': 'Rhaegal',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_312',
#   'sourceCharacter': 'Shaggydog',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_286',
#   'targetCharacter': 'Rickon Stark'},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_30',
#   'targetCharacter': 'Bran Stark'},
#  {'source_character_id': 'ch_355',
#   'sourceCharacter': 'Viserion',
#   'relationship_type': 'guardianOf',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_4',
#   'sourceCharacter': 'Aerys II Targaryen',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_282',
#   'targetCharacter': 'Rhaella Targaryen'},
#  {'source_character_id': 'ch_33',
#   'sourceCharacter': 'Bronn',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_173',
#   'targetCharacter': 'Lollys Stokeworth'},
#  {'source_character_id': 'ch_37',
#   'sourceCharacter': 'Catelyn Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_60',
#   'targetCharacter': 'Eddard Stark'},
#  {'source_character_id': 'ch_37',
#   'sourceCharacter': 'Catelyn Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_29',
#   'targetCharacter': 'Brandon Stark'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_288',
#   'targetCharacter': 'Robert Baratheon'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_134',
#   'targetCharacter': 'Khal Drogo'},
#  {'source_character_id': 'ch_60',
#   'sourceCharacter': 'Eddard Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_37',
#   'targetCharacter': 'Catelyn Stark'},
#  {'source_character_id': 'ch_62',
#   'sourceCharacter': 'Edmure Tully',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_295',
#   'targetCharacter': 'Roslin Frey'},
#  {'source_character_id': 'ch_63',
#   'sourceCharacter': 'Ellaria Sand',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_246',
#   'targetCharacter': 'Oberyn Martell'},
#  {'source_character_id': 'ch_64',
#   'sourceCharacter': 'Elia Martell',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_280',
#   'targetCharacter': 'Rhaegar Targaryen'},
#  {'source_character_id': 'ch_74',
#   'sourceCharacter': 'Gilly',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_299',
#   'targetCharacter': 'Samwell Tarly'},
#  {'source_character_id': 'ch_121',
#   'sourceCharacter': 'Joffrey Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_301',
#   'targetCharacter': 'Sansa Stark'},
#  {'source_character_id': 'ch_121',
#   'sourceCharacter': 'Joffrey Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_200',
#   'targetCharacter': 'Margaery Tyrell'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_379',
#   'targetCharacter': 'Ygritte'},
#  {'source_character_id': 'ch_128',
#   'sourceCharacter': 'Joyeuse Erenford',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_358',
#   'targetCharacter': 'Walder Frey'},
#  {'source_character_id': 'ch_134',
#   'sourceCharacter': 'Khal Drogo',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_145',
#   'sourceCharacter': 'Kitty Frey',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_358',
#   'targetCharacter': 'Walder Frey'},
#  {'source_character_id': 'ch_173',
#   'sourceCharacter': 'Lollys Stokeworth',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_33',
#   'targetCharacter': 'Bronn'},
#  {'source_character_id': 'ch_184',
#   'sourceCharacter': 'Lyanna Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_288',
#   'targetCharacter': 'Robert Baratheon'},
#  {'source_character_id': 'ch_184',
#   'sourceCharacter': 'Lyanna Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_280',
#   'targetCharacter': 'Rhaegar Targaryen'},
#  {'source_character_id': 'ch_185',
#   'sourceCharacter': 'Lysa Arryn',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_258',
#   'targetCharacter': 'Petyr Baelish'},
#  {'source_character_id': 'ch_200',
#   'sourceCharacter': 'Margaery Tyrell',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_278',
#   'targetCharacter': 'Renly Baratheon'},
#  {'source_character_id': 'ch_200',
#   'sourceCharacter': 'Margaery Tyrell',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_200',
#   'sourceCharacter': 'Margaery Tyrell',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_345',
#   'targetCharacter': 'Tommen Baratheon'},
#  {'source_character_id': 'ch_208',
#   'sourceCharacter': 'Melessa Tarly',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_271',
#   'targetCharacter': 'Randyll Tarly'},
#  {'source_character_id': 'ch_230',
#   'sourceCharacter': 'Myrcella Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_347',
#   'targetCharacter': 'Trystane Martell'},
#  {'source_character_id': 'ch_246',
#   'sourceCharacter': 'Oberyn Martell',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_63',
#   'targetCharacter': 'Ellaria Sand'},
#  {'source_character_id': 'ch_258',
#   'sourceCharacter': 'Petyr Baelish',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_185',
#   'targetCharacter': 'Lysa Arryn'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_301',
#   'targetCharacter': 'Sansa Stark'},
#  {'source_character_id': 'ch_271',
#   'sourceCharacter': 'Randyll Tarly',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_208',
#   'targetCharacter': 'Melessa Tarly'},
#  {'source_character_id': 'ch_278',
#   'sourceCharacter': 'Renly Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_200',
#   'targetCharacter': 'Margaery Tyrell'},
#  {'source_character_id': 'ch_280',
#   'sourceCharacter': 'Rhaegar Targaryen',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_64',
#   'targetCharacter': 'Elia Martell'},
#  {'source_character_id': 'ch_280',
#   'sourceCharacter': 'Rhaegar Targaryen',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_184',
#   'targetCharacter': 'Lyanna Stark'},
#  {'source_character_id': 'ch_282',
#   'sourceCharacter': 'Rhaella Targaryen',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_4',
#   'targetCharacter': 'Aerys II Targaryen'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_295',
#   'targetCharacter': 'Roslin Frey'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_329',
#   'targetCharacter': 'Talisa Maegyr'},
#  {'source_character_id': 'ch_288',
#   'sourceCharacter': 'Robert Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_184',
#   'targetCharacter': 'Lyanna Stark'},
#  {'source_character_id': 'ch_288',
#   'sourceCharacter': 'Robert Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_39',
#   'targetCharacter': 'Cersei Lannister'},
#  {'source_character_id': 'ch_292',
#   'sourceCharacter': 'Roose Bolton',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_357',
#   'targetCharacter': 'Walda Bolton'},
#  {'source_character_id': 'ch_295',
#   'sourceCharacter': 'Roslin Frey',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_287',
#   'targetCharacter': 'Robb Stark'},
#  {'source_character_id': 'ch_295',
#   'sourceCharacter': 'Roslin Frey',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_62',
#   'targetCharacter': 'Edmure Tully'},
#  {'source_character_id': 'ch_299',
#   'sourceCharacter': 'Samwell Tarly',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_74',
#   'targetCharacter': 'Gilly'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_350',
#   'targetCharacter': 'Tyrion Lannister'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_270',
#   'targetCharacter': 'Ramsay Snow'},
#  {'source_character_id': 'ch_302',
#   'sourceCharacter': 'Selyse Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_317',
#   'targetCharacter': 'Stannis Baratheon'},
#  {'source_character_id': 'ch_317',
#   'sourceCharacter': 'Stannis Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_302',
#   'targetCharacter': 'Selyse Baratheon'},
#  {'source_character_id': 'ch_329',
#   'sourceCharacter': 'Talisa Maegyr',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_287',
#   'targetCharacter': 'Robb Stark'},
#  {'source_character_id': 'ch_345',
#   'sourceCharacter': 'Tommen Baratheon',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_200',
#   'targetCharacter': 'Margaery Tyrell'},
#  {'source_character_id': 'ch_347',
#   'sourceCharacter': 'Trystane Martell',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_230',
#   'targetCharacter': 'Myrcella Baratheon'},
#  {'source_character_id': 'ch_350',
#   'sourceCharacter': 'Tyrion Lannister',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_301',
#   'targetCharacter': 'Sansa Stark'},
#  {'source_character_id': 'ch_357',
#   'sourceCharacter': 'Walda Bolton',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_292',
#   'targetCharacter': 'Roose Bolton'},
#  {'source_character_id': 'ch_358',
#   'sourceCharacter': 'Walder Frey',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_128',
#   'targetCharacter': 'Joyeuse Erenford'},
#  {'source_character_id': 'ch_358',
#   'sourceCharacter': 'Walder Frey',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_145',
#   'targetCharacter': 'Kitty Frey'},
#  {'source_character_id': 'ch_379',
#   'sourceCharacter': 'Ygritte',
#   'relationship_type': 'marriedEngaged',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_4',
#   'sourceCharacter': 'Aerys II Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_29',
#   'targetCharacter': 'Brandon Stark'},
#  {'source_character_id': 'ch_4',
#   'sourceCharacter': 'Aerys II Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_285',
#   'targetCharacter': 'Rickard Stark'},
#  {'source_character_id': 'ch_6',
#   'sourceCharacter': 'Alliser Thorne',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_9',
#   'sourceCharacter': 'Amory Lorch',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_381',
#   'targetCharacter': 'Yoren'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_275',
#   'targetCharacter': 'Red Keep Stableboy'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Frey Soldier #1'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_260',
#   'targetCharacter': 'Polliver'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_293',
#   'targetCharacter': 'Rorge'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Ghita'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_212',
#   'targetCharacter': 'Meryn Trant'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_335',
#   'targetCharacter': 'The Waif'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_26',
#   'targetCharacter': 'Black Walder Rivers'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_180',
#   'targetCharacter': 'Lothar Frey'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_358',
#   'targetCharacter': 'Walder Frey'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_258',
#   'targetCharacter': 'Petyr Baelish'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_333',
#   'targetCharacter': 'The Night King'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_363',
#   'targetCharacter': 'White Walker'},
#  {'source_character_id': 'ch_16',
#   'sourceCharacter': 'Arya Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_355',
#   'targetCharacter': 'Viserion'},
#  {'source_character_id': 'ch_26',
#   'sourceCharacter': 'Black Walder Rivers',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_37',
#   'targetCharacter': 'Catelyn Stark'},
#  {'source_character_id': 'ch_28',
#   'sourceCharacter': 'Bowen Marsh',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_32',
#   'sourceCharacter': 'Brienne of Tarth',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Soldier Tom'},
#  {'source_character_id': 'ch_32',
#   'sourceCharacter': 'Brienne of Tarth',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_317',
#   'targetCharacter': 'Stannis Baratheon'},
#  {'source_character_id': 'ch_32',
#   'sourceCharacter': 'Brienne of Tarth',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Bolton Officer'},
#  {'source_character_id': 'ch_33',
#   'sourceCharacter': 'Bronn',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_353',
#   'targetCharacter': 'Vardis Egen'},
#  {'source_character_id': 'ch_33',
#   'sourceCharacter': 'Bronn',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_205',
#   'targetCharacter': 'Matthos Seaworth'},
#  {'source_character_id': 'ch_33',
#   'sourceCharacter': 'Bronn',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_159',
#   'targetCharacter': 'Lead Dornish Guard'},
#  {'source_character_id': 'ch_37',
#   'sourceCharacter': 'Catelyn Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_128',
#   'targetCharacter': 'Joyeuse Erenford'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_153',
#   'targetCharacter': 'Lancel Lannister'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_101',
#   'targetCharacter': 'High Sparrow'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_175',
#   'targetCharacter': 'Loras Tyrell'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_186',
#   'targetCharacter': 'Mace Tyrell'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_200',
#   'targetCharacter': 'Margaery Tyrell'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_133',
#   'targetCharacter': 'Kevan Lannister'},
#  {'source_character_id': 'ch_39',
#   'sourceCharacter': 'Cersei Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_349',
#   'targetCharacter': 'Tyene Sand'},
#  {'source_character_id': 'ch_44',
#   'sourceCharacter': 'Daario Naharis',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_211',
#   'targetCharacter': 'Mero'},
#  {'source_character_id': 'ch_44',
#   'sourceCharacter': 'Daario Naharis',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_261',
#   'targetCharacter': 'Prendahl na Ghezn'},
#  {'source_character_id': 'ch_44',
#   'sourceCharacter': 'Daario Naharis',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Oznak zo Pahl'},
#  {'source_character_id': 'ch_44',
#   'sourceCharacter': 'Daario Naharis',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_219',
#   'targetCharacter': 'Mossador'},
#  {'source_character_id': 'ch_44',
#   'sourceCharacter': 'Daario Naharis',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Iggo'},
#  {'source_character_id': 'ch_44',
#   'sourceCharacter': 'Daario Naharis',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_5',
#   'targetCharacter': 'Akho'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_134',
#   'targetCharacter': 'Khal Drogo'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_216',
#   'targetCharacter': 'Mirri Maz Duur'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_54',
#   'targetCharacter': 'Doreah'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_376',
#   'targetCharacter': 'Xaro Xhoan Daxos'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_136',
#   'targetCharacter': 'Khal Rhalko'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Khal Brozho'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Khal Qorro'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Khal Forzho'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_135',
#   'targetCharacter': 'Khal Moro'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_55',
#   'targetCharacter': 'Dothraki Bloodrider #1'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_56',
#   'targetCharacter': 'Dothraki Bloodrider #2'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_271',
#   'targetCharacter': 'Randyll Tarly'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_49',
#   'targetCharacter': 'Dickon Tarly'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Eleanor'},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': "Eleanor's Daughter"},
#  {'source_character_id': 'ch_45',
#   'sourceCharacter': 'Daenerys Targaryen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_178',
#   'targetCharacter': 'Lord Varys'},
#  {'source_character_id': 'ch_54',
#   'sourceCharacter': 'Doreah',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_110',
#   'targetCharacter': 'Irri'},
#  {'source_character_id': 'ch_58',
#   'sourceCharacter': 'Drogon',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_262',
#   'targetCharacter': 'Pyat Pree'},
#  {'source_character_id': 'ch_58',
#   'sourceCharacter': 'Drogon',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_149',
#   'targetCharacter': 'Kraznys mo Nakloz'},
#  {'source_character_id': 'ch_58',
#   'sourceCharacter': 'Drogon',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Zalla'},
#  {'source_character_id': 'ch_60',
#   'sourceCharacter': 'Eddard Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_15',
#   'targetCharacter': 'Arthur Dayne'},
#  {'source_character_id': 'ch_60',
#   'sourceCharacter': 'Eddard Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_369',
#   'targetCharacter': 'Will'},
#  {'source_character_id': 'ch_60',
#   'sourceCharacter': 'Eddard Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_151',
#   'targetCharacter': 'Lady'},
#  {'source_character_id': 'ch_60',
#   'sourceCharacter': 'Eddard Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_72',
#   'targetCharacter': 'Gerold Hightower'},
#  {'source_character_id': 'ch_63',
#   'sourceCharacter': 'Ellaria Sand',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_230',
#   'targetCharacter': 'Myrcella Baratheon'},
#  {'source_character_id': 'ch_63',
#   'sourceCharacter': 'Ellaria Sand',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_53',
#   'targetCharacter': 'Doran Martell'},
#  {'source_character_id': 'ch_66',
#   'sourceCharacter': 'Euron Greyjoy',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_18',
#   'targetCharacter': 'Balon Greyjoy'},
#  {'source_character_id': 'ch_66',
#   'sourceCharacter': 'Euron Greyjoy',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_245',
#   'targetCharacter': 'Obara Sand'},
#  {'source_character_id': 'ch_66',
#   'sourceCharacter': 'Euron Greyjoy',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_244',
#   'targetCharacter': 'Nymeria Sand'},
#  {'source_character_id': 'ch_66',
#   'sourceCharacter': 'Euron Greyjoy',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_279',
#   'targetCharacter': 'Rhaegal'},
#  {'source_character_id': 'ch_71',
#   'sourceCharacter': 'Gendry',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Kevin Eldon'},
#  {'source_character_id': 'ch_71',
#   'sourceCharacter': 'Gendry',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Laurence Spellman'},
#  {'source_character_id': 'ch_73',
#   'sourceCharacter': 'Ghost',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_272',
#   'targetCharacter': 'Rast'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_64',
#   'targetCharacter': 'Elia Martell'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_283',
#   'targetCharacter': 'Rhaenys Targaryen'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_2',
#   'targetCharacter': 'Aegon Targaryen'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_107',
#   'targetCharacter': 'Hugh of the Vale'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_246',
#   'targetCharacter': 'Oberyn Martell'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': "King's Landing Boaster"},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Faith Militant'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_217',
#   'targetCharacter': 'Missandei'},
#  {'source_character_id': 'ch_88',
#   'sourceCharacter': 'Gregor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_268',
#   'targetCharacter': 'Qyburn'},
#  {'source_character_id': 'ch_90',
#   'sourceCharacter': 'Grenn',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_191',
#   'targetCharacter': 'Mag the Mighty'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Rennick'},
#  {'source_character_id': 'ch_92',
#   'sourceCharacter': 'Grey Worm',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Belicho Paenymion'},
#  {'source_character_id': 'ch_92',
#   'sourceCharacter': 'Grey Worm',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_274',
#   'targetCharacter': 'Razdal mo Eraz'},
#  {'source_character_id': 'ch_92',
#   'sourceCharacter': 'Grey Worm',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_97',
#   'targetCharacter': 'Harry Strickland'},
#  {'source_character_id': 'ch_103',
#   'sourceCharacter': 'Hodor',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_172',
#   'targetCharacter': 'Locke'},
#  {'source_character_id': 'ch_106',
#   'sourceCharacter': 'Howland Reed',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_15',
#   'targetCharacter': 'Arthur Dayne'},
#  {'source_character_id': 'ch_109',
#   'sourceCharacter': 'Ilyn Payne',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_60',
#   'targetCharacter': 'Eddard Stark'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_4',
#   'targetCharacter': 'Aerys II Targaryen'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_127',
#   'targetCharacter': 'Jory Cassel'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_7',
#   'targetCharacter': 'Alton Lannister'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Torrhen Karstark'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_249',
#   'targetCharacter': 'Olenna Tyrell'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_66',
#   'targetCharacter': 'Euron Greyjoy'},
#  {'source_character_id': 'ch_115',
#   'sourceCharacter': 'Janos Slynt',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Barra'},
#  {'source_character_id': 'ch_116',
#   'sourceCharacter': "Jaqen H'ghar",
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_334',
#   'targetCharacter': 'The Tickler'},
#  {'source_character_id': 'ch_116',
#   'sourceCharacter': "Jaqen H'ghar",
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_9',
#   'targetCharacter': 'Amory Lorch'},
#  {'source_character_id': 'ch_116',
#   'sourceCharacter': "Jaqen H'ghar",
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Despondent Man'},
#  {'source_character_id': 'ch_121',
#   'sourceCharacter': 'Joffrey Baratheon',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_294',
#   'targetCharacter': 'Ros'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_256',
#   'targetCharacter': 'Othor'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_265',
#   'targetCharacter': 'Qhorin Halfhand'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_252',
#   'targetCharacter': 'Orell'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_129',
#   'targetCharacter': 'Karl Tanner'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_326',
#   'targetCharacter': 'Styr'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_196',
#   'targetCharacter': 'Mance Rayder'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_115',
#   'targetCharacter': 'Janos Slynt'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_363',
#   'targetCharacter': 'White Walker'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_6',
#   'targetCharacter': 'Alliser Thorne'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_255',
#   'targetCharacter': 'Othell Yarwyck'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_28',
#   'targetCharacter': 'Bowen Marsh'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_250',
#   'targetCharacter': 'Olly'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_184',
#   'targetCharacter': 'Lyanna Stark'},
#  {'source_character_id': 'ch_124',
#   'sourceCharacter': 'Jon Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_126',
#   'sourceCharacter': 'Jorah Mormont',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_266',
#   'targetCharacter': 'Qotho'},
#  {'source_character_id': 'ch_126',
#   'sourceCharacter': 'Jorah Mormont',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Norvoshi Pit Fighter'},
#  {'source_character_id': 'ch_126',
#   'sourceCharacter': 'Jorah Mormont',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Meereenese Champion'},
#  {'source_character_id': 'ch_129',
#   'sourceCharacter': 'Karl Tanner',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_43',
#   'targetCharacter': 'Craster'},
#  {'source_character_id': 'ch_134',
#   'sourceCharacter': 'Khal Drogo',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_356',
#   'targetCharacter': 'Viserys Targaryen'},
#  {'source_character_id': 'ch_134',
#   'sourceCharacter': 'Khal Drogo',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_193',
#   'targetCharacter': 'Mago'},
#  {'source_character_id': 'ch_161',
#   'sourceCharacter': 'Lem Lemoncloak',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_34',
#   'targetCharacter': 'Brother Ray'},
#  {'source_character_id': 'ch_180',
#   'sourceCharacter': 'Lothar Frey',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_329',
#   'targetCharacter': 'Talisa Maegyr'},
#  {'source_character_id': 'ch_183',
#   'sourceCharacter': 'Lyanna Mormont',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_374',
#   'targetCharacter': 'Wun Wun'},
#  {'source_character_id': 'ch_185',
#   'sourceCharacter': 'Lysa Arryn',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_123',
#   'targetCharacter': 'Jon Arryn'},
#  {'source_character_id': 'ch_188',
#   'sourceCharacter': 'Maester Cressen',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_188',
#   'targetCharacter': 'Maester Cressen'},
#  {'source_character_id': 'ch_191',
#   'sourceCharacter': 'Mag the Mighty',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_90',
#   'targetCharacter': 'Grenn'},
#  {'source_character_id': 'ch_191',
#   'sourceCharacter': 'Mag the Mighty',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Donnel Hill'},
#  {'source_character_id': 'ch_191',
#   'sourceCharacter': 'Mag the Mighty',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Cooper'},
#  {'source_character_id': 'ch_206',
#   'sourceCharacter': 'Meera Reed',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_122',
#   'targetCharacter': 'Jojen Reed'},
#  {'source_character_id': 'ch_206',
#   'sourceCharacter': 'Meera Reed',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_363',
#   'targetCharacter': 'White Walker'},
#  {'source_character_id': 'ch_209',
#   'sourceCharacter': 'Melisandre',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_278',
#   'targetCharacter': 'Renly Baratheon'},
#  {'source_character_id': 'ch_209',
#   'sourceCharacter': 'Melisandre',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Axell Florent'},
#  {'source_character_id': 'ch_209',
#   'sourceCharacter': 'Melisandre',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_196',
#   'targetCharacter': 'Mance Rayder'},
#  {'source_character_id': 'ch_209',
#   'sourceCharacter': 'Melisandre',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_313',
#   'targetCharacter': 'Shireen Baratheon'},
#  {'source_character_id': 'ch_212',
#   'sourceCharacter': 'Meryn Trant',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_328',
#   'targetCharacter': 'Syrio Forel'},
#  {'source_character_id': 'ch_216',
#   'sourceCharacter': 'Mirri Maz Duur',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_281',
#   'targetCharacter': 'Rhaego'},
#  {'source_character_id': 'ch_219',
#   'sourceCharacter': 'Mossador',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Son of the Harpy'},
#  {'source_character_id': 'ch_245',
#   'sourceCharacter': 'Obara Sand',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_210',
#   'targetCharacter': 'Merchant Captain'},
#  {'source_character_id': 'ch_245',
#   'sourceCharacter': 'Obara Sand',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_347',
#   'targetCharacter': 'Trystane Martell'},
#  {'source_character_id': 'ch_249',
#   'sourceCharacter': 'Olenna Tyrell',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_250',
#   'sourceCharacter': 'Olly',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_379',
#   'targetCharacter': 'Ygritte'},
#  {'source_character_id': 'ch_250',
#   'sourceCharacter': 'Olly',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_254',
#   'sourceCharacter': 'Osha',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_57',
#   'targetCharacter': 'Drennan'},
#  {'source_character_id': 'ch_254',
#   'sourceCharacter': 'Osha',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_189',
#   'targetCharacter': 'Maester Luwin'},
#  {'source_character_id': 'ch_255',
#   'sourceCharacter': 'Othell Yarwyck',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_124',
#   'targetCharacter': 'Jon Snow'},
#  {'source_character_id': 'ch_258',
#   'sourceCharacter': 'Petyr Baelish',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_258',
#   'sourceCharacter': 'Petyr Baelish',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_52',
#   'targetCharacter': 'Dontos Hollard'},
#  {'source_character_id': 'ch_258',
#   'sourceCharacter': 'Petyr Baelish',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_185',
#   'targetCharacter': 'Lysa Arryn'},
#  {'source_character_id': 'ch_259',
#   'sourceCharacter': 'Podrick Payne',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_197',
#   'targetCharacter': 'Mandon Moore'},
#  {'source_character_id': 'ch_259',
#   'sourceCharacter': 'Podrick Payne',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Bolton Soldier'},
#  {'source_character_id': 'ch_260',
#   'sourceCharacter': 'Polliver',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_174',
#   'targetCharacter': 'Lommy Greenhands'},
#  {'source_character_id': 'ch_262',
#   'sourceCharacter': 'Pyat Pree',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_316',
#   'targetCharacter': 'Spice King'},
#  {'source_character_id': 'ch_262',
#   'sourceCharacter': 'Pyat Pree',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_314',
#   'targetCharacter': 'Silk King'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Master Torturer'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Medger Cerwyn'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Lady Cerwyn'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Unidentified Cerwyn'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Old Woman'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_292',
#   'targetCharacter': 'Roose Bolton'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_254',
#   'targetCharacter': 'Osha'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_286',
#   'targetCharacter': 'Rickon Stark'},
#  {'source_character_id': 'ch_270',
#   'sourceCharacter': 'Ramsay Snow',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_374',
#   'targetCharacter': 'Wun Wun'},
#  {'source_character_id': 'ch_272',
#   'sourceCharacter': 'Rast',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_119',
#   'targetCharacter': 'Jeor Mormont'},
#  {'source_character_id': 'ch_279',
#   'sourceCharacter': 'Rhaegal',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_262',
#   'targetCharacter': 'Pyat Pree'},
#  {'source_character_id': 'ch_279',
#   'sourceCharacter': 'Rhaegal',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_80',
#   'targetCharacter': 'Great Master #1'},
#  {'source_character_id': 'ch_284',
#   'sourceCharacter': 'Rickard Karstark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_203',
#   'targetCharacter': 'Martyn Lannister'},
#  {'source_character_id': 'ch_284',
#   'sourceCharacter': 'Rickard Karstark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_370',
#   'targetCharacter': 'Willem Lannister'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_359',
#   'targetCharacter': 'Wallen'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_284',
#   'targetCharacter': 'Rickard Karstark'},
#  {'source_character_id': 'ch_288',
#   'sourceCharacter': 'Robert Baratheon',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_280',
#   'targetCharacter': 'Rhaegar Targaryen'},
#  {'source_character_id': 'ch_292',
#   'sourceCharacter': 'Roose Bolton',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_287',
#   'targetCharacter': 'Robb Stark'},
#  {'source_character_id': 'ch_299',
#   'sourceCharacter': 'Samwell Tarly',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_363',
#   'targetCharacter': 'White Walker'},
#  {'source_character_id': 'ch_299',
#   'sourceCharacter': 'Samwell Tarly',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_336',
#   'targetCharacter': 'Thenn Warg'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_228',
#   'targetCharacter': 'Mycah'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Kings Landing Rioter #1'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Kings Landing Rioter #2'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Kings Landing Rioter #3'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_22',
#   'targetCharacter': 'Beric Dondarrion'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Frey Soldier #2'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Lowell'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Dying Man'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_24',
#   'targetCharacter': 'Biter'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Steve'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Riddell'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_70',
#   'targetCharacter': 'Gatins'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Morgan'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_161',
#   'targetCharacter': 'Lem Lemoncloak'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_88',
#   'targetCharacter': 'Gregor Clegane'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_300',
#   'targetCharacter': 'Sandor Clegane'},
#  {'source_character_id': 'ch_302',
#   'sourceCharacter': 'Selyse Baratheon',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_302',
#   'targetCharacter': 'Selyse Baratheon'},
#  {'source_character_id': 'ch_315',
#   'sourceCharacter': 'Smalljon Umber',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_312',
#   'targetCharacter': 'Shaggydog'},
#  {'source_character_id': 'ch_317',
#   'sourceCharacter': 'Stannis Baratheon',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Gordy'},
#  {'source_character_id': 'ch_317',
#   'sourceCharacter': 'Stannis Baratheon',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': 'Simpson'},
#  {'source_character_id': 'ch_326',
#   'sourceCharacter': 'Styr',
#   'relationship_type': 'killed',
#   'target_character_id': None,
#   'targetCharacter': "Olly's Mother"},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_38',
#   'targetCharacter': 'Catspaw Assassin'},
#  {'source_character_id': 'ch_333',
#   'sourceCharacter': 'The Night King',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_340',
#   'targetCharacter': 'Three-Eyed Raven'},
#  {'source_character_id': 'ch_333',
#   'sourceCharacter': 'The Night King',
#   'relationship_type': 'killed',
#   'target_character_id': 'ch_355',
#   'targetCharacter': 'Viserion'},
#  {'source_character_id': 'ch_333',
#   'sourceCharacter': 'The Night King',
# ...
#   'sourceCharacter': 'Ghost',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_151',
#   'targetCharacter': 'Lady'},
#  {'source_character_id': 'ch_73',
#   'sourceCharacter': 'Ghost',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_243',
#   'targetCharacter': 'Nymeria'},
#  {'source_character_id': 'ch_73',
#   'sourceCharacter': 'Ghost',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_327',
#   'targetCharacter': 'Summer'},
#  {'source_character_id': 'ch_73',
#   'sourceCharacter': 'Ghost',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_312',
#   'targetCharacter': 'Shaggydog'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_151',
#   'targetCharacter': 'Lady'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_243',
#   'targetCharacter': 'Nymeria'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_327',
#   'targetCharacter': 'Summer'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_312',
#   'targetCharacter': 'Shaggydog'},
#  {'source_character_id': 'ch_91',
#   'sourceCharacter': 'Grey Wind',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_73',
#   'targetCharacter': 'Ghost'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_39',
#   'targetCharacter': 'Cersei Lannister'},
#  {'source_character_id': 'ch_114',
#   'sourceCharacter': 'Jaime Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_350',
#   'targetCharacter': 'Tyrion Lannister'},
#  {'source_character_id': 'ch_121',
#   'sourceCharacter': 'Joffrey Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_230',
#   'targetCharacter': 'Myrcella Baratheon'},
#  {'source_character_id': 'ch_121',
#   'sourceCharacter': 'Joffrey Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_345',
#   'targetCharacter': 'Tommen Baratheon'},
#  {'source_character_id': 'ch_122',
#   'sourceCharacter': 'Jojen Reed',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_206',
#   'targetCharacter': 'Meera Reed'},
#  {'source_character_id': 'ch_133',
#   'sourceCharacter': 'Kevan Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_351',
#   'targetCharacter': 'Tywin Lannister'},
#  {'source_character_id': 'ch_151',
#   'sourceCharacter': 'Lady',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_91',
#   'targetCharacter': 'Grey Wind'},
#  {'source_character_id': 'ch_151',
#   'sourceCharacter': 'Lady',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_243',
#   'targetCharacter': 'Nymeria'},
#  {'source_character_id': 'ch_151',
#   'sourceCharacter': 'Lady',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_327',
#   'targetCharacter': 'Summer'},
#  {'source_character_id': 'ch_151',
#   'sourceCharacter': 'Lady',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_312',
#   'targetCharacter': 'Shaggydog'},
#  {'source_character_id': 'ch_151',
#   'sourceCharacter': 'Lady',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_73',
#   'targetCharacter': 'Ghost'},
#  {'source_character_id': 'ch_153',
#   'sourceCharacter': 'Lancel Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_203',
#   'targetCharacter': 'Martyn Lannister'},
#  {'source_character_id': 'ch_153',
#   'sourceCharacter': 'Lancel Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_370',
#   'targetCharacter': 'Willem Lannister'},
#  {'source_character_id': 'ch_175',
#   'sourceCharacter': 'Loras Tyrell',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_200',
#   'targetCharacter': 'Margaery Tyrell'},
#  {'source_character_id': 'ch_184',
#   'sourceCharacter': 'Lyanna Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_29',
#   'targetCharacter': 'Brandon Stark'},
#  {'source_character_id': 'ch_184',
#   'sourceCharacter': 'Lyanna Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_21',
#   'targetCharacter': 'Benjen Stark'},
#  {'source_character_id': 'ch_184',
#   'sourceCharacter': 'Lyanna Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_60',
#   'targetCharacter': 'Eddard Stark'},
#  {'source_character_id': 'ch_185',
#   'sourceCharacter': 'Lysa Arryn',
#   'relationship_type': 'siblings',
#   'target_character_id': None,
#   'targetCharacter': 'Catelyn Tully'},
#  {'source_character_id': 'ch_185',
#   'sourceCharacter': 'Lysa Arryn',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_62',
#   'targetCharacter': 'Edmure Tully'},
#  {'source_character_id': 'ch_200',
#   'sourceCharacter': 'Margaery Tyrell',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_175',
#   'targetCharacter': 'Loras Tyrell'},
#  {'source_character_id': 'ch_203',
#   'sourceCharacter': 'Martyn Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_153',
#   'targetCharacter': 'Lancel Lannister'},
#  {'source_character_id': 'ch_203',
#   'sourceCharacter': 'Martyn Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_370',
#   'targetCharacter': 'Willem Lannister'},
#  {'source_character_id': 'ch_230',
#   'sourceCharacter': 'Myrcella Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_230',
#   'sourceCharacter': 'Myrcella Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_345',
#   'targetCharacter': 'Tommen Baratheon'},
#  {'source_character_id': 'ch_243',
#   'sourceCharacter': 'Nymeria',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_91',
#   'targetCharacter': 'Grey Wind'},
#  {'source_character_id': 'ch_243',
#   'sourceCharacter': 'Nymeria',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_151',
#   'targetCharacter': 'Lady'},
#  {'source_character_id': 'ch_243',
#   'sourceCharacter': 'Nymeria',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_327',
#   'targetCharacter': 'Summer'},
#  {'source_character_id': 'ch_243',
#   'sourceCharacter': 'Nymeria',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_312',
#   'targetCharacter': 'Shaggydog'},
#  {'source_character_id': 'ch_243',
#   'sourceCharacter': 'Nymeria',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_73',
#   'targetCharacter': 'Ghost'},
#  {'source_character_id': 'ch_246',
#   'sourceCharacter': 'Oberyn Martell',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_53',
#   'targetCharacter': 'Doran Martell'},
#  {'source_character_id': 'ch_246',
#   'sourceCharacter': 'Oberyn Martell',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_64',
#   'targetCharacter': 'Elia Martell'},
#  {'source_character_id': 'ch_278',
#   'sourceCharacter': 'Renly Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_288',
#   'targetCharacter': 'Robert Baratheon'},
#  {'source_character_id': 'ch_278',
#   'sourceCharacter': 'Renly Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_317',
#   'targetCharacter': 'Stannis Baratheon'},
#  {'source_character_id': 'ch_279',
#   'sourceCharacter': 'Rhaegal',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_58',
#   'targetCharacter': 'Drogon'},
#  {'source_character_id': 'ch_279',
#   'sourceCharacter': 'Rhaegal',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_355',
#   'targetCharacter': 'Viserion'},
#  {'source_character_id': 'ch_280',
#   'sourceCharacter': 'Rhaegar Targaryen',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_280',
#   'sourceCharacter': 'Rhaegar Targaryen',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_356',
#   'targetCharacter': 'Viserys Targaryen'},
#  {'source_character_id': 'ch_282',
#   'sourceCharacter': 'Rhaella Targaryen',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_4',
#   'targetCharacter': 'Aerys II Targaryen'},
#  {'source_character_id': 'ch_286',
#   'sourceCharacter': 'Rickon Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_287',
#   'targetCharacter': 'Robb Stark'},
#  {'source_character_id': 'ch_286',
#   'sourceCharacter': 'Rickon Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_301',
#   'targetCharacter': 'Sansa Stark'},
#  {'source_character_id': 'ch_286',
#   'sourceCharacter': 'Rickon Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_16',
#   'targetCharacter': 'Arya Stark'},
#  {'source_character_id': 'ch_286',
#   'sourceCharacter': 'Rickon Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_30',
#   'targetCharacter': 'Bran Stark'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_301',
#   'targetCharacter': 'Sansa Stark'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_16',
#   'targetCharacter': 'Arya Stark'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_30',
#   'targetCharacter': 'Bran Stark'},
#  {'source_character_id': 'ch_287',
#   'sourceCharacter': 'Robb Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_286',
#   'targetCharacter': 'Rickon Stark'},
#  {'source_character_id': 'ch_288',
#   'sourceCharacter': 'Robert Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_317',
#   'targetCharacter': 'Stannis Baratheon'},
#  {'source_character_id': 'ch_288',
#   'sourceCharacter': 'Robert Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_278',
#   'targetCharacter': 'Renly Baratheon'},
#  {'source_character_id': 'ch_299',
#   'sourceCharacter': 'Samwell Tarly',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_49',
#   'targetCharacter': 'Dickon Tarly'},
#  {'source_character_id': 'ch_299',
#   'sourceCharacter': 'Samwell Tarly',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_330',
#   'targetCharacter': 'Talla Tarly'},
#  {'source_character_id': 'ch_300',
#   'sourceCharacter': 'Sandor Clegane',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_88',
#   'targetCharacter': 'Gregor Clegane'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_287',
#   'targetCharacter': 'Robb Stark'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_16',
#   'targetCharacter': 'Arya Stark'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_30',
#   'targetCharacter': 'Bran Stark'},
#  {'source_character_id': 'ch_301',
#   'sourceCharacter': 'Sansa Stark',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_286',
#   'targetCharacter': 'Rickon Stark'},
#  {'source_character_id': 'ch_312',
#   'sourceCharacter': 'Shaggydog',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_91',
#   'targetCharacter': 'Grey Wind'},
#  {'source_character_id': 'ch_312',
#   'sourceCharacter': 'Shaggydog',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_151',
#   'targetCharacter': 'Lady'},
#  {'source_character_id': 'ch_312',
#   'sourceCharacter': 'Shaggydog',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_243',
#   'targetCharacter': 'Nymeria'},
#  {'source_character_id': 'ch_312',
#   'sourceCharacter': 'Shaggydog',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_327',
#   'targetCharacter': 'Summer'},
#  {'source_character_id': 'ch_312',
#   'sourceCharacter': 'Shaggydog',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_73',
#   'targetCharacter': 'Ghost'},
#  {'source_character_id': 'ch_317',
#   'sourceCharacter': 'Stannis Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_288',
#   'targetCharacter': 'Robert Baratheon'},
#  {'source_character_id': 'ch_317',
#   'sourceCharacter': 'Stannis Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_278',
#   'targetCharacter': 'Renly Baratheon'},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_91',
#   'targetCharacter': 'Grey Wind'},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_151',
#   'targetCharacter': 'Lady'},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_243',
#   'targetCharacter': 'Nymeria'},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_312',
#   'targetCharacter': 'Shaggydog'},
#  {'source_character_id': 'ch_327',
#   'sourceCharacter': 'Summer',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_73',
#   'targetCharacter': 'Ghost'},
#  {'source_character_id': 'ch_330',
#   'sourceCharacter': 'Talla Tarly',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_49',
#   'targetCharacter': 'Dickon Tarly'},
#  {'source_character_id': 'ch_330',
#   'sourceCharacter': 'Talla Tarly',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_299',
#   'targetCharacter': 'Samwell Tarly'},
#  {'source_character_id': 'ch_337',
#   'sourceCharacter': 'Theon Greyjoy',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_377',
#   'targetCharacter': 'Yara Greyjoy'},
#  {'source_character_id': 'ch_345',
#   'sourceCharacter': 'Tommen Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_121',
#   'targetCharacter': 'Joffrey Baratheon'},
#  {'source_character_id': 'ch_345',
#   'sourceCharacter': 'Tommen Baratheon',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_230',
#   'targetCharacter': 'Myrcella Baratheon'},
#  {'source_character_id': 'ch_350',
#   'sourceCharacter': 'Tyrion Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_39',
#   'targetCharacter': 'Cersei Lannister'},
#  {'source_character_id': 'ch_350',
#   'sourceCharacter': 'Tyrion Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_114',
#   'targetCharacter': 'Jaime Lannister'},
#  {'source_character_id': 'ch_355',
#   'sourceCharacter': 'Viserion',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_58',
#   'targetCharacter': 'Drogon'},
#  {'source_character_id': 'ch_355',
#   'sourceCharacter': 'Viserion',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_279',
#   'targetCharacter': 'Rhaegal'},
#  {'source_character_id': 'ch_356',
#   'sourceCharacter': 'Viserys Targaryen',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_45',
#   'targetCharacter': 'Daenerys Targaryen'},
#  {'source_character_id': 'ch_356',
#   'sourceCharacter': 'Viserys Targaryen',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_280',
#   'targetCharacter': 'Rhaegar Targaryen'},
#  {'source_character_id': 'ch_370',
#   'sourceCharacter': 'Willem Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_153',
#   'targetCharacter': 'Lancel Lannister'},
#  {'source_character_id': 'ch_370',
#   'sourceCharacter': 'Willem Lannister',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_203',
#   'targetCharacter': 'Martyn Lannister'},
#  {'source_character_id': 'ch_377',
#   'sourceCharacter': 'Yara Greyjoy',
#   'relationship_type': 'siblings',
#   'target_character_id': 'ch_337',
#   'targetCharacter': 'Theon Greyjoy'}]

# %%
# TODO Student -- You will use the loop below and your query to load the information.
# TODO Student -- Put your query from above in the code below.
#
with GraphDatabase.driver(URI, auth=AUTH) as driver:

    for r in info_to_load:
        source_character_id= r['source_character_id']
        target_character_id= r["target_character_id"]
        relationship_type=r["relationship_type"]

        # We should skip the houseName because we loaded that by accident.
        # There are some target characters that were NOT in the original list of characters.
        #
        if relationship_type != 'houseName' and target_character_id is not None:

            # TODO Student -- Put your query here.
            create_relationship_q = f"""
                MERGE (source :Character:IMDB {{character_id: "{source_character_id}"}})
                MERGE (target :Character:IMDB {{character_id: "{target_character_id}"}})
                CREATE (source)-[:{relationship_type}]->(target)
                """
    
            records, summary, keys = driver.execute_query(
                create_relationship_q
            )
        
            if summary.counters.relationships_created != 1:
                print("Oops. Could not create", r)

# %% [markdown]
# An example of what things look like after the execution is below
#
# | <img src="neo4j_screen_2.jpg"> |
# | :---: |
# | __Arya Stark and Friends__ |

# %% [markdown]
# # This is Where the Magic Happens

# %% [markdown]
# Done with homework 3b. And, now on to the final homework.
#
# | <img src="the_magic.jpg"> |
# | :---: |
# | __Time to Make the Magic Happen__ |
